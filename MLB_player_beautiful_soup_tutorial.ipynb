# %% [markdown]
# # CSCI - Introduction to Programming with Python #

# %% [markdown]
# ## The TLDR version (see below for step-by-step annotated tutorial) ##

# %%
from bs4 import BeautifulSoup as bs4
import requests
import csv

alphabet = "abcdefghijklmnopqrstuvwyz"
player_list = []


for letter in alphabet:
    MLB_players = requests.get("http://www.baseball-reference.com/players/{}/".format(letter))
    MLB_soup = bs4(MLB_players.content, "html.parser")
   
    players = MLB_soup.findAll("p")
    
    for player in players:
        if "(" in player.text:
            player_list.append(player.text)
            
new_player_list = []
for player in player_list:
    player = player.replace('(',"").replace(')',"").replace("-"," ").replace("  ", " ")
    new_player_list.append(player)

split_player_list = []
for player in new_player_list:
    split_player_list.append(player.split(" "))

for career in split_player_list:
    if len(career) == 5:
        career[0] = career[0] + career[1]
        career.remove(career[1])
    
    elif len(career) == 3:
        career.insert(0, career[0])
        
    elif len(career) == 6:
        career[1] = career[1] + career[2] + career[3]
        career.remove(career[2])
        career.remove(career[2])
        
for row in split_player_list:
    row.append((int(row[3]) - int(row[2]))+1)
        
with open("MLB_careers.csv","w",newline="") as f:
    writer = csv.writer(f)
    writer.writerows(split_player_list)

# %% [markdown]
# ## Annotated Step by Step version

# %%
#import these libraries first
from bs4 import BeautifulSoup as bs4
import requests

#request.get grabs html from the url
MLB_players = requests.get("http://www.baseball-reference.com/players/a/")

#this creates a beautifulsoup object
MLB_soup = bs4(MLB_players.content, "html.parser")

# %% [markdown]
# ### As you can see, the contents of a request.get call is a mess, so we need beautifulsoup to parse the html.

# %%
print (MLB_players.content[0:200])
# Out:
# b'<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/br/build" itemscope itemtype="http://schema.org/WebSite" lang="en" class="no-js" >\n<head>\n    <meta name="viewport" content="width=device-'

# %%
#this makes the html much easier to readh
print (MLB_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/br/build" data-version="klecko-" itemscope="" itemtype="http://schema.org/WebSite" lang="en">
#  <head>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
#   <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect">
#    <link crossorigin="" href="http://d9kjk42l7bfqz.cloudfront.net/req/201607120" rel="preconnect">
#     <link crossorigin="" href="https://www.google-analytics.com/" rel="preconnect">
#      <link crossorigin="" href="https://www.googletagservices.com" rel="preconnect">
#       <script class="allowed">
#        var sr_is_production = true;
# function vjs_ready(e){"loading"!=document.readyState?e():document.addEventListener("DOMContentLoaded",e)}var log_performance=!1,sr_detect_operaMini=navigator.userAgent.indexOf("Opera Mini")>-1;if(sr_detect_operaMini){var el=document.querySelector("html");el.className=el.className.concat(" operamini")}var sr_detect_firefox=navigator.userAgent.indexOf("Firefox")>-1;if(sr_detect_firefox){var el=document.querySelector("html");el.className=el.className.concat(" firefox")}var sr_detect_firefoxMobile=navigator.userAgent.indexOf("Firefox")>-1&&(navigator.userAgent.indexOf("Mobile")>-1||navigator.userAgent.indexOf("Tablet")>-1);if(sr_detect_firefoxMobile){var el=document.querySelector("html");el.className=el.className.concat(" firefox-mobile")}var sr_detect_ie=function(){var e=window.navigator.userAgent;if(e.indexOf("Trident/7.0")>0)return 11;if(e.indexOf("Trident/6.0")>0)return 10;if(e.indexOf("Trident/5.0")>0)return 9;for(var t=3,n=document.createElement("div"),r=n.getElementsByTagName("i");n.innerHTML="<!--[if gt IE "+ ++t+"]><i></i><![endif]-->",r[0];);return t>4?t:!1}(),sr_detect_edge=!sr_detect_ie&&!!window.StyleMedia,sr_detect_safari=/Safari/.test(navigator.userAgent)&&/Apple Computer/.test(navigator.vendor),el=document.querySelector("html"),className="no-js";el.classList?el.classList.remove(className):el.className=el.className.replace(new RegExp("(^|\\b)"+className.split(" ").join("|")+"(\\b|)","gi")," "),el.className=el.className.concat(" js"),!function(e,t,n){function r(e,t){return typeof e===t}function o(){var e,t,n,o,i,a,s;for(var l in M)if(M.hasOwnProperty(l)){if(e=[],t=M[l],t.name&&(e.push(t.name.toLowerCase()),t.options&&t.options.aliases&&t.options.aliases.length))for(n=0;n<t.options.aliases.length;n++)e.push(t.options.aliases[n].toLowerCase());for(o=r(t.fn,"function")?t.fn():t.fn,i=0;i<e.length;i++)a=e[i],s=a.split("."),1===s.length?b[s[0]]=o:(!b[s[0]]||b[s[0]]instanceof Boolean||(b[s[0]]=new Boolean(b[s[0]])),b[s[0]][s[1]]=o),y.push((o?"":"no-")+s.join("-"))}}function i(e){var t=z.className,n=b._config.classPrefix||"";if(E&&(t=t.baseVal),b._config.enableJSClass){var r=new RegExp("(^|\\s)"+n+"no-js(\\s|)");t=t.replace(r,"1"+n+"js2")}b._config.enableClasses&&(t+=" "+n+e.join(" "+n),E?z.className.baseVal=t:z.className=t)}function a(){return"function"!=typeof t.createElement?t.createElement(arguments[0]):E?t.createElementNS.call(t,"http://www.w3.org/2000/svg",arguments[0]):t.createElement.apply(t,arguments)}function s(){var e=t.body;return e||(e=a(E?"svg":"body"),e.fake=!0),e}function l(e,n,r,o){var i,l,c,d,u="modernizr",f=a("div"),m=s();if(parseInt(r,10))for(;r--;)c=a("div"),c.id=o?o[r]:u+(r+1),f.appendChild(c);return i=a("style"),i.type="text/css",i.id="s"+u,(m.fake?m:f).appendChild(i),m.appendChild(f),i.styleSheet?i.styleSheet.cssText=e:i.appendChild(t.createTextNode(e)),f.id=u,m.fake&&(m.style.background="",m.style.overflow="hidden",d=z.style.overflow,z.style.overflow="hidden",z.appendChild(m)),l=n(f,e),m.fake?(m.parentNode.removeChild(m),z.style.overflow=d,z.offsetHeight):f.parentNode.removeChild(f),!!l}function c(e){return e.replace(/([a-z])-([a-z])/g,function(e,t,n){return t+n.toUpperCase()}).replace(/^-/,"")}function d(e,t){return!!~(""+e).indexOf(t)}function u(e,t){return function(){return e.apply(t,arguments)}}function f(e,t,n){var o;for(var i in e)if(e[i]in t)return n===!1?e[i]:(o=t[e[i]],r(o,"function")?u(o,n||t):o);return!1}function m(e){return e.replace(/([A-Z])/g,function(e,t){return"-"+t.toLowerCase()}).replace(/^ms-/,"-ms-")}function p(t,n,r){var o;if("getComputedStyle"in e){o=getComputedStyle.call(e,t,n);var i=e.console;if(null!==o)r&&(o=o.getPropertyValue(r));else if(i){var a=i.error?"error":"log";i[a].call(i,"getComputedStyle returning null, its possible modernizr test results are inaccurate")}}else o=!n&&t.currentStyle&&t.currentStyle[r];return o}function h(t,r){var o=t.length;if("CSS"in e&&"supports"in e.CSS){for(;o--;)if(e.CSS.supports(m(t[o]),r))return!0;return!1}if("CSSSupportsRule"in e){for(var i ...
#       </script>
#       <script>
#        if (Modernizr.is_modern) { loadJS( "https://d2p3bygnnzw9w3.cloudfront.net/req/201705014/js/br/sr-min.js"     , function() { vjs_ready(sr_fire_js); }); }
# else                     { loadJS( "https://d2p3bygnnzw9w3.cloudfront.net/req/201705014/js/br/sr-basic-min.js", function() { vjs_ready(sr_fire_js); }); }
#       </script>
#       <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201705014/css/br/sr-min.css" rel="stylesheet" type="text/css"/>
#       <title>
#        Baseball Players with Last Names Starting with A | Baseball-Reference.com
#       </title>
#       <meta content="True" name="HandheldFriendly"/>
#       <meta content="telephone=no" name="format-detection">
#        <meta content="yes" name="apple-mobile-web-app-capable">
#         <meta content="4d383b" name="theme-color">
#          <meta content="4d383b" name="msapplication-navbutton-color">
#           <meta content="4d383b" name="apple-mobile-web-app-status-bar-style">
#            <meta content="" name="keywords">
#             <link href="http://www.baseball-reference.com/players/a/index.shtml" rel="canonical"/>
#             <meta content="http://www.baseball-reference.com" itemprop="url">
#              <meta content="Baseball Reference" itemprop="name">
#               <meta content="BBref" itemprop="alternateName">
#                <meta content="Baseball Players with Last Names Starting with A" name="Description">
#                 <meta content="10515271761" property="fb:app_id">
#                  <meta content="http://www.baseball-reference.com/players/a/index.shtml" property="og:url">
#                   <meta content="Baseball Players with Last Names Starting with A | Baseball-Reference.com" property="og:title">
#                    <meta content="Baseball-Reference.com" property="og:site_name">
#                     <meta content="    article" property="og:type"/>
#                     <meta content="Baseball Players with Last Names Starting with A" property="og:description">
#                      <meta content="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-228x228-precomposed.png" property="og:image">
#                       <meta content="summary" name="twitter:card">
#                        <meta content="@baseball_ref" name="twitter:site">
#                         <meta content="@baseball_ref" name="twitter:creator">
#                          <meta content="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-228x228-precomposed.png" property="twitter:image">
#                           <meta content="Baseball-Reference.com" name="twitter:domain">
#                            <!-- tiles, touch, favicons -->
#                            <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-192x192-precomposed.png" rel="icon" sizes="192x192">
#                             <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-228x228-precomposed.png" rel="apple-touch-icon" sizes="228x228">
#                              <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-195x195-precomposed.png" rel="apple-touch-icon" sizes="195x195">
#                               <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon" sizes="180x180">
#                                <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon" sizes="152x152">
#                                 <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon" sizes="144x144">
#                                  <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-128x128-precomposed.png" rel="apple-touch-icon" sizes="128x128">
#                                   <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon" sizes="120x120">
#                                    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon" sizes="114x114">
#                                     <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76">
#                                      <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon" sizes="72x72">
#                                       <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon" sizes="57x57">
#                                        <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/favicon-32.png" rel="icon" sizes="32x32">
#                                         <!--[if IE]>
#     <link rel="shortcut icon"                                href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/favicon.ico"><![endif]-->
#                                         <meta content="#86081a" name="msapplication-TileColor"/>
#                                         <meta content="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/favicons/br/ms-tile-144.png" name="msapplication-TileImage"/>
#                                         <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/opensearch/opensearch-br.xml" rel="search" title=" Player and Team Search" type="application/opensearchdescription+xml">
#                                          <script async="" data-cfasync="false" src="//pub.freestar.io/sportsreference/pubfig.min.js">
#                                          </script>
#                                          <script data-cfasync="false" type="text/javascript">
#                                           var pbjs = pbjs || {};
# pbjs.que = pbjs.que || [];
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# googletag.cmd.push(function() {
#   // Include the line reflecting the area/section of the site you are on
#   googletag.pubads().setTargeting('sr_site_id', 'br');
# });
#                                          </script>
#                                         </link>
#                                        </link>
#                                       </link>
#                                      </link>
#                                     </link>
#                                    </link>
#                                   </link>
#                                  </link>
#                                 </link>
#                                </link>
#                               </link>
#                              </link>
#                             </link>
#                            </link>
#                           </meta>
#                          </meta>
#                         </meta>
#                        </meta>
#                       </meta>
#                      </meta>
#                     </meta>
#                    </meta>
#                   </meta>
#                  </meta>
#                 </meta>
#                </meta>
#               </meta>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="br">
#   <div id="wrap">
#    <div id="header" role="banner">
#     <ul id="subnav">
#      <li>
#       <a href="http://www.sports-reference.com/">
#        <svg height="15px" width="20px">
#         <use xlink:href="#ic-sr-pennant">
#         </use>
#        </svg>
#        Sports Reference
#       </a>
#      </li>
#      <li class="current">
#       <a href="http://www.baseball-reference.com/">
#        Baseball
#       </a>
#      </li>
#      <li>
#       <a href="http://www.pro-football-reference.com/">
#        Football
#       </a>
#       <a href="http://www.sports-reference.com/cfb/">
#        (college)
#       </a>
#      </li>
#      <li>
#       <a href="http://www.basketball-reference.com/">
#        Basketball
#       </a>
#       <a href="http://www.sports-reference.com/cbb/">
#        (college)
#       </a>
#      </li>
#      <li>
#       <a href="http://www.hockey-reference.com/">
#        Hockey
#       </a>
#      </li>
#      <li>
#       <a href="http://fbref.com/">
#        Soccer
#       </a>
#      </li>
#      <li>
#       <a href="http://www.sports-reference.com/blog/">
#        Blog
#       </a>
#      </li>
#      <li>
#       <a href="http://www.sports-reference.com/feedback/">
#        Questions or Comments?
#       </a>
#      </li>
#      <li class="user logged_in">
#       Welcome
#       <span class="username">
#       </span>
#       ·
#       <a href="/my/">
#        Your Account
#       </a>
#      </li>
#      <li class="user logged_in">
#       <a class="logout" href="/my/?do=logout">
#        Logout
#       </a>
#      </li>
#      <li class="user not_logged_in">
#       <a class="login" href="/my/">
#        Login
#       </a>
#      </li>
#      <li class="user not_logged_in">
#       <a href="/my/">
#        Create Account
#       </a>
#      </li>
#      <li>
#       <a href="/my/?do=ad_free_browsing">
#        Surf AD-FREE
#       </a>
#      </li>
#     </ul>
#     <a href="/">
#      <img alt="Baseball-Reference.com Logo &amp; Link to home page" onerror="this.src='https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/logos/br-logo.png'; this.onerror = null;" src="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/logos/br-logo.svg"/>
#     </a>
#     <div id="nav_trigger" role="button">
#      <a href="#site_menu_link">
#       MENU
#      </a>
#     </div>
#     <div aria-label="Baseball-Reference.com sections" id="nav" role="navigation">
#      <ul class="hoversmooth nohover" id="main_nav">
#       <li class="current" id="header_players">
#        <a href="/players">
#         Players
#        </a>
#       </li>
#       <li id="header_teams">
#        <a href="/teams/">
#         Teams
#        </a>
#       </li>
#       <li id="header_leagues">
#        <a href="/leagues/">
#         Seasons
#        </a>
#       </li>
#       <li id="header_leaders">
#        <a href="/leaders/">
#         Leaders
#        </a>
#       </li>
#       <li id="header_scores">
#        <a href="/boxes/">
#         MLB Scores
#        </a>
#       </li>
#       <li class="" id="header_playoffs">
#        <a href="/postseason/">
#         MLB Playoffs
#        </a>
#       </li>
#       <li class="" id="header_playindex">
#        <a href="/play-index/">
#         Play Index
#        </a>
#       </li>
#       <li>
#        <a class="opener" data-scroll="" href="#site_menu_link">
#         Full Site Menu Below
#        </a>
#       </li>
#      </ul>
#      <div class="breadcrumbs">
#       You are here:
#       <div class="crumbs" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#        <span>
#         <a href="/">
#          BR Home
#         </a>
#        </span>
#        &gt;
#        <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a href="/players/" itemprop="item">
#          <span itemprop="name">
#           Baseball Encyclopedia of Players
#          </span>
#         </a>
#         <meta content="1" itemprop="position"/>
#        </span>
#        &gt;
#        <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <strong>
#          <span itemprop="name">
#           Last Names Starting with A
#          </span>
#         </strong>
#         <meta content="2" itemprop="position"/>
#        </span>
#       </div>
#      </div>
#      <ul class="usertools bullets-inline">
#       <li class="user logged_in">
#        Welcome
#        <span class="username">
#        </span>
#        ·
#        <a href="/my/">
#         Your Account
#        </a>
#       </li>
#       <li class="user logged_in">
#        <a class="logout" href="/my/?do=logout">
#         Logout
#        </a>
#       </li>
#       <li class="user not_logged_in">
#        <a class="login" href="/my/">
#         Login
#        </a>
#       </li>
#       <li class="user not_logged_in">
#        <a href="/my/">
#         Create Account
#        </a>
#       </li>
#       <li>
#        <a href="/my/?do=ad_free_browsing">
#         Surf AD-FREE
#        </a>
#       </li>
#      </ul>
#      <!-- ul.user -->
#     </div>
#     <!-- div#nav -->
#     <script>
#      function sr_menus_setupMainNav_button_inline () {
#     if (sr_detect_operaMini || !("classList" in document.createElement("_"))) {
# 	return false;
#     }
#     var nav_trigger = document.getElementById('nav_trigger');
#     if(!nav_trigger || !Modernizr.is_modern || nav_trigger.triggered) {
# 	return false;
#     }
#     nav_trigger.triggered = true;
#     var nav = document.getElementById('nav');
#     var nav_trigger_a = nav_trigger.querySelector('a');
#     if (nav_trigger_a) {
# 	nav_trigger_a.setAttribute('href','javascript:void(0)');
# 	nav_trigger.onclick = function (event) {
# 	    nav.classList.toggle('open');
# 	    var is_open = nav.classList.contains('open');
# 	    if (is_open) {
# 		nav_trigger.classList.add('open');
# 	    }
# 	    else {
# 		nav_trigger.classList.remove('open');
# 	    }
# 	    event.preventDefault();
# 	    try { sr_record_analytics_event('MainNavButtonClick_inline',sr_record_directory(),sr_record_page());}
# 	    catch(err) {}
# 	};
#     }
#     return true;
# }
# sr_menus_setupMainNav_button_inline();
#     </script>
#     <div aria-label="Site Search for players, teams and sections" class="search" role="search">
#      <form action="/search/search.fcgi" itemprop="potentialAction" itemscope="" itemtype="http://schema.org/SearchAction" name="f_big">
#       <meta content="http://www.baseball-reference.com/search/search.fcgi?search={search}" itemprop="target">
#        <div class="ac-outline">
#         <div class="ac-wrapper">
#          <div class="ac-prompt">
#          </div>
#          <input autocapitalize="off" autocomplete="off" autocorrect="off" class="ac-hint" dir="auto" name="hint" placeholder="Enter Person, Team, Section, etc" spellcheck="false" tabindex="-1" type="search">
#           <input aria-label="Enter a player, team or section name" autocapitalize="off" autocomplete="off" autocorrect="off" class="ac-input completely" dir="auto" itemprop="query-input" name="search" placeholder="" spellcheck="false" tabindex="1" type="search"/>
#           <div class="ac-dropdown">
#           </div>
#          </input>
#         </div>
#        </div>
#        <input tabindex="2" type="submit" value="Search"/>
#        <input data-search-id="" name="pid" type="hidden" value="">
#        </input>
#       </meta>
#      </form>
#     </div>
#     <!-- div.search -->
#    </div>
#    <!-- div#header -->
#    <div id="srcom">
#     <!-- sr_general_top -->
#     <div class="adblock">
#      <!-- div#akunit_general_top  -->
#      <div align="center" id="div-gpt-ad-728x90-GeneralHeader">
#       <script data-cfasync="false" type="text/javascript">
#        if (sr_detect_ie || sr_detect_edge) {
#     }
#     else {
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-728x90-GeneralHeader'); });
#     }
#       </script>
#      </div>
#      <!-- /div.#akunit_general_top -->
#     </div>
#    </div>
#    <div aria-label="Sections on this page and/or other pages related to this page" class=" inactive suppress_inpage_nav" id="inner_nav" role="navigation">
#     <ul class="hoversmooth">
#      <li class="index ">
#       <a href="/players/">
#        Player Index
#       </a>
#      </li>
#      <li class="full current ">
#       <span>
#        All Players with 'A' Names
#       </span>
#      </li>
#      <li class="condensed hasmore " data-fade-selector="#inpage_nav">
#       <a href="#">
#        More Player Index Pages
#       </a>
#       <div>
#        <section>
#         <p>
#          <a href="/register/">
#           Professional Baseball Register
#          </a>
#         </p>
#         <p>
#          <a href="/nonmlbpa/">
#           Other Personnel
#          </a>
#         </p>
#         <p>
#          <a href="/managers/">
#           Managers Directory
#          </a>
#         </p>
#         <p>
#          <a href="/bullpen/">
#           Bullpen Wiki
#          </a>
#          with bios of many players, managers from MLB and beyond.
#         </p>
#        </section>
#        <p class="listhead">
#         Best Known Players
#        </p>
#        <ul class="">
#         <li>
#          <a href="/players/a/aaronha01.shtml" title="">
#           Hank Aaron
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/abreubo01.shtml" title="">
#           Bobby Abreu
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/aguilri01.shtml" title="">
#           Rick Aguilera
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/alberma01.shtml" title="">
#            Matt Albers
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/alexado01.shtml" title="">
#           Doyle Alexander
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/alexape01.shtml" title="">
#           Pete Alexander
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/allendi01.shtml" title="">
#           Dick Allen
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/allisbo01.shtml" title="">
#           Bob Allison
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/alomaro01.shtml" title="">
#           Roberto Alomar
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/alomasa02.shtml" title="">
#           Sandy Alomar
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/alonsyo01.shtml" title="">
#            Yonder Alonso
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/aloufe01.shtml" title="">
#           Felipe Alou
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/aloumo01.shtml" title="">
#           Moises Alou
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/alstowa01.shtml" title="">
#           Walter Alston
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/altuvjo01.shtml" title="">
#            Jose Altuve
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/alvarpe01.shtml" title="">
#            Pedro Alvarez
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/anderbr01.shtml" title="">
#           Brady Anderson
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/anderbr04.shtml" title="">
#            Brett Anderson
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/anderga01.shtml" title="">
#           Garret Anderson
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/andersp01.shtml" title="">
#           Sparky Anderson
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/andruel01.shtml" title="">
#            Elvis Andrus
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/andujjo01.shtml" title="">
#           Joaquin Andujar
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/ansonca01.shtml" title="">
#           Cap Anson
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/antonjo02.shtml" title="">
#           Johnny Antonelli
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/aokino01.shtml" title="">
#            Norichika Aoki
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/aparilu01.shtml" title="">
#           Luis Aparicio
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/applilu01.shtml" title="">
#           Luke Appling
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/archech01.shtml" title="">
#            Chris Archer
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/arenano01.shtml" title="">
#            Nolan Arenado
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/arrieja01.shtml" title="">
#            Jake Arrieta
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/arroybr01.shtml" title="">
#            Bronson Arroyo
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/ashburi01.shtml" title="">
#           Richie Ashburn
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/averiea01.shtml" title="">
#           Earl Averill
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/avilaal01.shtml" title="">
#            Alex Avila
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/axforjo01.shtml" title="">
#            John Axford
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/ayalalu01.shtml" title="">
#            Luis Ayala
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/aybarer01.shtml" title="">
#            Erick Aybar
#           </a>
#          </strong>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li class="full hasmore " data-fade-selector="#inpage_nav">
#       <span>
#        Other Indexes
#       </span>
#       <div>
#        <section>
#         <p>
#          <a href="/register/">
#           Professional Baseball Register
#          </a>
#         </p>
#         <p>
#          <a href="/nonmlbpa/">
#           Other Personnel
#          </a>
#         </p>
#         <p>
#          <a href="/managers/">
#           Managers Directory
#          </a>
#         </p>
#         <p>
#          <a href="/bullpen/">
#           Bullpen Wiki
#          </a>
#          with bios of many players, managers from MLB and beyond.
#         </p>
#        </section>
#       </div>
#      </li>
#      <li class="full hasmore " data-fade-selector="#inpage_nav">
#       <span>
#        Best Known Players
#       </span>
#       <div>
#        <p class="listhead">
#         Best Known Players
#        </p>
#        <ul class="">
#         <li>
#          <a href="/players/a/aaronha01.shtml" title="">
#           Hank Aaron
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/abreubo01.shtml" title="">
#           Bobby Abreu
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/aguilri01.shtml" title="">
#           Rick Aguilera
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/alberma01.shtml" title="">
#            Matt Albers
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/alexado01.shtml" title="">
#           Doyle Alexander
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/alexape01.shtml" title="">
#           Pete Alexander
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/allendi01.shtml" title="">
#           Dick Allen
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/allisbo01.shtml" title="">
#           Bob Allison
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/alomaro01.shtml" title="">
#           Roberto Alomar
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/alomasa02.shtml" title="">
#           Sandy Alomar
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/alonsyo01.shtml" title="">
#            Yonder Alonso
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/aloufe01.shtml" title="">
#           Felipe Alou
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/aloumo01.shtml" title="">
#           Moises Alou
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/alstowa01.shtml" title="">
#           Walter Alston
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/altuvjo01.shtml" title="">
#            Jose Altuve
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/alvarpe01.shtml" title="">
#            Pedro Alvarez
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/anderbr01.shtml" title="">
#           Brady Anderson
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/anderbr04.shtml" title="">
#            Brett Anderson
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/anderga01.shtml" title="">
#           Garret Anderson
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/andersp01.shtml" title="">
#           Sparky Anderson
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/andruel01.shtml" title="">
#            Elvis Andrus
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/andujjo01.shtml" title="">
#           Joaquin Andujar
#          </a>
#         </li>
#         <li>
#          <a href="/players/a/ansonca01.shtml" title="">
#           Cap Anson
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/antonjo02.shtml" title="">
#           Johnny Antonelli
#          </a>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/aokino01.shtml" title="">
#            Norichika Aoki
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/aparilu01.shtml" title="">
#           Luis Aparicio
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/applilu01.shtml" title="">
#           Luke Appling
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/archech01.shtml" title="">
#            Chris Archer
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/arenano01.shtml" title="">
#            Nolan Arenado
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/arrieja01.shtml" title="">
#            Jake Arrieta
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/arroybr01.shtml" title="">
#            Bronson Arroyo
#           </a>
#          </strong>
#         </li>
#         <li>
#          <a href="/players/a/ashburi01.shtml" title="">
#           Richie Ashburn
#          </a>
#          +
#         </li>
#         <li>
#          <a href="/players/a/averiea01.shtml" title="">
#           Earl Averill
#          </a>
#          +
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/avilaal01.shtml" title="">
#            Alex Avila
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/axforjo01.shtml" title="">
#            John Axford
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/ayalalu01.shtml" title="">
#            Luis Ayala
#           </a>
#          </strong>
#         </li>
#         <li>
#          <strong>
#           <a href="/players/a/aybarer01.shtml" title="">
#            Erick Aybar
#           </a>
#          </strong>
#         </li>
#        </ul>
#       </div>
#      </li>
#     </ul>
#    </div>
#    <!-- div#inner_nav -->
#    <div class="index" id="content" role="main">
#     <h1>
#      Baseball Players with Last Names Starting with A
#     </h1>
#     <div class="section_wrapper setup_commented commented alphabet" id="all_alphabet">
#      <div class="section_heading">
#       <span class="section_anchor" data-label="Index of Letters" data-no-inpage="1" id="alphabet_link">
#       </span>
#       <h2>
#        Index of Letters
#       </h2>
#      </div>
#      <!--
#     <div class="section_content" id="div_alphabet">
# <ul class="alphabet inline">
# <li><em>A</em></li><li><a href="/players/b/">B</a></li><li><a href="/players/c/">C</a></li><li><a href="/players/d/">D</a></li><li><a href="/players/e/">E</a></li><li><a href="/players/f/">F</a></li><li><a href="/players/g/">G</a></li><li><a href="/players/h/">H</a></li><li><a href="/players/i/">I</a></li><li><a href="/players/j/">J</a></li><li><a href="/players/k/">K</a></li><li><a href="/players/l/">L</a></li><li><a href="/players/m/">M</a></li><li><a href="/players/n/">N</a></li><li><a href="/players/o/">O</a></li><li><a href="/players/p/">P</a></li><li><a href="/players/q/">Q</a></li><li><a href="/players/r/">R</a></li><li><a href="/players/s/">S</a></li><li><a href="/players/t/">T</a></li><li><a href="/players/u/">U</a></li><li><a href="/players/v/">V</a></li><li><a href="/players/w/">W</a></li><li>X</li><li><a href="/players/y/">Y</a></li><li><a href="/players/z/">Z</a></li></ul>
#
#     </div>
#
# -->
#     </div>
#     <div class="section_wrapper" id="all_players_">
#      <div class="section_heading">
#       <span class="section_anchor" data-label="568 Players" id="players__link">
#       </span>
#       <h2>
#        568 Players
#       </h2>
#       <div class="section_heading_text">
#        <ul>
#         <li>
#          <strong>
#           Bold
#          </strong>
#          indicates active player and + indicates a Hall of Famer.
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="section_content" id="div_players_">
#       <p>
#        <a href="/players/a/aardsda01.shtml">
#         David Aardsma
#        </a>
#        (2004-2015)
#       </p>
#       <p>
#        <a href="/players/a/aaronha01.shtml">
#         Hank Aaron
#        </a>
#        + (1954-1976)
#       </p>
#       <p>
#        <a href="/players/a/aaronto01.shtml">
#         Tommie Aaron
#        </a>
#        (1962-1971)
#       </p>
#       <p>
#        <a href="/players/a/aasedo01.shtml">
#         Don Aase
#        </a>
#        (1977-1990)
#       </p>
#       <p>
#        <a href="/players/a/abadan01.shtml">
#         Andy Abad
#        </a>
#        (2001-2006)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/abadfe01.shtml">
#          Fernando Abad
#         </a>
#         (2010-2017)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/abadijo01.shtml">
#         John Abadie
#        </a>
#        (1875-1875)
#       </p>
#       <p>
#        <a href="/players/a/abbated01.shtml">
#         Ed Abbaticchio
#        </a>
#        (1897-1910)
#       </p>
#       <p>
#        <a href="/players/a/abbeybe01.shtml">
#         Bert Abbey
#        </a>
#        (1892-1896)
#       </p>
#       <p>
#        <a href="/players/a/abbeych01.shtml">
#         Charlie Abbey
#        </a>
#        (1893-1897)
#       </p>
#       <p>
#        <a href="/players/a/abbotda01.shtml">
#         Dan Abbott
#        </a>
#        (1890-1890)
#       </p>
#       <p>
#        <a href="/players/a/abbotfr01.shtml">
#         Fred Abbott
#        </a>
#        (1903-1905)
#       </p>
#       <p>
#        <a href="/players/a/abbotgl01.shtml">
#         Glenn Abbott
#        </a>
#        (1973-1984)
#       </p>
#       <p>
#        <a href="/players/a/abbotje01.shtml">
#         Jeff Abbott
#        </a>
#        (1997-2001)
#       </p>
#       <p>
#        <a href="/players/a/abbotji01.shtml">
#         Jim Abbott
#        </a>
#        (1989-1999)
#       </p>
#       <p>
#        <a href="/players/a/abbotku01.shtml">
#         Kurt Abbott
#        </a>
#        (1993-2001)
#       </p>
#       <p>
#        <a href="/players/a/abbotky01.shtml">
#         Kyle Abbott
#        </a>
#        (1991-1996)
#       </p>
#       <p>
#        <a href="/players/a/abbotod01.shtml">
#         Ody Abbott
#        </a>
#        (1910-1910)
#       </p>
#       <p>
#        <a href="/players/a/abbotpa01.shtml">
#         Paul Abbott
#        </a>
#        (1990-2004)
#       </p>
#       <p>
#        <a href="/players/a/aberal01.shtml">
#         Al Aber
#        </a>
#        (1950-1957)
#       </p>
#       <p>
#        <a href="/players/a/abercda01.shtml">
#         Frank Abercrombie
#        </a>
#        (1871-1871)
#       </p>
#       <p>
#        <a href="/players/a/abercre01.shtml">
#         Reggie Abercrombie
#        </a>
#        (2006-2008)
#       </p>
#       <p>
#        <a href="/players/a/abernbi01.shtml">
#         Bill Abernathie
#        </a>
#        (1952-1952)
#       </p>
#       <p>
#        <a href="/players/a/abernbr01.shtml">
#         Brent Abernathy
#        </a>
#        (2001-2005)
#       </p>
#       <p>
#        <a href="/players/a/abernte01.shtml">
#         Ted Abernathy
#        </a>
#        (1942-1944)
#       </p>
#       <p>
#        <a href="/players/a/abernte02.shtml">
#         Ted Abernathy
#        </a>
#        (1955-1972)
#       </p>
#       <p>
#        <a href="/players/a/abernwo01.shtml">
#         Woody Abernathy
#        </a>
#        (1946-1947)
#       </p>
#       <p>
#        <a href="/players/a/aberscl01.shtml">
#         Cliff Aberson
#        </a>
#        (1947-1949)
#       </p>
#       <p>
#        <a href="/players/a/ablesha01.shtml">
#         Harry Ables
#        </a>
#        (1905-1911)
#       </p>
#       <p>
#        <a href="/players/a/abnersh01.shtml">
#         Shawn Abner
#        </a>
#        (1987-1992)
#       </p>
#       <p>
#        <a href="/players/a/abramca01.shtml">
#         Cal Abrams
#        </a>
#        (1949-1956)
#       </p>
#       <p>
#        <a href="/players/a/abramge01.shtml">
#         George Abrams
#        </a>
#        (1923-1923)
#       </p>
#       <p>
#        <a href="/players/a/abregjo01.shtml">
#         Johnny Abrego
#        </a>
#        (1985-1985)
#       </p>
#       <p>
#        <a href="/players/a/abreubo01.shtml">
#         Bobby Abreu
#        </a>
#        (1996-2014)
#       </p>
#       <p>
#        <a href="/players/a/abreujo01.shtml">
#         Joe Abreu
#        </a>
#        (1942-1942)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/abreujo02.shtml">
#          Jose Abreu
#         </a>
#         (2014-2017)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/abreuju01.shtml">
#         Juan Abreu
#        </a>
#        (2011-2011)
#       </p>
#       <p>
#        <a href="/players/a/abreuto01.shtml">
#         Tony Abreu
#        </a>
#        (2007-2014)
#       </p>
#       <p>
#        <a href="/players/a/abreuwi01.shtml">
#         Winston Abreu
#        </a>
#        (2006-2009)
#       </p>
#       <p>
#        <a href="/players/a/abstebi01.shtml">
#         Bill Abstein
#        </a>
#        (1906-1910)
#       </p>
#       <p>
#        <a href="/players/a/accarje01.shtml">
#         Jeremy Accardo
#        </a>
#        (2005-2012)
#       </p>
#       <p>
#        <a href="/players/a/acevejo01.shtml">
#         Jose Acevedo
#        </a>
#        (2001-2005)
#       </p>
#       <p>
#        <a href="/players/a/aceveju01.shtml">
#         Juan Acevedo
#        </a>
#        (1995-2003)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/aceveal01.shtml">
#          Alfredo Aceves
#         </a>
#         (2008-2014)
#        </b>
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/achteaj01.shtml">
#          A.J. Achter
#         </a>
#         (2014-2016)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/ackerji01.shtml">
#         Jim Acker
#        </a>
#        (1983-1992)
#       </p>
#       <p>
#        <a href="/players/a/ackerto01.shtml">
#         Tom Acker
#        </a>
#        (1956-1959)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/ackledu01.shtml">
#          Dustin Ackley
#         </a>
#         (2011-2016)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/acklefr01.shtml">
#         Fritz Ackley
#        </a>
#        (1963-1964)
#       </p>
#       <p>
#        <a href="/players/a/acostcy01.shtml">
#         Cy Acosta
#        </a>
#        (1972-1975)
#       </p>
#       <p>
#        <a href="/players/a/acosted01.shtml">
#         Ed Acosta
#        </a>
#        (1970-1972)
#       </p>
#       <p>
#        <a href="/players/a/acostjo01.shtml">
#         Jose Acosta
#        </a>
#        (1920-1922)
#       </p>
#       <p>
#        <a href="/players/a/acostma01.shtml">
#         Manny Acosta
#        </a>
#        (2007-2012)
#       </p>
#       <p>
#        <a href="/players/a/acostme01.shtml">
#         Merito Acosta
#        </a>
#        (1913-1918)
#       </p>
#       <p>
#        <a href="/players/a/acrema01.shtml">
#         Mark Acre
#        </a>
#        (1994-1997)
#       </p>
#       <p>
#        <a href="/players/a/adairje01.shtml">
#         Jerry Adair
#        </a>
#        (1958-1970)
#       </p>
#       <p>
#        <a href="/players/a/adairji01.shtml">
#         Jimmy Adair
#        </a>
#        (1931-1931)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adamecr01.shtml">
#          Cristhian Adames
#         </a>
#         (2014-2017)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/adamsac01.shtml">
#         Ace Adams
#        </a>
#        (1941-1946)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adamsau01.shtml">
#          Austin Adams
#         </a>
#         (2014-2016)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/adamsba01.shtml">
#         Babe Adams
#        </a>
#        (1906-1926)
#       </p>
#       <p>
#        <a href="/players/a/adamsbe01.shtml">
#         Bert Adams
#        </a>
#        (1910-1919)
#       </p>
#       <p>
#        <a href="/players/a/adamsbo01.shtml">
#         Bob Adams
#        </a>
#        (1925-1925)
#       </p>
#       <p>
#        <a href="/players/a/adamsbo02.shtml">
#         Bob Adams
#        </a>
#        (1931-1932)
#       </p>
#       <p>
#        <a href="/players/a/adamsbo04.shtml">
#         Bob Adams
#        </a>
#        (1977-1977)
#       </p>
#       <p>
#        <a href="/players/a/adamsbo03.shtml">
#         Bobby Adams
#        </a>
#        (1946-1959)
#       </p>
#       <p>
#        <a href="/players/a/adamsbu01.shtml">
#         Buster Adams
#        </a>
#        (1939-1947)
#       </p>
#       <p>
#        <a href="/players/a/adamsda01.shtml">
#         Dan Adams
#        </a>
#        (1914-1915)
#       </p>
#       <p>
#        <a href="/players/a/adamsda02.shtml">
#         David Adams
#        </a>
#        (2013-2013)
#       </p>
#       <p>
#        <a href="/players/a/adamsdi01.shtml">
#         Dick Adams
#        </a>
#        (1947-1947)
#       </p>
#       <p>
#        <a href="/players/a/adamsdo01.shtml">
#         Doug Adams
#        </a>
#        (1969-1969)
#       </p>
#       <p>
#        <a href="/players/a/adamsge01.shtml">
#         George Adams
#        </a>
#        (1879-1879)
#       </p>
#       <p>
#        <a href="/players/a/adamsgl01.shtml">
#         Glenn Adams
#        </a>
#        (1975-1982)
#       </p>
#       <p>
#        <a href="/players/a/adamshe01.shtml">
#         Herb Adams
#        </a>
#        (1948-1950)
#       </p>
#       <p>
#        <a href="/players/a/adamsji01.shtml">
#         Jim Adams
#        </a>
#        (1890-1890)
#       </p>
#       <p>
#        <a href="/players/a/adamsjo01.shtml">
#         Joe Adams
#        </a>
#        (1902-1902)
#       </p>
#       <p>
#        <a href="/players/a/adamska01.shtml">
#         Karl Adams
#        </a>
#        (1914-1915)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adamsla01.shtml">
#          Lane Adams
#         </a>
#         (2014-2017)
#        </b>
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adamsma01.shtml">
#          Matt Adams
#         </a>
#         (2012-2017)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/adamsmi02.shtml">
#         Mike Adams
#        </a>
#        (1972-1978)
#       </p>
#       <p>
#        <a href="/players/a/adamsmi03.shtml">
#         Mike Adams
#        </a>
#        (2004-2014)
#       </p>
#       <p>
#        <a href="/players/a/adamsre01.shtml">
#         Red Adams
#        </a>
#        (1946-1946)
#       </p>
#       <p>
#        <a href="/players/a/adamsri01.shtml">
#         Rick Adams
#        </a>
#        (1905-1905)
#       </p>
#       <p>
#        <a href="/players/a/adamsri02.shtml">
#         Ricky Adams
#        </a>
#        (1982-1985)
#       </p>
#       <p>
#        <a href="/players/a/adamsru01.shtml">
#         Russ Adams
#        </a>
#        (2004-2009)
#       </p>
#       <p>
#        <a href="/players/a/adamsry01.shtml">
#         Ryan Adams
#        </a>
#        (2011-2011)
#       </p>
#       <p>
#        <a href="/players/a/adamssp01.shtml">
#         Sparky Adams
#        </a>
#        (1922-1934)
#       </p>
#       <p>
#        <a href="/players/a/adamssp02.shtml">
#         Spencer Adams
#        </a>
#        (1923-1927)
#       </p>
#       <p>
#        <a href="/players/a/adamste01.shtml">
#         Terry Adams
#        </a>
#        (1995-2005)
#       </p>
#       <p>
#        <a href="/players/a/adamswi01.shtml">
#         Willie Adams
#        </a>
#        (1912-1919)
#       </p>
#       <p>
#        <a href="/players/a/adamswi02.shtml">
#         Willie Adams
#        </a>
#        (1996-1997)
#       </p>
#       <p>
#        <a href="/players/a/adamsjo02.shtml">
#         Joel Adamson
#        </a>
#        (1996-1998)
#       </p>
#       <p>
#        <a href="/players/a/adamsmi01.shtml">
#         Mike Adamson
#        </a>
#        (1967-1969)
#       </p>
#       <p>
#        <a href="/players/a/adcocjo01.shtml">
#         Joe Adcock
#        </a>
#        (1950-1966)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adcocna01.shtml">
#          Nathan Adcock
#         </a>
#         (2011-2015)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/addisbo01.shtml">
#         Bob Addis
#        </a>
#        (1950-1953)
#       </p>
#       <p>
#        <a href="/players/a/adducji01.shtml">
#         Jim Adduci
#        </a>
#        (1983-1989)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adducji02.shtml">
#          Jim Adduci
#         </a>
#         (2013-2017)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/addybo01.shtml">
#         Bob Addy
#        </a>
#        (1871-1877)
#       </p>
#       <p>
#        <a href="/players/a/adenhni01.shtml">
#         Nick Adenhart
#        </a>
#        (2008-2009)
#       </p>
#       <p>
#        <a href="/players/a/aderhmo01.shtml">
#         Morrie Aderholt
#        </a>
#        (1939-1945)
#       </p>
#       <p>
#        <a href="/players/a/adkinde01.shtml">
#         Dewey Adkins
#        </a>
#        (1942-1949)
#       </p>
#       <p>
#        <a href="/players/a/adkindi01.shtml">
#         Dick Adkins
#        </a>
#        (1942-1942)
#       </p>
#       <p>
#        <a href="/players/a/adkindo01.shtml">
#         Doc Adkins
#        </a>
#        (1902-1903)
#       </p>
#       <p>
#        <a href="/players/a/adkingr01.shtml">
#         Grady Adkins
#        </a>
#        (1928-1929)
#       </p>
#       <p>
#        <a href="/players/a/adkinjo01.shtml">
#         Jon Adkins
#        </a>
#        (2003-2008)
#       </p>
#       <p>
#        <a href="/players/a/adkinst01.shtml">
#         Steve Adkins
#        </a>
#        (1990-1990)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adlemti01.shtml">
#          Tim Adleman
#         </a>
#         (2016-2017)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/adlesda01.shtml">
#         Dave Adlesh
#        </a>
#        (1963-1968)
#       </p>
#       <p>
#        <b>
#         <a href="/players/a/adriaeh01.shtml">
#          Ehire Adrianza
#         </a>
#         (2013-2016)
#        </b>
#       </p>
#       <p>
#        <a href="/players/a/afenitr01.shtml">
#         Troy Afenir
#        </a>
#        (1987-1992)
#       </p>
#       <p>
#        <a href="/players/a/affelje01.shtml">
#         Jeremy Affeldt
#        </a>
#        (2002-2015)
#       </p>
#       <p>
#        <a href="/players/a/agbaybe01.shtml">
#         Benny Agbayani
#        </a>
#        (1998-2002)
#       </p>
#       <p>
#        <a href="/players/a/ageeto01.shtml">
#         Tommie Agee
#        </a>
#        (1962-1973)
#       </p>
# ...
#       <li>
#        <a href="/draft/">
#         MLB Draft
#        </a>
#        <div>
#         <a href="/draft/?query_type=year_round&amp;year_ID=2016&amp;draft_round=1&amp;draft_type=junreg&amp;">
#          2016 Draft
#         </a>
#         ,
#         <a href="/draft/?query_type=year_round&amp;year_ID=2015&amp;draft_round=1&amp;draft_type=junreg&amp;">
#          2015 Draft
#         </a>
#         ,
#         <a href="/draft/?query_type=year_round&amp;year_ID=2014&amp;draft_round=1&amp;draft_type=junreg&amp;">
#          2014 Draft
#         </a>
#         ,
#         <a href="/draft/?overall_pick=1&amp;draft_type=junreg&amp;">
#          MLB Number One Picks
#         </a>
#         ,
# 	     ...
#        </div>
#       </li>
#       <li>
#        <a href="/register/">
#         Minor, Foreign, &amp; Negro Leagues
#        </a>
#        <div>
#         <a href="/register/minor-league-stats.shtml">
#          Minor League Stats
#         </a>
#         ,
#         <a href="/register/negro-league-stats.shtml">
#          Negro League Stats
#         </a>
#         ,
#         <a href="/register/npb-stats.shtml">
#          Nippon Pro Baseball Stats
#         </a>
#         ,
#         <a href="/register/cuban-league-stats.shtml">
#          Cuban National Series Stats
#         </a>
#         ,
#         <a href="/register/kbo-stats.shtml">
#          Korean Baseball Stats
#         </a>
#         ,
#         <a href="/register/league.cgi?year=2017">
#          2017 Minor Leagues
#         </a>
#         ,
#         <a href="/register/affiliate.cgi?year=2017">
#          2017 Affiliates
#         </a>
#         ,
# 	     ...
#        </div>
#       </li>
#       <li>
#        <a href="/bullpen/">
#         Baseball-Reference Bullpen
#        </a>
#        <div>
#         <a href="/bullpen/">
#          80,000+ pages of baseball information
#         </a>
#         ,
#         <a href="/bullpen/How_to_contribute">
#          How to Contribute
#         </a>
#         ,
# 	     ...
#        </div>
#       </li>
#       <li>
#        <a href="/about/">
#         About Baseball Reference
#        </a>
#        <div>
#         <a href="/about/bat_glossary.shtml">
#          Batting Glossary
#         </a>
#         ,
#         <a href="/about/bat_glossary.shtml">
#          Pitching Glossary
#         </a>
#         ,
#         <a href="/about/war_explained.shtml">
#          Wins Above Replacement Explainer
#         </a>
#         ,
#         <a href="/data/">
#          WAR data archive
#         </a>
#         ,
#         <a href="/about/coverage.shtml">
#          BR Data Coverage
#         </a>
#         ,
# 	     ...
#        </div>
#       </li>
#      </ul>
#     </div>
#     <!-- div#site_menu -->
#     <div class="icon_group noload" id="social">
#      <div class="section_heading">
#       <span class="section_anchor" data-label="We're Social...for Statheads" data-no-inpage="1" id="_link">
#       </span>
#       <h2>
#        We're Social...for Statheads
#       </h2>
#      </div>
#      <a class="poptip" data-label="Telephone" data-tip="Call us on Telephone" href="tel://800-512-8907">
#       <svg class="icon phone">
#        <use xlink:href="#ic-phone">
#        </use>
#       </svg>
#      </a>
#      <a class="poptip" data-label="Our Blog" data-tip="The Sports Reference Blog" href="//www.sports-reference.com/blog/">
#       <svg class="icon wordpress">
#        <use xlink:href="#ic-wordpress">
#        </use>
#       </svg>
#      </a>
#      <a class="poptip" data-label="RSS Feed" data-tip="Our Blog's RSS Feed" href="http://www.sports-reference.com/blog/feed/">
#       <svg class="icon rss">
#        <use xlink:href="#ic-rss">
#        </use>
#       </svg>
#      </a>
#      <a class="poptip" data-label="Twitter" data-tip="Baseball-Reference.com at Twitter" href="http://twitter.com/baseball_ref">
#       <svg class="icon twitter">
#        <use xlink:href="#ic-twitter">
#        </use>
#       </svg>
#      </a>
#      <a class="poptip" data-label="Reddit/r/SR" data-tip="Reddit/r/SportsReference" href="http://reddit.com/r/SportsReference">
#       <svg class="icon reddit">
#        <use xlink:href="#ic-reddit">
#        </use>
#       </svg>
#      </a>
#      <a class="poptip" data-label="YouTube" data-tip="YouTube/SportsReference" href="https://www.youtube.com/user/sportsreference">
#       <svg class="icon youtube">
#        <use xlink:href="#ic-youtube">
#        </use>
#       </svg>
#      </a>
#      <a class="poptip" data-label="LinkedIn" data-tip="Follow SR on LinkedIn" href="https://www.linkedin.com/company/sports-reference-llc">
#       <svg class="icon linkedin">
#        <use xlink:href="#ic-linkedin">
#        </use>
#       </svg>
#      </a>
#      <a class="poptip" data-label="PayPal" data-tip="Send us money via PayPal" href="https://www.paypal.me/sportsref">
#       <svg class="icon paypal">
#        <use xlink:href="#ic-paypal">
#        </use>
#       </svg>
#      </a>
#      <p>
#       Every
#       <a href="http://www.sports-reference.com/blog/sports-reference-social-media/">
#        Sports Reference Social Media Account
#       </a>
#      </p>
#      <a class="button alt" href="http://www.sports-reference.com/feedback/">
#       Question, Comment, Feedback, or Correction?
#      </a>
#     </div>
#     <!-- div#social -->
#     <div id="tips_tricks">
#      <div class="section_heading">
#       <span class="section_anchor" data-label="FAQs, Tip &amp; Tricks" data-no-inpage="1" id="tips_link">
#       </span>
#       <h2>
#        FAQs, Tip &amp; Tricks
#       </h2>
#      </div>
#      <ul>
#       <li>
#        <a href="//www.sports-reference.com/blog/category/tips-and-tricks/">
#         Tips and Tricks from our Blog.
#        </a>
#       </li>
#       <li>
#        <a href="/linker/">
#         Do you have a blog? Join our linker program.
#        </a>
#       </li>
#       <li>
#        <a href="//www.sports-reference.com/blog/category/how-to-videos/">
#         Watch our How-To Videos to Become a Stathead
#        </a>
#       </li>
#       <li>
#        <a href="/my/auth.cgi?do=ad_free_browsing">
#         Go ad-free to support Sports Reference and get our fastest browsing experience
#        </a>
#       </li>
#       <li>
#        <a href="//www.baseball-reference.com/play-index/">
#         Subscribe to the Play Index and get access to more data than you can imagine
#        </a>
#       </li>
#       <li>
#        Learn about the
#        <a href="//www.baseball-reference.com/about/war_explained.shtml">
#         Wins Above Replacement Formula
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- div#tips_tricks -->
#     <div id="credits">
#      <p>
#       All logos are the trademark &amp; property of their owners and not Sports Reference LLC.  We present them here for purely educational purposes.
#       <a href="http://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">
#        Our reasoning for presenting offensive logos.
#       </a>
#      </p>
#      <p>
#       Logos were compiled by the amazing
#       <a href="http://sportslogos.net/">
#        SportsLogos.net.
#       </a>
#      </p>
#      <div class="notice">
#       A Member of the
#       <a href="http://www.foxsports.com/" rel="nofollow">
#        <img alt="Fox Sports Engage Network" height="33" src="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/images/klecko/engage.png" width="300">
#        </img>
#       </a>
#      </div>
#      <div class="notice">
#       Primary Data Provided By
#       <a href="http://www.gracenote.com/sports/sports-data/" rel="nofollow">
#        <img alt="Gracenote Sports" border="0" src="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/images/klecko/gracenote.png" width="275"/>
#       </a>
#      </div>
#      <p>
#       Copyright © 2000-2017
#       <a href="//www.sports-reference.com/">
#        Sports Reference LLC
#       </a>
#       . All rights reserved.
#      </p>
#      <p>
#       Much of the play-by-play, game results, and transaction information both shown and used to create certain data sets was obtained free of charge from and is copyrighted by
#       <a href="http://www.retrosheet.org/" rel="nofollow">
#        RetroSheet
#       </a>
#       .
#      </p>
#      <p>
#       Win Expectancy, Run Expectancy, and Leverage Index calculations provided by Tom Tango of
#       <a href="http://www.tangotiger.com/index.php" rel="nofollow">
#        InsideTheBook.com
#       </a>
#       , and co-author of
#       <a class="italic_text" href="" rel="nofollow">
#        The Book: Playing the Percentages in Baseball
#       </a>
#       .
#      </p>
#      <p>
#       Total Zone Rating and initial framework for Wins above Replacement calculations provided by Sean Smith.
#      </p>
#      <p>
#       Full-year historical Major League statistics provided by Pete Palmer and Gary Gillette of
#       <a href="http://www.hiddengamesports.com/" rel="nofollow">
#        Hidden Game Sports
#       </a>
#       .
#      </p>
#      <p>
#       <a href="http://www.baseballinfosolutions.com/">
#        <img alt="BaseballInfoSolutions.com logo" src="https://d2p3bygnnzw9w3.cloudfront.net/req/201704241/images/klecko/bis_logo.png"/>
#       </a>
#      </p>
#      <p>
#       Some defensive statistics Copyright ©
#       <a href="http://www.baseballinfosolutions.com/">
#        Baseball Info Solutions
#       </a>
#       , 2010-2017.
#      </p>
#      <p>
#       Some high school data is courtesy David McWater.
#      </p>
#      <p>
#       Many historical player head shots courtesy of David Davis. Many thanks to him. All images are property the copyright holder and are displayed here for informational purposes only.
#      </p>
#     </div>
#     <!-- div#credits -->
#     <ul class="bullets-inline" id="site_dirs">
#      <li>
#       <a href="http://www.sports-reference.com/">
#        <svg height="15px" width="20px">
#         <use xlink:href="#ic-sr-pennant">
#         </use>
#        </svg>
#        Sports Reference
#       </a>
#      </li>
#      <li class="current">
#       <a href="http://www.baseball-reference.com/">
#        Baseball
#       </a>
#      </li>
#      <li>
#       <a href="http://www.pro-football-reference.com/">
#        Football
#       </a>
#       <a href="http://www.sports-reference.com/cfb/">
#        (college)
#       </a>
#      </li>
#      <li>
#       <a href="http://www.basketball-reference.com/">
#        Basketball
#       </a>
#       <a href="http://www.sports-reference.com/cbb/">
#        (college)
#       </a>
#      </li>
#      <li>
#       <a href="http://www.hockey-reference.com/">
#        Hockey
#       </a>
#      </li>
#      <li>
#       <a href="http://fbref.com/">
#        Soccer
#       </a>
#      </li>
#      <li>
#       <a href="http://www.sports-reference.com/blog/">
#        Blog
#       </a>
#      </li>
#     </ul>
#     <div id="about">
#      <a href="//www.sports-reference.com/about.html">
#       About
#      </a>
#      •
#      <a href="//www.sports-reference.com/privacy.html">
#       Privacy Statement
#      </a>
#      •
#      <a href="//www.sports-reference.com/termsofuse.html">
#       Conditions &amp; Terms of Service
#      </a>
#      •
#      <a href="//www.sports-reference.com/data_use.html">
#       Use of Data
#      </a>
#     </div>
#     <!-- div#about -->
#    </div>
#    <!-- div#footer -->
#   </div>
#   <!-- div#wrap -->
#   <!-- Google Analytics -->
#   <script>
#    String.prototype.sr_isMatch = function(s){ return this.match(s)!==null}; function getCookie(name) { var prefix = name + "="; var begin = document.cookie.indexOf("; " + prefix); if (begin == -1) { begin = document.cookie.indexOf(prefix); if (begin != 0) return null; } else { begin += 2; var end = document.cookie.indexOf(";", begin); if (end == -1) { end = document.cookie.length; } } return unescape(document.cookie.substring(begin + prefix.length, end));} var sr_cookie = getCookie('SR_user') || ''; var sr_is_ad_free = sr_cookie.sr_isMatch('Z6SON8tTdJid'); var sr_is_user = sr_cookie !== null && sr_cookie !== ''; var sr_seen_modal = getCookie('modal_ad') !== null; (function(i,s,o,g,r,a,m){ i['GoogleAnalyticsObject']=r; i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date(); a=s.createElement(o),m=s.getElementsByTagName(o)[0]; a.async=1; a.src=g; m.parentNode.insertBefore(a,m) })(window,document,'script','https://www.google-analytics.com/analytics.js','ga'); ga('create', 'UA-1890630-1', 'auto'); ga('require', 'linkid', 'linkid.js'); ga('require', 'ecommerce', 'ecommerce.js'); ga('send', 'pageview'); ga('create', 'UA-1890630-19', 'auto', {'name': 'combined_tracker', 'allowLinker': true }); ga('combined_tracker.send', 'pageview'); var sr_device = 'unk'; if (Modernizr.phone) { sr_device = 'phone'; } else if (Modernizr.tablet) { sr_device = 'tablet'; } else if (Modernizr.laptop) { sr_device = 'laptop'; } else if (Modernizr.desktop) { sr_device = 'desktop'; } ga('create', 'UA-1890630-9', 'auto', {'name': 'sr_tracker', 'allowLinker': true }); ga('sr_tracker.require', 'displayfeatures'); ga('sr_tracker.set', 'dimension1','br'); ga('sr_tracker.set', 'dimension2',sr_is_ad_free); ga('sr_tracker.set', 'dimension3',sr_is_user); ga('sr_tracker.set', 'dimension4',sr_seen_modal); ga('sr_tracker.set', 'dimension5',sr_device); ga('sr_tracker.set', 'dimension6',Modernizr.is_modern?'yes':'no'); ga('sr_tracker.set', 'dimension7',Modernizr.viewport_width); /* note that this requires the Assets/AdBlockTest.tt2 to be included above. */ ga('sr_tracker.set', 'dimension8',(typeof sr_test == 'undefined')?'no-test':( sr_test ? 'non-blocking':'blocking')); ga('sr_tracker.send', 'pageview'); /* cribbed from: http://www.axllent.org/docs/view/track-outbound-links-with-analytics-js/ */ function _gaLt(event) { if (!ga.hasOwnProperty("loaded") || ga.loaded != true) { return; } var el = event.srcElement || event.target; /* if a link has been clicked */ if (el && el.href) { var link = el.href; /* Only if it is an external link */ if (link.indexOf(location.host) == -1 && !link.match(/^javascript\:/i)) { /* Is target set and not _(self|parent|top)? */ var target = (el.target && !el.target.match(/^_(self|parent|top)/i)) ? el.target : false; /* If target opens a new window then just track */ if (el.target && !el.target.match(/^_(self|parent|top)/i)) { ga("send", "event", "Outgoing Links", link, document.location.pathname + document.location.search); } }; } } window.addEventListener ? window.addEventListener("load", function() { document.body.addEventListener("click", _gaLt, !1)}, !1) : window.attachEvent && window.attachEvent("onload", function() { document.body.attachEvent("onclick", _gaLt) });
#   </script>
#   <!-- End Google Analytics -->
#   <!-- courtesy "http://network.yardbarker.com/network/ybn_pixel/12488" -->
#   <!-- Start Quantcast tag -->
#   <script type="text/javascript">
#    _qoptions={qacct:'p-a3g2Mplggde4A',labels:'SportsReference.AllSports'};
#   </script>
#   <script async="" src="http://edge.quantserve.com/quant.js" type="text/javascript">
#   </script>
#   <noscript>
#    <img alt="Quantcast" border="0" height="1" src="http://pixel.quantserve.com/pixel/p-a3g2Mplggde4A.gif" style="display: none;" width="1"/>
#   </noscript>
#   <!-- End Quantcast tag -->
#   <!-- Begin comScore tag -->
#   <script async="" src="http://b.scorecardresearch.com/beacon.js?c1=2&amp;c2=6036378&amp;c3=&amp;c4=&amp;c5=&amp;c6=&amp;c10=">
#   </script>
#   <noscript>
#    <img alt="scoreboard" height="0" src="http://b.scorecardresearch.com/b?c1=2&amp;c2=6036378&amp;c3=&amp;c4=&amp;c5=&amp;c6=&amp;c10=&amp;cj=1" style="display: none;" width="0"/>
#   </noscript>
#   <!-- End comScore tag -->
#   <script type="text/javascript">
#    (function () { var d = new Image(1, 1); d.onerror = d.onload = function () { d.onerror = d.onload = null; }; d.src = ['//secure-us.imrworldwide.com/cgi-bin/m?ci=us-603545h&cg=0&cc=1&si=', escape(window.location.href), '&rp=', escape(document.referrer), '&ts=compact&rnd=', (new Date()).getTime() ].join(''); })();
#   </script>
#   <noscript>
#    <div>
#     <img alt="imr" height="1" src="//secure-us.imrworldwide.com/cgi-bin/m?ci=us-603545h&amp;cg=0&amp;cc=1&amp;ts=noscript" width="1"/>
#    </div>
#   </noscript>
#   <script type="text/javascript">
#    var utag_data = { };
#   </script>
#   <script type="text/javascript">
#    (function(a,b,c,d){ a='//tags.tiqcdn.com/utag/foxsports/yardbarker/prod/utag.js'; b=document; c='script'; d=b.createElement(c); d.src=a; d.type='text/java'+c; d.async=true; a=b.getElementsByTagName(c)[0]; a.parentNode.insertBefore(d,a); })();
#   </script>
#  </body>
#  <!-- SR -->
# </html>

# %% [markdown]
# ### Next, we use FindAll() to get the content under the correct tag. In this case, the "p" tag.

# %%
players = MLB_soup.findAll("p")

#returns the strings inside each of the elements with a "p" tag
for player in players:
    print (player.text)
# Out:
# Professional Baseball Register
# Other Personnel
# Managers Directory
# Bullpen Wiki with bios of many players, managers from MLB and beyond.
# Best Known Players
# Professional Baseball Register
# Other Personnel
# Managers Directory
# Bullpen Wiki with bios of many players, managers from MLB and beyond.
# Best Known Players
# David Aardsma  (2004-2015)
# Hank Aaron+ (1954-1976)
# Tommie Aaron  (1962-1971)
# Don Aase  (1977-1990)
# Andy Abad  (2001-2006)
# Fernando Abad  (2010-2017)
# John Abadie  (1875-1875)
# Ed Abbaticchio  (1897-1910)
# Bert Abbey  (1892-1896)
# Charlie Abbey  (1893-1897)
# Dan Abbott  (1890-1890)
# Fred Abbott  (1903-1905)
# Glenn Abbott  (1973-1984)
# Jeff Abbott  (1997-2001)
# Jim Abbott  (1989-1999)
# Kurt Abbott  (1993-2001)
# Kyle Abbott  (1991-1996)
# Ody Abbott  (1910-1910)
# Paul Abbott  (1990-2004)
# Al Aber  (1950-1957)
# Frank Abercrombie  (1871-1871)
# Reggie Abercrombie  (2006-2008)
# Bill Abernathie  (1952-1952)
# Brent Abernathy  (2001-2005)
# Ted Abernathy  (1942-1944)
# Ted Abernathy  (1955-1972)
# Woody Abernathy  (1946-1947)
# Cliff Aberson  (1947-1949)
# Harry Ables  (1905-1911)
# Shawn Abner  (1987-1992)
# Cal Abrams  (1949-1956)
# George Abrams  (1923-1923)
# Johnny Abrego  (1985-1985)
# Bobby Abreu  (1996-2014)
# Joe Abreu  (1942-1942)
# Jose Abreu  (2014-2017)
# Juan Abreu  (2011-2011)
# Tony Abreu  (2007-2014)
# Winston Abreu  (2006-2009)
# Bill Abstein  (1906-1910)
# Jeremy Accardo  (2005-2012)
# Jose Acevedo  (2001-2005)
# Juan Acevedo  (1995-2003)
# Alfredo Aceves  (2008-2014)
# A.J. Achter  (2014-2016)
# Jim Acker  (1983-1992)
# Tom Acker  (1956-1959)
# Dustin Ackley  (2011-2016)
# Fritz Ackley  (1963-1964)
# Cy Acosta  (1972-1975)
# Ed Acosta  (1970-1972)
# Jose Acosta  (1920-1922)
# Manny Acosta  (2007-2012)
# Merito Acosta  (1913-1918)
# Mark Acre  (1994-1997)
# Jerry Adair  (1958-1970)
# Jimmy Adair  (1931-1931)
# Cristhian Adames  (2014-2017)
# Ace Adams  (1941-1946)
# Austin Adams  (2014-2016)
# Babe Adams  (1906-1926)
# Bert Adams  (1910-1919)
# Bob Adams  (1925-1925)
# Bob Adams  (1931-1932)
# Bob Adams  (1977-1977)
# Bobby Adams  (1946-1959)
# Buster Adams  (1939-1947)
# Dan Adams  (1914-1915)
# David Adams  (2013-2013)
# Dick Adams  (1947-1947)
# Doug Adams  (1969-1969)
# George Adams  (1879-1879)
# Glenn Adams  (1975-1982)
# Herb Adams  (1948-1950)
# Jim Adams  (1890-1890)
# Joe Adams  (1902-1902)
# Karl Adams  (1914-1915)
# Lane Adams  (2014-2017)
# Matt Adams  (2012-2017)
# Mike Adams  (1972-1978)
# Mike Adams  (2004-2014)
# Red Adams  (1946-1946)
# Rick Adams  (1905-1905)
# Ricky Adams  (1982-1985)
# Russ Adams  (2004-2009)
# Ryan Adams  (2011-2011)
# Sparky Adams  (1922-1934)
# Spencer Adams  (1923-1927)
# Terry Adams  (1995-2005)
# Willie Adams  (1912-1919)
# Willie Adams  (1996-1997)
# Joel Adamson  (1996-1998)
# Mike Adamson  (1967-1969)
# Joe Adcock  (1950-1966)
# Nathan Adcock  (2011-2015)
# Bob Addis  (1950-1953)
# Jim Adduci  (1983-1989)
# Jim Adduci  (2013-2017)
# Bob Addy  (1871-1877)
# Nick Adenhart  (2008-2009)
# Morrie Aderholt  (1939-1945)
# Dewey Adkins  (1942-1949)
# Dick Adkins  (1942-1942)
# Doc Adkins  (1902-1903)
# Grady Adkins  (1928-1929)
# Jon Adkins  (2003-2008)
# Steve Adkins  (1990-1990)
# Tim Adleman  (2016-2017)
# Dave Adlesh  (1963-1968)
# Ehire Adrianza  (2013-2016)
# Troy Afenir  (1987-1992)
# Jeremy Affeldt  (2002-2015)
# Benny Agbayani  (1998-2002)
# Tommie Agee  (1962-1973)
# Harry Agganis  (1954-1955)
# Joe Agler  (1912-1915)
# Sam Agnew  (1913-1919)
# Juan Agosto  (1981-1993)
# Luis Aguayo  (1980-1989)
# Chris Aguila  (2004-2008)
# Jesus Aguilar  (2014-2017)
# Rick Aguilera  (1985-2000)
# Hank Aguirre  (1955-1970)
# Bill Ahearn  (1880-1880)
# Pat Ahearne  (1995-1995)
# Nick Ahmed  (2014-2017)
# Willie Aikens  (1977-1985)
# Danny Ainge  (1979-1981)
# Eddie Ainsmith  (1910-1924)
# Kurt Ainsworth  (2001-2004)
# Raleigh Aitchison  (1911-1915)
# George Aiton  (1912-1912)
# John Ake  (1884-1884)
# Jack Aker  (1964-1974)
# Darrel Akerfelds  (1986-1991)
# Bill Akers  (1929-1932)
# Jerry Akers  (1912-1912)
# Gibson Alba  (1988-1988)
# Jonathan Albaladejo  (2007-2012)
# Joe Albanese  (1958-1958)
# Jose Alberro  (1995-1997)
# Andrew Albers  (2013-2016)
# Matt Albers  (2006-2017)
# Hanser Alberto  (2015-2016)
# Butch Alberts  (1978-1978)
# Cy Alberts  (1910-1910)
# Gus Alberts  (1884-1891)
# Ed Albosta  (1941-1946)
# Ed Albrecht  (1949-1950)
# Jack Albright  (1947-1947)
# Al Alburquerque  (2011-2016)
# Vic Albury  (1973-1976)
# Santo Alcala  (1976-1977)
# Arismendy Alcantara  (2014-2017)
# Israel Alcantara  (2000-2002)
# Raul Alcantara  (2016-2017)
# Luis Alcaraz  (1967-1970)
# Scotty Alcock  (1914-1914)
# Dale Alderson  (1943-1944)
# Scott Aldred  (1990-2000)
# Mike Aldrete  (1986-1996)
# Jay Aldrich  (1987-1990)
# Cory Aldridge  (2001-2010)
# Vic Aldridge  (1917-1928)
# Chuck Aleno  (1941-1944)
# Bob Alexander  (1955-1957)
# Dale Alexander  (1929-1933)
# Doyle Alexander  (1971-1989)
# Gary Alexander  (1975-1981)
# Gerald Alexander  (1990-1992)
# Hugh Alexander  (1937-1937)
# Manny Alexander  (1992-2006)
# Matt Alexander  (1973-1981)
# Nin Alexander  (1884-1884)
# Pete Alexander+ (1911-1930)
# Scott Alexander  (2015-2017)
# Walt Alexander  (1912-1917)
# Jason Alfaro  (2004-2004)
# Jorge Alfaro  (2016-2016)
# Antonio Alfonseca  (1997-2007)
# Edgardo Alfonzo  (1995-2006)
# Eliezer Alfonzo  (2006-2011)
# Luis Alicea  (1988-2002)
# Andy Allanson  (1986-1995)
# Brian Allard  (1979-1981)
# Bernie Allen  (1962-1973)
# Bob Allen  (1890-1900)
# Bob Allen  (1919-1919)
# Bob Allen  (1937-1937)
# Bob Allen  (1961-1967)
# Brandon Allen  (2009-2012)
# Chad Allen  (1999-2005)
# Cody Allen  (2012-2017)
# Dick Allen  (1963-1977)
# Dusty Allen  (2000-2000)
# Ethan Allen  (1926-1938)
# Frank Allen  (1912-1917)
# Ham Allen  (1872-1872)
# Hank Allen  (1966-1973)
# Hezekiah Allen  (1884-1884)
# Horace Allen  (1919-1919)
# Jack Allen  (1879-1879)
# Jamie Allen  (1983-1983)
# John Allen  (1914-1914)
# Johnny Allen  (1932-1944)
# Kim Allen  (1980-1981)
# Lloyd Allen  (1969-1975)
# Luke Allen  (2002-2003)
# Myron Allen  (1883-1888)
# Neil Allen  (1979-1989)
# Nick Allen  (1914-1920)
# Pete Allen  (1893-1893)
# Rod Allen  (1983-1988)
# Ron Allen  (1972-1972)
# Sled Allen  (1910-1910)
# Gary Allenson  (1979-1985)
# Jermaine Allensworth  (1996-1999)
# Gene Alley  (1963-1973)
# Gair Allie  (1954-1954)
# Bob Allietta  (1975-1975)
# Andy Allison  (1872-1872)
# Art Allison  (1871-1876)
# Bill Allison  (1872-1872)
# Bob Allison  (1958-1970)
# Dana Allison  (1991-1991)
# Doug Allison  (1871-1883)
# Mack Allison  (1911-1913)
# Milo Allison  (1913-1917)
# Beau Allred  (1989-1991)
# Mel Almada  (1933-1939)
# Armando Almanza  (1999-2005)
# Carlos Almanzar  (1997-2005)
# Rafael Almeida  (1911-1913)
# Bill Almon  (1974-1988)
# Abraham Almonte  (2013-2017)
# Edwin Almonte  (2003-2003)
# Erick Almonte  (2001-2011)
# Hector Almonte  (1999-2003)
# Miguel Almonte  (2015-2015)
# Zoilo Almonte  (2013-2014)
# Albert Almora  (2016-2017)
# Luis Aloma  (1950-1953)
# Roberto Alomar+ (1988-2004)
# Sandy Alomar  (1964-1978)
# Sandy Alomar  (1988-2007)
# Yonder Alonso  (2010-2017)
# Felipe Alou  (1958-1974)
# Jesus Alou  (1963-1979)
# Matty Alou  (1960-1974)
# Moises Alou  (1990-2008)
# Whitey Alpermann  (1906-1909)
# Dell Alston  (1977-1980)
# Garvin Alston  (1996-1996)
# Tom Alston  (1954-1957)
# Walter Alston+ (1936-1936)
# Porfi Altamirano  (1982-1984)
# Dan Altavilla  (2016-2017)
# Ernie Alten  (1920-1920)
# Jesse Altenburg  (1916-1917)
# Aaron Altherr  (2014-2017)
# Dave Altizer  (1906-1911)
# George Altman  (1959-1967)
# Joe Altobelli  (1955-1961)
# Nick Altrock  (1898-1933)
# Jose Altuve  (2011-2017)
# George Alusik  (1958-1964)
# Luis Alvarado  (1968-1977)
# Abe Alvarez  (2004-2006)
# Clemente Alvarez  (2000-2000)
# Dariel Alvarez  (2015-2016)
# Dario Alvarez  (2014-2017)
# Gabe Alvarez  (1998-2000)
# Henderson Alvarez  (2011-2015)
# Jose Alvarez  (1981-1989)
# Jose Alvarez  (2013-2017)
# Juan Alvarez  (1999-2003)
# Orlando Alvarez  (1973-1976)
# Ossie Alvarez  (1958-1959)
# Pedro Alvarez  (2010-2016)
# R.J. Alvarez  (2014-2015)
# Rogelio Alvarez  (1960-1962)
# Tavo Alvarez  (1995-1996)
# Tony Alvarez  (2002-2004)
# Victor Alvarez  (2002-2003)
# Wilson Alvarez  (1989-2005)
# Max Alvis  (1962-1970)
# Billy Alvord  (1885-1893)
# Brant Alyea  (1965-1972)
# Joey Amalfitano  (1954-1967)
# Rich Amaral  (1991-2000)
# Alexi Amarista  (2011-2017)
# Ruben Amaro  (1958-1969)
# Ruben Amaro  (1991-1998)
# Wayne Ambler  (1937-1939)
# Chip Ambres  (2005-2008)
# Hector Ambriz  (2010-2014)
# Ed Amelung  (1984-1986)
# Red Ames  (1903-1919)
# Steve Ames  (2013-2013)
# Alfredo Amezaga  (2002-2011)
# Doc Amole  (1897-1898)
# Vicente Amor  (1955-1957)
# Sandy Amoros  (1952-1960)
# Walter Ancker  (1915-1915)
# Larry Andersen  (1975-1994)
# Alf Anderson  (1941-1946)
# Allan Anderson  (1986-1991)
# Andy Anderson  (1948-1949)
# Bill Anderson  (1889-1889)
# Bill Anderson  (1925-1925)
# Bob Anderson  (1957-1963)
# Brady Anderson  (1988-2002)
# Brett Anderson  (2009-2017)
# Brian Anderson  (1993-2005)
# Brian Anderson  (2005-2009)
# Bryan Anderson  (2010-2015)
# Bud Anderson  (1982-1983)
# Chase Anderson  (2014-2017)
# Cody Anderson  (2015-2016)
# Craig Anderson  (1961-1964)
# Dave Anderson  (1889-1890)
# Dave Anderson  (1983-1992)
# Drew Anderson  (2006-2006)
# Dwain Anderson  (1971-1974)
# Ferrell Anderson  (1946-1953)
# Fred Anderson  (1909-1918)
# Garret Anderson  (1994-2010)
# George Anderson  (1914-1918)
# Goat Anderson  (1907-1907)
# Hal Anderson  (1932-1932)
# Harry Anderson  (1957-1961)
# Jason Anderson  (2003-2005)
# Jim Anderson  (1978-1984)
# Jimmy Anderson  (1999-2004)
# John Anderson  (1894-1908)
# John Anderson  (1958-1962)
# Josh Anderson  (2007-2009)
# Kent Anderson  (1989-1990)
# Larry Anderson  (1974-1977)
# Lars Anderson  (2010-2012)
# Marlon Anderson  (1998-2009)
# Matt Anderson  (1998-2005)
# Mike Anderson  (1971-1979)
# Mike Anderson  (1993-1993)
# Red Anderson  (1937-1941)
# Rick Anderson  (1979-1980)
# Rick Anderson  (1986-1988)
# Scott Anderson  (1987-1995)
# Sparky Anderson+ (1959-1959)
# Tim Anderson  (2016-2017)
# Tyler Anderson  (2016-2017)
# Varney Anderson  (1889-1896)
# Walter Anderson  (1917-1919)
# Wingo Anderson  (1910-1910)
# Robert Andino  (2005-2016)
# Steve Andrade  (2006-2006)
# John Andre  (1955-1955)
# Ernie Andres  (1946-1946)
# Kim Andrew  (1975-1975)
# Clayton Andrews  (2000-2000)
# Ed Andrews  (1884-1891)
# Elbert Andrews  (1925-1925)
# Fred Andrews  (1976-1977)
# Hub Andrews  (1947-1948)
# Ivy Andrews  (1931-1938)
# Jim Andrews  (1890-1890)
# John Andrews  (1973-1973)
# Mike Andrews  (1966-1973)
# Nate Andrews  (1937-1946)
# Rob Andrews  (1975-1979)
# Shane Andrews  (1995-2002)
# Stan Andrews  (1939-1945)
# Wally Andrews  (1884-1888)
# Matt Andriese  (2015-2017)
# Bill Andrus  (1931-1937)
# Elvis Andrus  (2009-2017)
# Fred Andrus  (1876-1884)
# Wyman Andrus  (1885-1885)
# Joaquin Andujar  (1976-1988)
# Luis Andujar  (1995-1998)
# Norm Angelini  (1972-1973)
# Matt Angle  (2011-2011)
# Tom Angley  (1929-1929)
# Pat Ankenman  (1936-1944)
# Rick Ankiel  (1999-2013)
# Dean Anna  (2014-2015)
# Bill Annis  (1884-1884)
# Cap Anson+ (1871-1897)
# Eric Anthony  (1989-1997)
# Joe Antolick  (1944-1944)
# Dustin Antolin  (2016-2016)
# John Antonelli  (1944-1945)
# Johnny Antonelli  (1948-1961)
# Matt Antonelli  (2008-2008)
# Bill Antonello  (1953-1953)
# Norichika Aoki  (2012-2017)
# Luis Aparicio+ (1956-1973)
# Bob Apodaca  (1973-1977)
# Luis Aponte  (1980-1984)
# Kevin Appier  (1989-2004)
# Fred Applegate  (1904-1904)
# Ed Appleton  (1915-1916)
# Pete Appleton  (1927-1945)
# Luke Appling+ (1930-1950)
# Greg Aquino  (2004-2009)
# Jayson Aquino  (2016-2017)
# Luis Aquino  (1986-1995)
# Angel Aragon  (1914-1917)
# Jack Aragon  (1941-1941)
# Elvis Araujo  (2015-2016)
# Maurice Archdeacon  (1923-1925)
# Chris Archer  (2012-2017)
# Fred Archer  (1936-1937)
# Jim Archer  (1961-1962)
# Jimmy Archer  (1904-1918)
# George Archie  (1938-1946)
# Jose Arcia  (1968-1970)
# Orlando Arcia  (2016-2017)
# Oswaldo Arcia  (2013-2016)
# Dan Ardell  (1961-1961)
# Rugger Ardizoia  (1947-1947)
# Joe Ardner  (1884-1890)
# Danny Ardoin  (2000-2008)
# Frank Arellanes  (1908-1910)
# Nolan Arenado  (2013-2017)
# J.P. Arencibia  (2010-2015)
# Hank Arft  (1948-1952)
# Alberto Arias  (2007-2009)
# Alex Arias  (1992-2002)
# George Arias  (1996-1999)
# Joaquin Arias  (2006-2015)
# Rudy Arias  (1959-1959)
# Buzz Arlett  (1931-1931)
# Don Arlich  (1965-1966)
# Steve Arlin  (1969-1974)
# Marcos Armas  (1993-1993)
# Tony Armas  (1976-1989)
# Tony Armas  (1999-2008)
# Ed Armbrister  (1973-1977)
# Orville Armbrust  (1934-1934)
# Charlie Armbruster  (1905-1907)
# Harry Armbruster  (1906-1906)
# George Armstrong  (1946-1946)
# Howard Armstrong  (1911-1911)
# Jack Armstrong  (1988-1994)
# Mike Armstrong  (1980-1987)
# Robert Armstrong  (1871-1871)
# Shawn Armstrong  (2015-2017)
# Harry Arndt  (1902-1907)
# Larry Arndt  (1989-1989)
# Billy Arnold  (1872-1872)
# Chris Arnold  (1971-1976)
# Jamie Arnold  (1999-2000)
# Scott Arnold  (1988-1988)
# Tony Arnold  (1986-1987)
# Morrie Arnovich  (1936-1946)
# Brad Arnsberg  (1986-1992)
# Orie Arntzen  (1943-1943)
# Jonathan Aro  (2015-2016)
# Rene Arocha  (1993-1997)
# Jose Arredondo  (2008-2012)
# Jake Arrieta  (2010-2017)
# Gerry Arrigo  (1961-1970)
# Rolando Arrojo  (1998-2002)
# Bronson Arroyo  (2000-2017)
# Christian Arroyo  (2017-2017)
# Fernando Arroyo  (1975-1986)
# Luis Arroyo  (1955-1963)
# Rudy Arroyo  (1971-1971)
# Erisbel Arruebarrena  (2014-2014)
# Harry Arundel  (1875-1884)
# Tug Arundel  (1882-1888)
# Randy Asadoor  (1986-1986)
# Jim Asbell  (1938-1938)
# Casper Asbjornson  (1928-1932)
# Jose Ascanio  (2007-2011)
# Cody Asche  (2013-2017)
# Jairo Asencio  (2009-2013)
# Miguel Asencio  (2002-2006)
# Ken Ash  (1925-1930)
# Richie Ashburn+ (1948-1962)
# Alan Ashby  (1973-1989)
# Andy Ashby  (1991-2004)
# Alec Asher  (2015-2017)
# Tucker Ashford  (1976-1984)
# Billy Ashley  (1992-1998)
# Nevin Ashley  (2015-2015)
# Tom Asmussen  (1907-1907)
# Bob Aspromonte  (1956-1971)
# Ken Aspromonte  (1957-1963)
# Brian Asselstine  (1976-1981)
# Paul Assenmacher  (1986-1999)
# Ezequiel Astacio  (2005-2006)
# Pedro Astacio  (1992-2006)
# Barrett Astin  (2017-2017)
# Joe Astroth  (1945-1956)
# Carlos Asuaje  (2016-2016)
# Scott Atchison  (2004-2015)
# Justin Atchley  (2001-2001)
# Charlie Atherton  (1899-1899)
# Keith Atherton  (1983-1989)
# Luis Atilano  (2010-2010)
# Garrett Atkins  (2003-2010)
# James Atkins  (1950-1952)
# Mitch Atkins  (2009-2011)
# Tommy Atkins  (1909-1910)
# Al Atkinson  (1884-1887)
# Bill Atkinson  (1976-1979)
# Ed Atkinson  (1873-1873)
# Harry Atkinson  (1895-1895)
# Lefty Atkinson  (1927-1927)
# Dick Attreau  (1926-1927)
# Toby Atwell  (1952-1956)
# Bill Atwood  (1936-1940)
# Jake Atz  (1902-1909)
# Chub Aubrey  (1903-1903)
# Michael Aubrey  (2008-2009)
# Derek Aucoin  (1996-1996)
# Rich Aude  (1993-1996)
# Rick Auerbach  (1971-1981)
# Bryan Augenstein  (2009-2011)
# Don August  (1988-1991)
# Dave Augustine  (1973-1974)
# Jerry Augustine  (1975-1984)
# Elden Auker  (1933-1942)
# Tex Aulds  (1947-1947)
# Doug Ault  (1976-1980)
# Phillippe Aumont  (2012-2015)
# Rich Aurilia  (1995-2009)
# Joe Ausanio  (1994-1995)
# Brad Ausmus  (1993-2010)
# Dennis Aust  (1965-1966)
# Henry Austin  (1873-1873)
# Jeff Austin  (2001-2003)
# Jim Austin  (1991-1993)
# Jimmy Austin  (1909-1929)
# Rick Austin  (1970-1976)
# Tyler Austin  (2016-2016)
# Al Autry  (1976-1976)
# Chick Autry  (1907-1909)
# Chick Autry  (1924-1930)
# Bruce Aven  (1997-2002)
# Earl Averill+ (1929-1941)
# Earl Averill  (1956-1963)
# Steve Avery  (1990-2003)
# Xavier Avery  (2012-2012)
# Alex Avila  (2009-2017)
# Bobby Avila  (1949-1959)
# Luis Avilan  (2012-2017)
# Mike Aviles  (2008-2016)
# Ramon Aviles  (1977-1981)
# Jay Avrea  (1950-1950)
# Dylan Axelrod  (2011-2015)
# John Axford  (2009-2016)
# Benny Ayala  (1974-1985)
# Bobby Ayala  (1992-1999)
# Luis Ayala  (2003-2013)
# Erick Aybar  (2006-2017)
# Manny Aybar  (1997-2005)
# Willy Aybar  (2005-2010)
# Jake Aydelott  (1884-1886)
# Bill Ayers  (1947-1947)
# Doc Ayers  (1913-1921)
# Dick Aylward  (1953-1953)
# Bob Ayrault  (1992-1993)
# Joe Ayrault  (1996-1996)
# Joe Azcue  (1960-1972)
# Oscar Azocar  (1990-1992)
# Professional Baseball Register
# Other Personnel
# Managers Directory
# Bullpen Wiki with bios of many players, managers from MLB and beyond.
# Best Known Players
# Every Sports Reference Social Media Account
# All logos are the trademark & property of their owners and not Sports Reference LLC.  We present them here for purely educational purposes.
#         Our reasoning for presenting offensive logos.
# Logos were compiled by the amazing SportsLogos.net.
# Copyright © 2000-2017 Sports Reference LLC. All rights reserved.
# Much of the play-by-play, game results, and transaction information both shown and used to create certain data sets was obtained free of charge from and is copyrighted by RetroSheet.
# Win Expectancy, Run Expectancy, and Leverage Index calculations provided by Tom Tango of InsideTheBook.com, and co-author of The Book: Playing the Percentages in Baseball.
# Total Zone Rating and initial framework for Wins above Replacement calculations provided by Sean Smith.
# Full-year historical Major League statistics provided by Pete Palmer and Gary Gillette of Hidden Game Sports.
#
# Some defensive statistics Copyright © Baseball Info Solutions, 2010-2017.
# Some high school data is courtesy David McWater.
# Many historical player head shots courtesy of David Davis. Many thanks to him. All images are property the copyright holder and are displayed here for informational purposes only.

# %% [markdown]
# ### However, this return more text than just the player names, so we need an additional for loop
# ### to separate the player names.

# %%
player_list = []

#appends each string with a parenthesis to a new list,
for player in players:
    if "(" in player.text:
        player_list.append(player.text)

player_list[:10]
# Out:
# ['David Aardsma  (2004-2015)',
#  'Hank Aaron+ (1954-1976)',
#  'Tommie Aaron  (1962-1971)',
#  'Don Aase  (1977-1990)',
#  'Andy Abad  (2001-2006)',
#  'Fernando Abad  (2010-2017)',
#  'John Abadie  (1875-1875)',
#  'Ed Abbaticchio  (1897-1910)',
#  'Bert Abbey  (1892-1896)',
#  'Charlie Abbey  (1893-1897)']

# %% [markdown]
# ### Now that we've parsed the html to grab only what we need, we need to clean the data to make it easier to analyze.

# %%
#removes characters from the strings
new_player_list = []
for player in player_list:
    player = player.replace('(',"").replace(')',"").replace("-"," ").replace("  ", " ")
    new_player_list.append(player)

new_player_list
# Out:
# ['David Aardsma 2004 2015',
#  'Hank Aaron+ 1954 1976',
#  'Tommie Aaron 1962 1971',
#  'Don Aase 1977 1990',
#  'Andy Abad 2001 2006',
#  'Fernando Abad 2010 2017',
#  'John Abadie 1875 1875',
#  'Ed Abbaticchio 1897 1910',
#  'Bert Abbey 1892 1896',
#  'Charlie Abbey 1893 1897',
#  'Dan Abbott 1890 1890',
#  'Fred Abbott 1903 1905',
#  'Glenn Abbott 1973 1984',
#  'Jeff Abbott 1997 2001',
#  'Jim Abbott 1989 1999',
#  'Kurt Abbott 1993 2001',
#  'Kyle Abbott 1991 1996',
#  'Ody Abbott 1910 1910',
#  'Paul Abbott 1990 2004',
#  'Al Aber 1950 1957',
#  'Frank Abercrombie 1871 1871',
#  'Reggie Abercrombie 2006 2008',
#  'Bill Abernathie 1952 1952',
#  'Brent Abernathy 2001 2005',
#  'Ted Abernathy 1942 1944',
#  'Ted Abernathy 1955 1972',
#  'Woody Abernathy 1946 1947',
#  'Cliff Aberson 1947 1949',
#  'Harry Ables 1905 1911',
#  'Shawn Abner 1987 1992',
#  'Cal Abrams 1949 1956',
#  'George Abrams 1923 1923',
#  'Johnny Abrego 1985 1985',
#  'Bobby Abreu 1996 2014',
#  'Joe Abreu 1942 1942',
#  'Jose Abreu 2014 2017',
#  'Juan Abreu 2011 2011',
#  'Tony Abreu 2007 2014',
#  'Winston Abreu 2006 2009',
#  'Bill Abstein 1906 1910',
#  'Jeremy Accardo 2005 2012',
#  'Jose Acevedo 2001 2005',
#  'Juan Acevedo 1995 2003',
#  'Alfredo Aceves 2008 2014',
#  'A.J. Achter 2014 2016',
#  'Jim Acker 1983 1992',
#  'Tom Acker 1956 1959',
#  'Dustin Ackley 2011 2016',
#  'Fritz Ackley 1963 1964',
#  'Cy Acosta 1972 1975',
#  'Ed Acosta 1970 1972',
#  'Jose Acosta 1920 1922',
#  'Manny Acosta 2007 2012',
#  'Merito Acosta 1913 1918',
#  'Mark Acre 1994 1997',
#  'Jerry Adair 1958 1970',
#  'Jimmy Adair 1931 1931',
#  'Cristhian Adames 2014 2017',
#  'Ace Adams 1941 1946',
#  'Austin Adams 2014 2016',
#  'Babe Adams 1906 1926',
#  'Bert Adams 1910 1919',
#  'Bob Adams 1925 1925',
#  'Bob Adams 1931 1932',
#  'Bob Adams 1977 1977',
#  'Bobby Adams 1946 1959',
#  'Buster Adams 1939 1947',
#  'Dan Adams 1914 1915',
#  'David Adams 2013 2013',
#  'Dick Adams 1947 1947',
#  'Doug Adams 1969 1969',
#  'George Adams 1879 1879',
#  'Glenn Adams 1975 1982',
#  'Herb Adams 1948 1950',
#  'Jim Adams 1890 1890',
#  'Joe Adams 1902 1902',
#  'Karl Adams 1914 1915',
#  'Lane Adams 2014 2017',
#  'Matt Adams 2012 2017',
#  'Mike Adams 1972 1978',
#  'Mike Adams 2004 2014',
#  'Red Adams 1946 1946',
#  'Rick Adams 1905 1905',
#  'Ricky Adams 1982 1985',
#  'Russ Adams 2004 2009',
#  'Ryan Adams 2011 2011',
#  'Sparky Adams 1922 1934',
#  'Spencer Adams 1923 1927',
#  'Terry Adams 1995 2005',
#  'Willie Adams 1912 1919',
#  'Willie Adams 1996 1997',
#  'Joel Adamson 1996 1998',
#  'Mike Adamson 1967 1969',
#  'Joe Adcock 1950 1966',
#  'Nathan Adcock 2011 2015',
#  'Bob Addis 1950 1953',
#  'Jim Adduci 1983 1989',
#  'Jim Adduci 2013 2017',
#  'Bob Addy 1871 1877',
#  'Nick Adenhart 2008 2009',
#  'Morrie Aderholt 1939 1945',
#  'Dewey Adkins 1942 1949',
#  'Dick Adkins 1942 1942',
#  'Doc Adkins 1902 1903',
#  'Grady Adkins 1928 1929',
#  'Jon Adkins 2003 2008',
#  'Steve Adkins 1990 1990',
#  'Tim Adleman 2016 2017',
#  'Dave Adlesh 1963 1968',
#  'Ehire Adrianza 2013 2016',
#  'Troy Afenir 1987 1992',
#  'Jeremy Affeldt 2002 2015',
#  'Benny Agbayani 1998 2002',
#  'Tommie Agee 1962 1973',
#  'Harry Agganis 1954 1955',
#  'Joe Agler 1912 1915',
#  'Sam Agnew 1913 1919',
#  'Juan Agosto 1981 1993',
#  'Luis Aguayo 1980 1989',
#  'Chris Aguila 2004 2008',
#  'Jesus Aguilar 2014 2017',
#  'Rick Aguilera 1985 2000',
#  'Hank Aguirre 1955 1970',
#  'Bill Ahearn 1880 1880',
#  'Pat Ahearne 1995 1995',
#  'Nick Ahmed 2014 2017',
#  'Willie Aikens 1977 1985',
#  'Danny Ainge 1979 1981',
#  'Eddie Ainsmith 1910 1924',
#  'Kurt Ainsworth 2001 2004',
#  'Raleigh Aitchison 1911 1915',
#  'George Aiton 1912 1912',
#  'John Ake 1884 1884',
#  'Jack Aker 1964 1974',
#  'Darrel Akerfelds 1986 1991',
#  'Bill Akers 1929 1932',
#  'Jerry Akers 1912 1912',
#  'Gibson Alba 1988 1988',
#  'Jonathan Albaladejo 2007 2012',
#  'Joe Albanese 1958 1958',
#  'Jose Alberro 1995 1997',
#  'Andrew Albers 2013 2016',
#  'Matt Albers 2006 2017',
#  'Hanser Alberto 2015 2016',
#  'Butch Alberts 1978 1978',
#  'Cy Alberts 1910 1910',
#  'Gus Alberts 1884 1891',
#  'Ed Albosta 1941 1946',
#  'Ed Albrecht 1949 1950',
#  'Jack Albright 1947 1947',
#  'Al Alburquerque 2011 2016',
#  'Vic Albury 1973 1976',
#  'Santo Alcala 1976 1977',
#  'Arismendy Alcantara 2014 2017',
#  'Israel Alcantara 2000 2002',
#  'Raul Alcantara 2016 2017',
#  'Luis Alcaraz 1967 1970',
#  'Scotty Alcock 1914 1914',
#  'Dale Alderson 1943 1944',
#  'Scott Aldred 1990 2000',
#  'Mike Aldrete 1986 1996',
#  'Jay Aldrich 1987 1990',
#  'Cory Aldridge 2001 2010',
#  'Vic Aldridge 1917 1928',
#  'Chuck Aleno 1941 1944',
#  'Bob Alexander 1955 1957',
#  'Dale Alexander 1929 1933',
#  'Doyle Alexander 1971 1989',
#  'Gary Alexander 1975 1981',
#  'Gerald Alexander 1990 1992',
#  'Hugh Alexander 1937 1937',
#  'Manny Alexander 1992 2006',
#  'Matt Alexander 1973 1981',
#  'Nin Alexander 1884 1884',
#  'Pete Alexander+ 1911 1930',
#  'Scott Alexander 2015 2017',
#  'Walt Alexander 1912 1917',
#  'Jason Alfaro 2004 2004',
#  'Jorge Alfaro 2016 2016',
#  'Antonio Alfonseca 1997 2007',
#  'Edgardo Alfonzo 1995 2006',
#  'Eliezer Alfonzo 2006 2011',
#  'Luis Alicea 1988 2002',
#  'Andy Allanson 1986 1995',
#  'Brian Allard 1979 1981',
#  'Bernie Allen 1962 1973',
#  'Bob Allen 1890 1900',
#  'Bob Allen 1919 1919',
#  'Bob Allen 1937 1937',
#  'Bob Allen 1961 1967',
#  'Brandon Allen 2009 2012',
#  'Chad Allen 1999 2005',
#  'Cody Allen 2012 2017',
#  'Dick Allen 1963 1977',
#  'Dusty Allen 2000 2000',
#  'Ethan Allen 1926 1938',
#  'Frank Allen 1912 1917',
#  'Ham Allen 1872 1872',
#  'Hank Allen 1966 1973',
#  'Hezekiah Allen 1884 1884',
#  'Horace Allen 1919 1919',
#  'Jack Allen 1879 1879',
#  'Jamie Allen 1983 1983',
#  'John Allen 1914 1914',
#  'Johnny Allen 1932 1944',
#  'Kim Allen 1980 1981',
#  'Lloyd Allen 1969 1975',
#  'Luke Allen 2002 2003',
#  'Myron Allen 1883 1888',
#  'Neil Allen 1979 1989',
#  'Nick Allen 1914 1920',
#  'Pete Allen 1893 1893',
#  'Rod Allen 1983 1988',
#  'Ron Allen 1972 1972',
#  'Sled Allen 1910 1910',
#  'Gary Allenson 1979 1985',
#  'Jermaine Allensworth 1996 1999',
#  'Gene Alley 1963 1973',
#  'Gair Allie 1954 1954',
#  'Bob Allietta 1975 1975',
#  'Andy Allison 1872 1872',
#  'Art Allison 1871 1876',
#  'Bill Allison 1872 1872',
#  'Bob Allison 1958 1970',
#  'Dana Allison 1991 1991',
#  'Doug Allison 1871 1883',
#  'Mack Allison 1911 1913',
#  'Milo Allison 1913 1917',
#  'Beau Allred 1989 1991',
#  'Mel Almada 1933 1939',
#  'Armando Almanza 1999 2005',
#  'Carlos Almanzar 1997 2005',
#  'Rafael Almeida 1911 1913',
#  'Bill Almon 1974 1988',
#  'Abraham Almonte 2013 2017',
#  'Edwin Almonte 2003 2003',
#  'Erick Almonte 2001 2011',
#  'Hector Almonte 1999 2003',
#  'Miguel Almonte 2015 2015',
#  'Zoilo Almonte 2013 2014',
#  'Albert Almora 2016 2017',
#  'Luis Aloma 1950 1953',
#  'Roberto Alomar+ 1988 2004',
#  'Sandy Alomar 1964 1978',
#  'Sandy Alomar 1988 2007',
#  'Yonder Alonso 2010 2017',
#  'Felipe Alou 1958 1974',
#  'Jesus Alou 1963 1979',
#  'Matty Alou 1960 1974',
#  'Moises Alou 1990 2008',
#  'Whitey Alpermann 1906 1909',
#  'Dell Alston 1977 1980',
#  'Garvin Alston 1996 1996',
#  'Tom Alston 1954 1957',
#  'Walter Alston+ 1936 1936',
#  'Porfi Altamirano 1982 1984',
#  'Dan Altavilla 2016 2017',
#  'Ernie Alten 1920 1920',
#  'Jesse Altenburg 1916 1917',
#  'Aaron Altherr 2014 2017',
#  'Dave Altizer 1906 1911',
#  'George Altman 1959 1967',
#  'Joe Altobelli 1955 1961',
#  'Nick Altrock 1898 1933',
#  'Jose Altuve 2011 2017',
#  'George Alusik 1958 1964',
#  'Luis Alvarado 1968 1977',
#  'Abe Alvarez 2004 2006',
#  'Clemente Alvarez 2000 2000',
#  'Dariel Alvarez 2015 2016',
#  'Dario Alvarez 2014 2017',
#  'Gabe Alvarez 1998 2000',
#  'Henderson Alvarez 2011 2015',
#  'Jose Alvarez 1981 1989',
#  'Jose Alvarez 2013 2017',
#  'Juan Alvarez 1999 2003',
#  'Orlando Alvarez 1973 1976',
#  'Ossie Alvarez 1958 1959',
#  'Pedro Alvarez 2010 2016',
#  'R.J. Alvarez 2014 2015',
#  'Rogelio Alvarez 1960 1962',
#  'Tavo Alvarez 1995 1996',
#  'Tony Alvarez 2002 2004',
#  'Victor Alvarez 2002 2003',
#  'Wilson Alvarez 1989 2005',
#  'Max Alvis 1962 1970',
#  'Billy Alvord 1885 1893',
#  'Brant Alyea 1965 1972',
#  'Joey Amalfitano 1954 1967',
#  'Rich Amaral 1991 2000',
#  'Alexi Amarista 2011 2017',
#  'Ruben Amaro 1958 1969',
#  'Ruben Amaro 1991 1998',
#  'Wayne Ambler 1937 1939',
#  'Chip Ambres 2005 2008',
#  'Hector Ambriz 2010 2014',
#  'Ed Amelung 1984 1986',
#  'Red Ames 1903 1919',
#  'Steve Ames 2013 2013',
#  'Alfredo Amezaga 2002 2011',
#  'Doc Amole 1897 1898',
#  'Vicente Amor 1955 1957',
#  'Sandy Amoros 1952 1960',
#  'Walter Ancker 1915 1915',
#  'Larry Andersen 1975 1994',
#  'Alf Anderson 1941 1946',
#  'Allan Anderson 1986 1991',
#  'Andy Anderson 1948 1949',
#  'Bill Anderson 1889 1889',
#  'Bill Anderson 1925 1925',
#  'Bob Anderson 1957 1963',
#  'Brady Anderson 1988 2002',
#  'Brett Anderson 2009 2017',
#  'Brian Anderson 1993 2005',
#  'Brian Anderson 2005 2009',
#  'Bryan Anderson 2010 2015',
#  'Bud Anderson 1982 1983',
#  'Chase Anderson 2014 2017',
#  'Cody Anderson 2015 2016',
#  'Craig Anderson 1961 1964',
#  'Dave Anderson 1889 1890',
#  'Dave Anderson 1983 1992',
#  'Drew Anderson 2006 2006',
#  'Dwain Anderson 1971 1974',
#  'Ferrell Anderson 1946 1953',
#  'Fred Anderson 1909 1918',
#  'Garret Anderson 1994 2010',
#  'George Anderson 1914 1918',
#  'Goat Anderson 1907 1907',
#  'Hal Anderson 1932 1932',
#  'Harry Anderson 1957 1961',
#  'Jason Anderson 2003 2005',
#  'Jim Anderson 1978 1984',
#  'Jimmy Anderson 1999 2004',
#  'John Anderson 1894 1908',
#  'John Anderson 1958 1962',
#  'Josh Anderson 2007 2009',
#  'Kent Anderson 1989 1990',
#  'Larry Anderson 1974 1977',
#  'Lars Anderson 2010 2012',
#  'Marlon Anderson 1998 2009',
#  'Matt Anderson 1998 2005',
#  'Mike Anderson 1971 1979',
#  'Mike Anderson 1993 1993',
#  'Red Anderson 1937 1941',
#  'Rick Anderson 1979 1980',
#  'Rick Anderson 1986 1988',
#  'Scott Anderson 1987 1995',
#  'Sparky Anderson+ 1959 1959',
#  'Tim Anderson 2016 2017',
#  'Tyler Anderson 2016 2017',
#  'Varney Anderson 1889 1896',
#  'Walter Anderson 1917 1919',
#  'Wingo Anderson 1910 1910',
#  'Robert Andino 2005 2016',
#  'Steve Andrade 2006 2006',
#  'John Andre 1955 1955',
#  'Ernie Andres 1946 1946',
#  'Kim Andrew 1975 1975',
#  'Clayton Andrews 2000 2000',
#  'Ed Andrews 1884 1891',
#  'Elbert Andrews 1925 1925',
#  'Fred Andrews 1976 1977',
#  'Hub Andrews 1947 1948',
#  'Ivy Andrews 1931 1938',
#  'Jim Andrews 1890 1890',
#  'John Andrews 1973 1973',
#  'Mike Andrews 1966 1973',
#  'Nate Andrews 1937 1946',
#  'Rob Andrews 1975 1979',
#  'Shane Andrews 1995 2002',
#  'Stan Andrews 1939 1945',
#  'Wally Andrews 1884 1888',
#  'Matt Andriese 2015 2017',
#  'Bill Andrus 1931 1937',
#  'Elvis Andrus 2009 2017',
#  'Fred Andrus 1876 1884',
#  'Wyman Andrus 1885 1885',
#  'Joaquin Andujar 1976 1988',
#  'Luis Andujar 1995 1998',
#  'Norm Angelini 1972 1973',
#  'Matt Angle 2011 2011',
#  'Tom Angley 1929 1929',
#  'Pat Ankenman 1936 1944',
#  'Rick Ankiel 1999 2013',
#  'Dean Anna 2014 2015',
#  'Bill Annis 1884 1884',
#  'Cap Anson+ 1871 1897',
#  'Eric Anthony 1989 1997',
#  'Joe Antolick 1944 1944',
#  'Dustin Antolin 2016 2016',
#  'John Antonelli 1944 1945',
#  'Johnny Antonelli 1948 1961',
#  'Matt Antonelli 2008 2008',
#  'Bill Antonello 1953 1953',
#  'Norichika Aoki 2012 2017',
#  'Luis Aparicio+ 1956 1973',
#  'Bob Apodaca 1973 1977',
#  'Luis Aponte 1980 1984',
#  'Kevin Appier 1989 2004',
#  'Fred Applegate 1904 1904',
#  'Ed Appleton 1915 1916',
#  'Pete Appleton 1927 1945',
#  'Luke Appling+ 1930 1950',
#  'Greg Aquino 2004 2009',
#  'Jayson Aquino 2016 2017',
#  'Luis Aquino 1986 1995',
#  'Angel Aragon 1914 1917',
#  'Jack Aragon 1941 1941',
#  'Elvis Araujo 2015 2016',
#  'Maurice Archdeacon 1923 1925',
#  'Chris Archer 2012 2017',
#  'Fred Archer 1936 1937',
#  'Jim Archer 1961 1962',
#  'Jimmy Archer 1904 1918',
#  'George Archie 1938 1946',
#  'Jose Arcia 1968 1970',
#  'Orlando Arcia 2016 2017',
#  'Oswaldo Arcia 2013 2016',
#  'Dan Ardell 1961 1961',
#  'Rugger Ardizoia 1947 1947',
#  'Joe Ardner 1884 1890',
#  'Danny Ardoin 2000 2008',
#  'Frank Arellanes 1908 1910',
#  'Nolan Arenado 2013 2017',
#  'J.P. Arencibia 2010 2015',
#  'Hank Arft 1948 1952',
#  'Alberto Arias 2007 2009',
#  'Alex Arias 1992 2002',
#  'George Arias 1996 1999',
#  'Joaquin Arias 2006 2015',
#  'Rudy Arias 1959 1959',
#  'Buzz Arlett 1931 1931',
#  'Don Arlich 1965 1966',
#  'Steve Arlin 1969 1974',
#  'Marcos Armas 1993 1993',
#  'Tony Armas 1976 1989',
#  'Tony Armas 1999 2008',
#  'Ed Armbrister 1973 1977',
#  'Orville Armbrust 1934 1934',
#  'Charlie Armbruster 1905 1907',
#  'Harry Armbruster 1906 1906',
#  'George Armstrong 1946 1946',
#  'Howard Armstrong 1911 1911',
#  'Jack Armstrong 1988 1994',
#  'Mike Armstrong 1980 1987',
#  'Robert Armstrong 1871 1871',
#  'Shawn Armstrong 2015 2017',
#  'Harry Arndt 1902 1907',
#  'Larry Arndt 1989 1989',
#  'Billy Arnold 1872 1872',
#  'Chris Arnold 1971 1976',
#  'Jamie Arnold 1999 2000',
#  'Scott Arnold 1988 1988',
#  'Tony Arnold 1986 1987',
#  'Morrie Arnovich 1936 1946',
#  'Brad Arnsberg 1986 1992',
#  'Orie Arntzen 1943 1943',
#  'Jonathan Aro 2015 2016',
#  'Rene Arocha 1993 1997',
#  'Jose Arredondo 2008 2012',
#  'Jake Arrieta 2010 2017',
#  'Gerry Arrigo 1961 1970',
#  'Rolando Arrojo 1998 2002',
#  'Bronson Arroyo 2000 2017',
#  'Christian Arroyo 2017 2017',
#  'Fernando Arroyo 1975 1986',
#  'Luis Arroyo 1955 1963',
#  'Rudy Arroyo 1971 1971',
#  'Erisbel Arruebarrena 2014 2014',
#  'Harry Arundel 1875 1884',
#  'Tug Arundel 1882 1888',
#  'Randy Asadoor 1986 1986',
#  'Jim Asbell 1938 1938',
#  'Casper Asbjornson 1928 1932',
#  'Jose Ascanio 2007 2011',
#  'Cody Asche 2013 2017',
#  'Jairo Asencio 2009 2013',
#  'Miguel Asencio 2002 2006',
#  'Ken Ash 1925 1930',
#  'Richie Ashburn+ 1948 1962',
#  'Alan Ashby 1973 1989',
#  'Andy Ashby 1991 2004',
#  'Alec Asher 2015 2017',
#  'Tucker Ashford 1976 1984',
#  'Billy Ashley 1992 1998',
#  'Nevin Ashley 2015 2015',
#  'Tom Asmussen 1907 1907',
#  'Bob Aspromonte 1956 1971',
#  'Ken Aspromonte 1957 1963',
#  'Brian Asselstine 1976 1981',
#  'Paul Assenmacher 1986 1999',
#  'Ezequiel Astacio 2005 2006',
#  'Pedro Astacio 1992 2006',
#  'Barrett Astin 2017 2017',
#  'Joe Astroth 1945 1956',
#  'Carlos Asuaje 2016 2016',
#  'Scott Atchison 2004 2015',
#  'Justin Atchley 2001 2001',
#  'Charlie Atherton 1899 1899',
#  'Keith Atherton 1983 1989',
#  'Luis Atilano 2010 2010',
#  'Garrett Atkins 2003 2010',
#  'James Atkins 1950 1952',
#  'Mitch Atkins 2009 2011',
#  'Tommy Atkins 1909 1910',
#  'Al Atkinson 1884 1887',
#  'Bill Atkinson 1976 1979',
#  'Ed Atkinson 1873 1873',
#  'Harry Atkinson 1895 1895',
#  'Lefty Atkinson 1927 1927',
#  'Dick Attreau 1926 1927',
#  'Toby Atwell 1952 1956',
#  'Bill Atwood 1936 1940',
#  'Jake Atz 1902 1909',
#  'Chub Aubrey 1903 1903',
#  'Michael Aubrey 2008 2009',
#  'Derek Aucoin 1996 1996',
#  'Rich Aude 1993 1996',
#  'Rick Auerbach 1971 1981',
#  'Bryan Augenstein 2009 2011',
#  'Don August 1988 1991',
#  'Dave Augustine 1973 1974',
#  'Jerry Augustine 1975 1984',
#  'Elden Auker 1933 1942',
#  'Tex Aulds 1947 1947',
#  'Doug Ault 1976 1980',
#  'Phillippe Aumont 2012 2015',
#  'Rich Aurilia 1995 2009',
#  'Joe Ausanio 1994 1995',
#  'Brad Ausmus 1993 2010',
#  'Dennis Aust 1965 1966',
#  'Henry Austin 1873 1873',
#  'Jeff Austin 2001 2003',
#  'Jim Austin 1991 1993',
#  'Jimmy Austin 1909 1929',
#  'Rick Austin 1970 1976',
#  'Tyler Austin 2016 2016',
#  'Al Autry 1976 1976',
#  'Chick Autry 1907 1909',
#  'Chick Autry 1924 1930',
#  'Bruce Aven 1997 2002',
#  'Earl Averill+ 1929 1941',
#  'Earl Averill 1956 1963',
#  'Steve Avery 1990 2003',
#  'Xavier Avery 2012 2012',
#  'Alex Avila 2009 2017',
#  'Bobby Avila 1949 1959',
#  'Luis Avilan 2012 2017',
#  'Mike Aviles 2008 2016',
#  'Ramon Aviles 1977 1981',
#  'Jay Avrea 1950 1950',
#  'Dylan Axelrod 2011 2015',
#  'John Axford 2009 2016',
#  'Benny Ayala 1974 1985',
#  'Bobby Ayala 1992 1999',
#  'Luis Ayala 2003 2013',
#  'Erick Aybar 2006 2017',
#  'Manny Aybar 1997 2005',
#  'Willy Aybar 2005 2010',
#  'Jake Aydelott 1884 1886',
#  'Bill Ayers 1947 1947',
#  'Doc Ayers 1913 1921',
#  'Dick Aylward 1953 1953',
#  'Bob Ayrault 1992 1993',
#  'Joe Ayrault 1996 1996',
#  'Joe Azcue 1960 1972',
#  'Oscar Azocar 1990 1992']

# %%
split_player_list = []
for player in new_player_list:
    split_player_list.append(player.split(" "))
    
split_player_list
# Out:
# [['David', 'Aardsma', '2004', '2015'],
#  ['Hank', 'Aaron+', '1954', '1976'],
#  ['Tommie', 'Aaron', '1962', '1971'],
#  ['Don', 'Aase', '1977', '1990'],
#  ['Andy', 'Abad', '2001', '2006'],
#  ['Fernando', 'Abad', '2010', '2017'],
#  ['John', 'Abadie', '1875', '1875'],
#  ['Ed', 'Abbaticchio', '1897', '1910'],
#  ['Bert', 'Abbey', '1892', '1896'],
#  ['Charlie', 'Abbey', '1893', '1897'],
#  ['Dan', 'Abbott', '1890', '1890'],
#  ['Fred', 'Abbott', '1903', '1905'],
#  ['Glenn', 'Abbott', '1973', '1984'],
#  ['Jeff', 'Abbott', '1997', '2001'],
#  ['Jim', 'Abbott', '1989', '1999'],
#  ['Kurt', 'Abbott', '1993', '2001'],
#  ['Kyle', 'Abbott', '1991', '1996'],
#  ['Ody', 'Abbott', '1910', '1910'],
#  ['Paul', 'Abbott', '1990', '2004'],
#  ['Al', 'Aber', '1950', '1957'],
#  ['Frank', 'Abercrombie', '1871', '1871'],
#  ['Reggie', 'Abercrombie', '2006', '2008'],
#  ['Bill', 'Abernathie', '1952', '1952'],
#  ['Brent', 'Abernathy', '2001', '2005'],
#  ['Ted', 'Abernathy', '1942', '1944'],
#  ['Ted', 'Abernathy', '1955', '1972'],
#  ['Woody', 'Abernathy', '1946', '1947'],
#  ['Cliff', 'Aberson', '1947', '1949'],
#  ['Harry', 'Ables', '1905', '1911'],
#  ['Shawn', 'Abner', '1987', '1992'],
#  ['Cal', 'Abrams', '1949', '1956'],
#  ['George', 'Abrams', '1923', '1923'],
#  ['Johnny', 'Abrego', '1985', '1985'],
#  ['Bobby', 'Abreu', '1996', '2014'],
#  ['Joe', 'Abreu', '1942', '1942'],
#  ['Jose', 'Abreu', '2014', '2017'],
#  ['Juan', 'Abreu', '2011', '2011'],
#  ['Tony', 'Abreu', '2007', '2014'],
#  ['Winston', 'Abreu', '2006', '2009'],
#  ['Bill', 'Abstein', '1906', '1910'],
#  ['Jeremy', 'Accardo', '2005', '2012'],
#  ['Jose', 'Acevedo', '2001', '2005'],
#  ['Juan', 'Acevedo', '1995', '2003'],
#  ['Alfredo', 'Aceves', '2008', '2014'],
#  ['A.J.', 'Achter', '2014', '2016'],
#  ['Jim', 'Acker', '1983', '1992'],
#  ['Tom', 'Acker', '1956', '1959'],
#  ['Dustin', 'Ackley', '2011', '2016'],
#  ['Fritz', 'Ackley', '1963', '1964'],
#  ['Cy', 'Acosta', '1972', '1975'],
#  ['Ed', 'Acosta', '1970', '1972'],
#  ['Jose', 'Acosta', '1920', '1922'],
#  ['Manny', 'Acosta', '2007', '2012'],
#  ['Merito', 'Acosta', '1913', '1918'],
#  ['Mark', 'Acre', '1994', '1997'],
#  ['Jerry', 'Adair', '1958', '1970'],
#  ['Jimmy', 'Adair', '1931', '1931'],
#  ['Cristhian', 'Adames', '2014', '2017'],
#  ['Ace', 'Adams', '1941', '1946'],
#  ['Austin', 'Adams', '2014', '2016'],
#  ['Babe', 'Adams', '1906', '1926'],
#  ['Bert', 'Adams', '1910', '1919'],
#  ['Bob', 'Adams', '1925', '1925'],
#  ['Bob', 'Adams', '1931', '1932'],
#  ['Bob', 'Adams', '1977', '1977'],
#  ['Bobby', 'Adams', '1946', '1959'],
#  ['Buster', 'Adams', '1939', '1947'],
#  ['Dan', 'Adams', '1914', '1915'],
#  ['David', 'Adams', '2013', '2013'],
#  ['Dick', 'Adams', '1947', '1947'],
#  ['Doug', 'Adams', '1969', '1969'],
#  ['George', 'Adams', '1879', '1879'],
#  ['Glenn', 'Adams', '1975', '1982'],
#  ['Herb', 'Adams', '1948', '1950'],
#  ['Jim', 'Adams', '1890', '1890'],
#  ['Joe', 'Adams', '1902', '1902'],
#  ['Karl', 'Adams', '1914', '1915'],
#  ['Lane', 'Adams', '2014', '2017'],
#  ['Matt', 'Adams', '2012', '2017'],
#  ['Mike', 'Adams', '1972', '1978'],
#  ['Mike', 'Adams', '2004', '2014'],
#  ['Red', 'Adams', '1946', '1946'],
#  ['Rick', 'Adams', '1905', '1905'],
#  ['Ricky', 'Adams', '1982', '1985'],
#  ['Russ', 'Adams', '2004', '2009'],
#  ['Ryan', 'Adams', '2011', '2011'],
#  ['Sparky', 'Adams', '1922', '1934'],
#  ['Spencer', 'Adams', '1923', '1927'],
#  ['Terry', 'Adams', '1995', '2005'],
#  ['Willie', 'Adams', '1912', '1919'],
#  ['Willie', 'Adams', '1996', '1997'],
#  ['Joel', 'Adamson', '1996', '1998'],
#  ['Mike', 'Adamson', '1967', '1969'],
#  ['Joe', 'Adcock', '1950', '1966'],
#  ['Nathan', 'Adcock', '2011', '2015'],
#  ['Bob', 'Addis', '1950', '1953'],
#  ['Jim', 'Adduci', '1983', '1989'],
#  ['Jim', 'Adduci', '2013', '2017'],
#  ['Bob', 'Addy', '1871', '1877'],
#  ['Nick', 'Adenhart', '2008', '2009'],
#  ['Morrie', 'Aderholt', '1939', '1945'],
#  ['Dewey', 'Adkins', '1942', '1949'],
#  ['Dick', 'Adkins', '1942', '1942'],
#  ['Doc', 'Adkins', '1902', '1903'],
#  ['Grady', 'Adkins', '1928', '1929'],
#  ['Jon', 'Adkins', '2003', '2008'],
#  ['Steve', 'Adkins', '1990', '1990'],
#  ['Tim', 'Adleman', '2016', '2017'],
#  ['Dave', 'Adlesh', '1963', '1968'],
#  ['Ehire', 'Adrianza', '2013', '2016'],
#  ['Troy', 'Afenir', '1987', '1992'],
#  ['Jeremy', 'Affeldt', '2002', '2015'],
#  ['Benny', 'Agbayani', '1998', '2002'],
#  ['Tommie', 'Agee', '1962', '1973'],
#  ['Harry', 'Agganis', '1954', '1955'],
#  ['Joe', 'Agler', '1912', '1915'],
#  ['Sam', 'Agnew', '1913', '1919'],
#  ['Juan', 'Agosto', '1981', '1993'],
#  ['Luis', 'Aguayo', '1980', '1989'],
#  ['Chris', 'Aguila', '2004', '2008'],
#  ['Jesus', 'Aguilar', '2014', '2017'],
#  ['Rick', 'Aguilera', '1985', '2000'],
#  ['Hank', 'Aguirre', '1955', '1970'],
#  ['Bill', 'Ahearn', '1880', '1880'],
#  ['Pat', 'Ahearne', '1995', '1995'],
#  ['Nick', 'Ahmed', '2014', '2017'],
#  ['Willie', 'Aikens', '1977', '1985'],
#  ['Danny', 'Ainge', '1979', '1981'],
#  ['Eddie', 'Ainsmith', '1910', '1924'],
#  ['Kurt', 'Ainsworth', '2001', '2004'],
#  ['Raleigh', 'Aitchison', '1911', '1915'],
#  ['George', 'Aiton', '1912', '1912'],
#  ['John', 'Ake', '1884', '1884'],
#  ['Jack', 'Aker', '1964', '1974'],
#  ['Darrel', 'Akerfelds', '1986', '1991'],
#  ['Bill', 'Akers', '1929', '1932'],
#  ['Jerry', 'Akers', '1912', '1912'],
#  ['Gibson', 'Alba', '1988', '1988'],
#  ['Jonathan', 'Albaladejo', '2007', '2012'],
#  ['Joe', 'Albanese', '1958', '1958'],
#  ['Jose', 'Alberro', '1995', '1997'],
#  ['Andrew', 'Albers', '2013', '2016'],
#  ['Matt', 'Albers', '2006', '2017'],
#  ['Hanser', 'Alberto', '2015', '2016'],
#  ['Butch', 'Alberts', '1978', '1978'],
#  ['Cy', 'Alberts', '1910', '1910'],
#  ['Gus', 'Alberts', '1884', '1891'],
#  ['Ed', 'Albosta', '1941', '1946'],
#  ['Ed', 'Albrecht', '1949', '1950'],
#  ['Jack', 'Albright', '1947', '1947'],
#  ['Al', 'Alburquerque', '2011', '2016'],
#  ['Vic', 'Albury', '1973', '1976'],
#  ['Santo', 'Alcala', '1976', '1977'],
#  ['Arismendy', 'Alcantara', '2014', '2017'],
#  ['Israel', 'Alcantara', '2000', '2002'],
#  ['Raul', 'Alcantara', '2016', '2017'],
#  ['Luis', 'Alcaraz', '1967', '1970'],
#  ['Scotty', 'Alcock', '1914', '1914'],
#  ['Dale', 'Alderson', '1943', '1944'],
#  ['Scott', 'Aldred', '1990', '2000'],
#  ['Mike', 'Aldrete', '1986', '1996'],
#  ['Jay', 'Aldrich', '1987', '1990'],
#  ['Cory', 'Aldridge', '2001', '2010'],
#  ['Vic', 'Aldridge', '1917', '1928'],
#  ['Chuck', 'Aleno', '1941', '1944'],
#  ['Bob', 'Alexander', '1955', '1957'],
#  ['Dale', 'Alexander', '1929', '1933'],
#  ['Doyle', 'Alexander', '1971', '1989'],
#  ['Gary', 'Alexander', '1975', '1981'],
#  ['Gerald', 'Alexander', '1990', '1992'],
#  ['Hugh', 'Alexander', '1937', '1937'],
#  ['Manny', 'Alexander', '1992', '2006'],
#  ['Matt', 'Alexander', '1973', '1981'],
#  ['Nin', 'Alexander', '1884', '1884'],
#  ['Pete', 'Alexander+', '1911', '1930'],
#  ['Scott', 'Alexander', '2015', '2017'],
#  ['Walt', 'Alexander', '1912', '1917'],
#  ['Jason', 'Alfaro', '2004', '2004'],
#  ['Jorge', 'Alfaro', '2016', '2016'],
#  ['Antonio', 'Alfonseca', '1997', '2007'],
#  ['Edgardo', 'Alfonzo', '1995', '2006'],
#  ['Eliezer', 'Alfonzo', '2006', '2011'],
#  ['Luis', 'Alicea', '1988', '2002'],
#  ['Andy', 'Allanson', '1986', '1995'],
#  ['Brian', 'Allard', '1979', '1981'],
#  ['Bernie', 'Allen', '1962', '1973'],
#  ['Bob', 'Allen', '1890', '1900'],
#  ['Bob', 'Allen', '1919', '1919'],
#  ['Bob', 'Allen', '1937', '1937'],
#  ['Bob', 'Allen', '1961', '1967'],
#  ['Brandon', 'Allen', '2009', '2012'],
#  ['Chad', 'Allen', '1999', '2005'],
#  ['Cody', 'Allen', '2012', '2017'],
#  ['Dick', 'Allen', '1963', '1977'],
#  ['Dusty', 'Allen', '2000', '2000'],
#  ['Ethan', 'Allen', '1926', '1938'],
#  ['Frank', 'Allen', '1912', '1917'],
#  ['Ham', 'Allen', '1872', '1872'],
#  ['Hank', 'Allen', '1966', '1973'],
#  ['Hezekiah', 'Allen', '1884', '1884'],
#  ['Horace', 'Allen', '1919', '1919'],
#  ['Jack', 'Allen', '1879', '1879'],
#  ['Jamie', 'Allen', '1983', '1983'],
#  ['John', 'Allen', '1914', '1914'],
#  ['Johnny', 'Allen', '1932', '1944'],
#  ['Kim', 'Allen', '1980', '1981'],
#  ['Lloyd', 'Allen', '1969', '1975'],
#  ['Luke', 'Allen', '2002', '2003'],
#  ['Myron', 'Allen', '1883', '1888'],
#  ['Neil', 'Allen', '1979', '1989'],
#  ['Nick', 'Allen', '1914', '1920'],
#  ['Pete', 'Allen', '1893', '1893'],
#  ['Rod', 'Allen', '1983', '1988'],
#  ['Ron', 'Allen', '1972', '1972'],
#  ['Sled', 'Allen', '1910', '1910'],
#  ['Gary', 'Allenson', '1979', '1985'],
#  ['Jermaine', 'Allensworth', '1996', '1999'],
#  ['Gene', 'Alley', '1963', '1973'],
#  ['Gair', 'Allie', '1954', '1954'],
#  ['Bob', 'Allietta', '1975', '1975'],
#  ['Andy', 'Allison', '1872', '1872'],
#  ['Art', 'Allison', '1871', '1876'],
#  ['Bill', 'Allison', '1872', '1872'],
#  ['Bob', 'Allison', '1958', '1970'],
#  ['Dana', 'Allison', '1991', '1991'],
#  ['Doug', 'Allison', '1871', '1883'],
#  ['Mack', 'Allison', '1911', '1913'],
#  ['Milo', 'Allison', '1913', '1917'],
#  ['Beau', 'Allred', '1989', '1991'],
#  ['Mel', 'Almada', '1933', '1939'],
#  ['Armando', 'Almanza', '1999', '2005'],
#  ['Carlos', 'Almanzar', '1997', '2005'],
#  ['Rafael', 'Almeida', '1911', '1913'],
#  ['Bill', 'Almon', '1974', '1988'],
#  ['Abraham', 'Almonte', '2013', '2017'],
#  ['Edwin', 'Almonte', '2003', '2003'],
#  ['Erick', 'Almonte', '2001', '2011'],
#  ['Hector', 'Almonte', '1999', '2003'],
#  ['Miguel', 'Almonte', '2015', '2015'],
#  ['Zoilo', 'Almonte', '2013', '2014'],
#  ['Albert', 'Almora', '2016', '2017'],
#  ['Luis', 'Aloma', '1950', '1953'],
#  ['Roberto', 'Alomar+', '1988', '2004'],
#  ['Sandy', 'Alomar', '1964', '1978'],
#  ['Sandy', 'Alomar', '1988', '2007'],
#  ['Yonder', 'Alonso', '2010', '2017'],
#  ['Felipe', 'Alou', '1958', '1974'],
#  ['Jesus', 'Alou', '1963', '1979'],
#  ['Matty', 'Alou', '1960', '1974'],
#  ['Moises', 'Alou', '1990', '2008'],
#  ['Whitey', 'Alpermann', '1906', '1909'],
#  ['Dell', 'Alston', '1977', '1980'],
#  ['Garvin', 'Alston', '1996', '1996'],
#  ['Tom', 'Alston', '1954', '1957'],
#  ['Walter', 'Alston+', '1936', '1936'],
#  ['Porfi', 'Altamirano', '1982', '1984'],
#  ['Dan', 'Altavilla', '2016', '2017'],
#  ['Ernie', 'Alten', '1920', '1920'],
#  ['Jesse', 'Altenburg', '1916', '1917'],
#  ['Aaron', 'Altherr', '2014', '2017'],
#  ['Dave', 'Altizer', '1906', '1911'],
#  ['George', 'Altman', '1959', '1967'],
#  ['Joe', 'Altobelli', '1955', '1961'],
#  ['Nick', 'Altrock', '1898', '1933'],
#  ['Jose', 'Altuve', '2011', '2017'],
#  ['George', 'Alusik', '1958', '1964'],
#  ['Luis', 'Alvarado', '1968', '1977'],
#  ['Abe', 'Alvarez', '2004', '2006'],
#  ['Clemente', 'Alvarez', '2000', '2000'],
#  ['Dariel', 'Alvarez', '2015', '2016'],
#  ['Dario', 'Alvarez', '2014', '2017'],
#  ['Gabe', 'Alvarez', '1998', '2000'],
#  ['Henderson', 'Alvarez', '2011', '2015'],
#  ['Jose', 'Alvarez', '1981', '1989'],
#  ['Jose', 'Alvarez', '2013', '2017'],
#  ['Juan', 'Alvarez', '1999', '2003'],
#  ['Orlando', 'Alvarez', '1973', '1976'],
#  ['Ossie', 'Alvarez', '1958', '1959'],
#  ['Pedro', 'Alvarez', '2010', '2016'],
#  ['R.J.', 'Alvarez', '2014', '2015'],
#  ['Rogelio', 'Alvarez', '1960', '1962'],
#  ['Tavo', 'Alvarez', '1995', '1996'],
#  ['Tony', 'Alvarez', '2002', '2004'],
#  ['Victor', 'Alvarez', '2002', '2003'],
#  ['Wilson', 'Alvarez', '1989', '2005'],
#  ['Max', 'Alvis', '1962', '1970'],
#  ['Billy', 'Alvord', '1885', '1893'],
#  ['Brant', 'Alyea', '1965', '1972'],
#  ['Joey', 'Amalfitano', '1954', '1967'],
#  ['Rich', 'Amaral', '1991', '2000'],
#  ['Alexi', 'Amarista', '2011', '2017'],
#  ['Ruben', 'Amaro', '1958', '1969'],
#  ['Ruben', 'Amaro', '1991', '1998'],
#  ['Wayne', 'Ambler', '1937', '1939'],
#  ['Chip', 'Ambres', '2005', '2008'],
#  ['Hector', 'Ambriz', '2010', '2014'],
#  ['Ed', 'Amelung', '1984', '1986'],
#  ['Red', 'Ames', '1903', '1919'],
#  ['Steve', 'Ames', '2013', '2013'],
#  ['Alfredo', 'Amezaga', '2002', '2011'],
#  ['Doc', 'Amole', '1897', '1898'],
#  ['Vicente', 'Amor', '1955', '1957'],
#  ['Sandy', 'Amoros', '1952', '1960'],
#  ['Walter', 'Ancker', '1915', '1915'],
#  ['Larry', 'Andersen', '1975', '1994'],
#  ['Alf', 'Anderson', '1941', '1946'],
#  ['Allan', 'Anderson', '1986', '1991'],
#  ['Andy', 'Anderson', '1948', '1949'],
#  ['Bill', 'Anderson', '1889', '1889'],
#  ['Bill', 'Anderson', '1925', '1925'],
#  ['Bob', 'Anderson', '1957', '1963'],
#  ['Brady', 'Anderson', '1988', '2002'],
#  ['Brett', 'Anderson', '2009', '2017'],
#  ['Brian', 'Anderson', '1993', '2005'],
#  ['Brian', 'Anderson', '2005', '2009'],
#  ['Bryan', 'Anderson', '2010', '2015'],
#  ['Bud', 'Anderson', '1982', '1983'],
#  ['Chase', 'Anderson', '2014', '2017'],
#  ['Cody', 'Anderson', '2015', '2016'],
#  ['Craig', 'Anderson', '1961', '1964'],
#  ['Dave', 'Anderson', '1889', '1890'],
#  ['Dave', 'Anderson', '1983', '1992'],
#  ['Drew', 'Anderson', '2006', '2006'],
#  ['Dwain', 'Anderson', '1971', '1974'],
#  ['Ferrell', 'Anderson', '1946', '1953'],
#  ['Fred', 'Anderson', '1909', '1918'],
#  ['Garret', 'Anderson', '1994', '2010'],
#  ['George', 'Anderson', '1914', '1918'],
#  ['Goat', 'Anderson', '1907', '1907'],
#  ['Hal', 'Anderson', '1932', '1932'],
#  ['Harry', 'Anderson', '1957', '1961'],
#  ['Jason', 'Anderson', '2003', '2005'],
#  ['Jim', 'Anderson', '1978', '1984'],
#  ['Jimmy', 'Anderson', '1999', '2004'],
#  ['John', 'Anderson', '1894', '1908'],
#  ['John', 'Anderson', '1958', '1962'],
#  ['Josh', 'Anderson', '2007', '2009'],
#  ['Kent', 'Anderson', '1989', '1990'],
#  ['Larry', 'Anderson', '1974', '1977'],
#  ['Lars', 'Anderson', '2010', '2012'],
#  ['Marlon', 'Anderson', '1998', '2009'],
#  ['Matt', 'Anderson', '1998', '2005'],
#  ['Mike', 'Anderson', '1971', '1979'],
#  ['Mike', 'Anderson', '1993', '1993'],
#  ['Red', 'Anderson', '1937', '1941'],
#  ['Rick', 'Anderson', '1979', '1980'],
#  ['Rick', 'Anderson', '1986', '1988'],
#  ['Scott', 'Anderson', '1987', '1995'],
#  ['Sparky', 'Anderson+', '1959', '1959'],
#  ['Tim', 'Anderson', '2016', '2017'],
#  ['Tyler', 'Anderson', '2016', '2017'],
#  ['Varney', 'Anderson', '1889', '1896'],
#  ['Walter', 'Anderson', '1917', '1919'],
#  ['Wingo', 'Anderson', '1910', '1910'],
#  ['Robert', 'Andino', '2005', '2016'],
#  ['Steve', 'Andrade', '2006', '2006'],
#  ['John', 'Andre', '1955', '1955'],
#  ['Ernie', 'Andres', '1946', '1946'],
#  ['Kim', 'Andrew', '1975', '1975'],
#  ['Clayton', 'Andrews', '2000', '2000'],
#  ['Ed', 'Andrews', '1884', '1891'],
#  ['Elbert', 'Andrews', '1925', '1925'],
#  ['Fred', 'Andrews', '1976', '1977'],
#  ['Hub', 'Andrews', '1947', '1948'],
#  ['Ivy', 'Andrews', '1931', '1938'],
#  ['Jim', 'Andrews', '1890', '1890'],
#  ['John', 'Andrews', '1973', '1973'],
#  ['Mike', 'Andrews', '1966', '1973'],
#  ['Nate', 'Andrews', '1937', '1946'],
#  ['Rob', 'Andrews', '1975', '1979'],
#  ['Shane', 'Andrews', '1995', '2002'],
#  ['Stan', 'Andrews', '1939', '1945'],
#  ['Wally', 'Andrews', '1884', '1888'],
#  ['Matt', 'Andriese', '2015', '2017'],
#  ['Bill', 'Andrus', '1931', '1937'],
#  ['Elvis', 'Andrus', '2009', '2017'],
#  ['Fred', 'Andrus', '1876', '1884'],
#  ['Wyman', 'Andrus', '1885', '1885'],
#  ['Joaquin', 'Andujar', '1976', '1988'],
#  ['Luis', 'Andujar', '1995', '1998'],
#  ['Norm', 'Angelini', '1972', '1973'],
#  ['Matt', 'Angle', '2011', '2011'],
#  ['Tom', 'Angley', '1929', '1929'],
#  ['Pat', 'Ankenman', '1936', '1944'],
#  ['Rick', 'Ankiel', '1999', '2013'],
#  ['Dean', 'Anna', '2014', '2015'],
#  ['Bill', 'Annis', '1884', '1884'],
#  ['Cap', 'Anson+', '1871', '1897'],
#  ['Eric', 'Anthony', '1989', '1997'],
#  ['Joe', 'Antolick', '1944', '1944'],
#  ['Dustin', 'Antolin', '2016', '2016'],
#  ['John', 'Antonelli', '1944', '1945'],
#  ['Johnny', 'Antonelli', '1948', '1961'],
#  ['Matt', 'Antonelli', '2008', '2008'],
#  ['Bill', 'Antonello', '1953', '1953'],
#  ['Norichika', 'Aoki', '2012', '2017'],
#  ['Luis', 'Aparicio+', '1956', '1973'],
#  ['Bob', 'Apodaca', '1973', '1977'],
#  ['Luis', 'Aponte', '1980', '1984'],
#  ['Kevin', 'Appier', '1989', '2004'],
#  ['Fred', 'Applegate', '1904', '1904'],
#  ['Ed', 'Appleton', '1915', '1916'],
#  ['Pete', 'Appleton', '1927', '1945'],
#  ['Luke', 'Appling+', '1930', '1950'],
#  ['Greg', 'Aquino', '2004', '2009'],
#  ['Jayson', 'Aquino', '2016', '2017'],
#  ['Luis', 'Aquino', '1986', '1995'],
#  ['Angel', 'Aragon', '1914', '1917'],
#  ['Jack', 'Aragon', '1941', '1941'],
#  ['Elvis', 'Araujo', '2015', '2016'],
#  ['Maurice', 'Archdeacon', '1923', '1925'],
#  ['Chris', 'Archer', '2012', '2017'],
#  ['Fred', 'Archer', '1936', '1937'],
#  ['Jim', 'Archer', '1961', '1962'],
#  ['Jimmy', 'Archer', '1904', '1918'],
#  ['George', 'Archie', '1938', '1946'],
#  ['Jose', 'Arcia', '1968', '1970'],
#  ['Orlando', 'Arcia', '2016', '2017'],
#  ['Oswaldo', 'Arcia', '2013', '2016'],
#  ['Dan', 'Ardell', '1961', '1961'],
#  ['Rugger', 'Ardizoia', '1947', '1947'],
#  ['Joe', 'Ardner', '1884', '1890'],
#  ['Danny', 'Ardoin', '2000', '2008'],
#  ['Frank', 'Arellanes', '1908', '1910'],
#  ['Nolan', 'Arenado', '2013', '2017'],
#  ['J.P.', 'Arencibia', '2010', '2015'],
#  ['Hank', 'Arft', '1948', '1952'],
#  ['Alberto', 'Arias', '2007', '2009'],
#  ['Alex', 'Arias', '1992', '2002'],
#  ['George', 'Arias', '1996', '1999'],
#  ['Joaquin', 'Arias', '2006', '2015'],
#  ['Rudy', 'Arias', '1959', '1959'],
#  ['Buzz', 'Arlett', '1931', '1931'],
#  ['Don', 'Arlich', '1965', '1966'],
#  ['Steve', 'Arlin', '1969', '1974'],
#  ['Marcos', 'Armas', '1993', '1993'],
#  ['Tony', 'Armas', '1976', '1989'],
#  ['Tony', 'Armas', '1999', '2008'],
#  ['Ed', 'Armbrister', '1973', '1977'],
#  ['Orville', 'Armbrust', '1934', '1934'],
#  ['Charlie', 'Armbruster', '1905', '1907'],
#  ['Harry', 'Armbruster', '1906', '1906'],
#  ['George', 'Armstrong', '1946', '1946'],
#  ['Howard', 'Armstrong', '1911', '1911'],
#  ['Jack', 'Armstrong', '1988', '1994'],
#  ['Mike', 'Armstrong', '1980', '1987'],
#  ['Robert', 'Armstrong', '1871', '1871'],
#  ['Shawn', 'Armstrong', '2015', '2017'],
#  ['Harry', 'Arndt', '1902', '1907'],
#  ['Larry', 'Arndt', '1989', '1989'],
#  ['Billy', 'Arnold', '1872', '1872'],
#  ['Chris', 'Arnold', '1971', '1976'],
#  ['Jamie', 'Arnold', '1999', '2000'],
#  ['Scott', 'Arnold', '1988', '1988'],
#  ['Tony', 'Arnold', '1986', '1987'],
#  ['Morrie', 'Arnovich', '1936', '1946'],
#  ['Brad', 'Arnsberg', '1986', '1992'],
#  ['Orie', 'Arntzen', '1943', '1943'],
#  ['Jonathan', 'Aro', '2015', '2016'],
#  ['Rene', 'Arocha', '1993', '1997'],
#  ['Jose', 'Arredondo', '2008', '2012'],
#  ['Jake', 'Arrieta', '2010', '2017'],
#  ['Gerry', 'Arrigo', '1961', '1970'],
#  ['Rolando', 'Arrojo', '1998', '2002'],
#  ['Bronson', 'Arroyo', '2000', '2017'],
#  ['Christian', 'Arroyo', '2017', '2017'],
#  ['Fernando', 'Arroyo', '1975', '1986'],
#  ['Luis', 'Arroyo', '1955', '1963'],
#  ['Rudy', 'Arroyo', '1971', '1971'],
#  ['Erisbel', 'Arruebarrena', '2014', '2014'],
#  ['Harry', 'Arundel', '1875', '1884'],
#  ['Tug', 'Arundel', '1882', '1888'],
#  ['Randy', 'Asadoor', '1986', '1986'],
#  ['Jim', 'Asbell', '1938', '1938'],
#  ['Casper', 'Asbjornson', '1928', '1932'],
#  ['Jose', 'Ascanio', '2007', '2011'],
#  ['Cody', 'Asche', '2013', '2017'],
#  ['Jairo', 'Asencio', '2009', '2013'],
#  ['Miguel', 'Asencio', '2002', '2006'],
#  ['Ken', 'Ash', '1925', '1930'],
#  ['Richie', 'Ashburn+', '1948', '1962'],
#  ['Alan', 'Ashby', '1973', '1989'],
#  ['Andy', 'Ashby', '1991', '2004'],
#  ['Alec', 'Asher', '2015', '2017'],
#  ['Tucker', 'Ashford', '1976', '1984'],
#  ['Billy', 'Ashley', '1992', '1998'],
#  ['Nevin', 'Ashley', '2015', '2015'],
#  ['Tom', 'Asmussen', '1907', '1907'],
#  ['Bob', 'Aspromonte', '1956', '1971'],
#  ['Ken', 'Aspromonte', '1957', '1963'],
#  ['Brian', 'Asselstine', '1976', '1981'],
#  ['Paul', 'Assenmacher', '1986', '1999'],
#  ['Ezequiel', 'Astacio', '2005', '2006'],
#  ['Pedro', 'Astacio', '1992', '2006'],
#  ['Barrett', 'Astin', '2017', '2017'],
#  ['Joe', 'Astroth', '1945', '1956'],
#  ['Carlos', 'Asuaje', '2016', '2016'],
#  ['Scott', 'Atchison', '2004', '2015'],
#  ['Justin', 'Atchley', '2001', '2001'],
#  ['Charlie', 'Atherton', '1899', '1899'],
#  ['Keith', 'Atherton', '1983', '1989'],
#  ['Luis', 'Atilano', '2010', '2010'],
#  ['Garrett', 'Atkins', '2003', '2010'],
#  ['James', 'Atkins', '1950', '1952'],
#  ['Mitch', 'Atkins', '2009', '2011'],
#  ['Tommy', 'Atkins', '1909', '1910'],
#  ['Al', 'Atkinson', '1884', '1887'],
#  ['Bill', 'Atkinson', '1976', '1979'],
#  ['Ed', 'Atkinson', '1873', '1873'],
#  ['Harry', 'Atkinson', '1895', '1895'],
#  ['Lefty', 'Atkinson', '1927', '1927'],
#  ['Dick', 'Attreau', '1926', '1927'],
#  ['Toby', 'Atwell', '1952', '1956'],
#  ['Bill', 'Atwood', '1936', '1940'],
#  ['Jake', 'Atz', '1902', '1909'],
#  ['Chub', 'Aubrey', '1903', '1903'],
#  ['Michael', 'Aubrey', '2008', '2009'],
#  ['Derek', 'Aucoin', '1996', '1996'],
#  ['Rich', 'Aude', '1993', '1996'],
#  ['Rick', 'Auerbach', '1971', '1981'],
#  ['Bryan', 'Augenstein', '2009', '2011'],
#  ['Don', 'August', '1988', '1991'],
#  ['Dave', 'Augustine', '1973', '1974'],
#  ['Jerry', 'Augustine', '1975', '1984'],
#  ['Elden', 'Auker', '1933', '1942'],
#  ['Tex', 'Aulds', '1947', '1947'],
#  ['Doug', 'Ault', '1976', '1980'],
#  ['Phillippe', 'Aumont', '2012', '2015'],
#  ['Rich', 'Aurilia', '1995', '2009'],
#  ['Joe', 'Ausanio', '1994', '1995'],
#  ['Brad', 'Ausmus', '1993', '2010'],
#  ['Dennis', 'Aust', '1965', '1966'],
#  ['Henry', 'Austin', '1873', '1873'],
#  ['Jeff', 'Austin', '2001', '2003'],
#  ['Jim', 'Austin', '1991', '1993'],
#  ['Jimmy', 'Austin', '1909', '1929'],
#  ['Rick', 'Austin', '1970', '1976'],
#  ['Tyler', 'Austin', '2016', '2016'],
#  ['Al', 'Autry', '1976', '1976'],
#  ['Chick', 'Autry', '1907', '1909'],
#  ['Chick', 'Autry', '1924', '1930'],
#  ['Bruce', 'Aven', '1997', '2002'],
#  ['Earl', 'Averill+', '1929', '1941'],
#  ['Earl', 'Averill', '1956', '1963'],
#  ['Steve', 'Avery', '1990', '2003'],
#  ['Xavier', 'Avery', '2012', '2012'],
#  ['Alex', 'Avila', '2009', '2017'],
#  ['Bobby', 'Avila', '1949', '1959'],
#  ['Luis', 'Avilan', '2012', '2017'],
#  ['Mike', 'Aviles', '2008', '2016'],
#  ['Ramon', 'Aviles', '1977', '1981'],
#  ['Jay', 'Avrea', '1950', '1950'],
#  ['Dylan', 'Axelrod', '2011', '2015'],
#  ['John', 'Axford', '2009', '2016'],
#  ['Benny', 'Ayala', '1974', '1985'],
#  ['Bobby', 'Ayala', '1992', '1999'],
#  ['Luis', 'Ayala', '2003', '2013'],
#  ['Erick', 'Aybar', '2006', '2017'],
#  ['Manny', 'Aybar', '1997', '2005'],
#  ['Willy', 'Aybar', '2005', '2010'],
#  ['Jake', 'Aydelott', '1884', '1886'],
#  ['Bill', 'Ayers', '1947', '1947'],
#  ['Doc', 'Ayers', '1913', '1921'],
#  ['Dick', 'Aylward', '1953', '1953'],
#  ['Bob', 'Ayrault', '1992', '1993'],
#  ['Joe', 'Ayrault', '1996', '1996'],
#  ['Joe', 'Azcue', '1960', '1972'],
#  ['Oscar', 'Azocar', '1990', '1992']]

# %% [markdown]
# ### Unfortunately, the length of each list is not the same because not every single player in the full list has exactly 1 first name and 1 last name.

# %%
#takes care of people with middle names by adding first and middle name to one string
for career in split_player_list:
    if len(career) == 5:
        career[0] = career[0] + career[1]
        career.remove(career[1])

#makes player with one name have his first and last name the same
    elif len(career) == 3:
        career.insert(0, career[0])

#combines the strings of players with more than one last name into one string. (Eg. de la cruz --->delacruz)        
    elif len(career) == 6:
        career[1] = career[1] + career[2] + career[3]
        career.remove(career[2])
        career.remove(career[2])

# %% [markdown]
# ### With that, we have a list of lists with all players with a last name that starts with "A".
#
# ### And now comes the real magic of webscraping. With a few additional lines of code, we can grab the html from each of the pages and add the relevant data to our data set in a matter of seconds.

# %%
alphabet = "abcdefghijklmnopqrstuvwyz"
player_list = []

#this for loop and nested for loop creates a beautiful soup object for each url (a - z) and appends
#the relevant text to an empty list
for letter in alphabet:
    MLB_players = requests.get("http://www.baseball-reference.com/players/{}/".format(letter))
    MLB_soup = bs4(MLB_players.content, "html.parser")
   
    players = MLB_soup.findAll("p")
    
    for player in players:
        if "(" in player.text:
            player_list.append(player.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f240d90ac06d> in <module>()
#       5 #the relevant text to an empty list
#       6 for letter in alphabet:
# ----> 7     MLB_players = requests.get("http://www.baseball-reference.com/players/{}/".format(letter))
#       8     MLB_soup = bs4(MLB_players.content, "html.parser")
#       9
#
# NameError: name 'requests' is not defined

# %% [markdown]
# ### Run the same code from before to clean the data.

# %%
new_player_list = []
for player in player_list:
    player = player.replace('(',"").replace(')',"").replace("-"," ").replace("  ", " ")
    new_player_list.append(player)

split_player_list = []
for player in new_player_list:
    split_player_list.append(player.split(" "))

for career in split_player_list:
    if len(career) == 5:
        career[0] = career[0] + career[1]
        career.remove(career[1])
    
    elif len(career) == 3:
        career.insert(0, career[0])
        
    elif len(career) == 6:
        career[1] = career[1] + career[2] + career[3]
        career.remove(career[2])
        career.remove(career[2])

# %% [markdown]
# ### Add a column to the end of each row that is the length of the player's career.

# %%
#add one to the value of the difference between the starting year and end year.
#otherwise, players who played 1 season will have 0 as the length of their career. 

for row in split_player_list:
    row.append((int(row[3]) - int(row[2]))+1)

# %% [markdown]
# ### Finally, write the data to a csv file.

# %%
import csv

with open("MLB_careers.csv","w",newline="") as f:
    writer = csv.writer(f)
    writer.writerows(split_player_list)

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Rookies

# %%
for career in split_player_list:
    if "2017" in career[2]:
        print (career)
# Out:
# ['Christian', 'Arroyo', '2017', '2017', 1]
# ['Barrett', 'Astin', '2017', '2017', 1]
# ['Rafael', 'Bautista', '2017', '2017', 1]
# ['Cody', 'Bellinger', '2017', '2017', 1]
# ['Jorge', 'Bonifacio', '2017', '2017', 1]
# ['John', 'Bormann', '2017', '2017', 1]
# ['Johan', 'Camargo', '2017', '2017', 1]
# ['Shane', 'Carle', '2017', '2017', 1]
# ['Allen', 'Cordoba', '2017', '2017', 1]
# ['Dylan', 'Covey', '2017', '2017', 1]
# ['Stefan', 'Crichton', '2017', '2017', 1]
# ['Rookie', 'Davis', '2017', '2017', 1]
# ['ChaseDe', 'Jong', '2017', '2017', 1]
# ['Miguel', 'Diaz', '2017', '2017', 1]
# ['Yandy', 'Diaz', '2017', '2017', 1]
# ['Phil', 'Ervin', '2017', '2017', 1]
# ['Kyle', 'Freeland', '2017', '2017', 1]
# ['Jarlin', 'Garcia', '2017', '2017', 1]
# ['Willy', 'Garcia', '2017', '2017', 1]
# ['Amir', 'Garrett', '2017', '2017', 1]
# ['Justin', 'Haley', '2017', '2017', 1]
# ['Mike', 'Hauschild', '2017', '2017', 1]
# ['Ariel', 'Hernandez', '2017', '2017', 1]
# ['Kyle', 'Higashioka', '2017', '2017', 1]
# ['ChihWei', 'Hu', '2017', '2017', 1]
# ['Joe', 'Jimenez', '2017', '2017', 1]
# ['Jake', 'Junis', '2017', '2017', 1]
# ['Andrew', 'Knapp', '2017', '2017', 1]
# ['Casey', 'Lawrence', '2017', '2017', 1]
# ['Mark', 'Leiter', '2017', '2017', 1]
# ['Jacob', 'May', '2017', '2017', 1]
# ['Jordan', 'Montgomery', '2017', '2017', 1]
# ['Dovydas', 'Neverauskas', '2017', '2017', 1]
# ['Gift', 'Ngoepe', '2017', '2017', 1]
# ['Daniel', 'Ortiz', '2017', '2017', 1]
# ['Jose', 'Osuna', '2017', '2017', 1]
# ['Nick', 'Pivetta', '2017', '2017', 1]
# ['Boog', 'Powell', '2017', '2017', 1]
# ['Austin', 'Pruitt', '2017', '2017', 1]
# ['J.T.', 'Riddle', '2017', '2017', 1]
# ['Daniel', 'Robertson', '2017', '2017', 1]
# ['Drew', 'Robinson', '2017', '2017', 1]
# ['Sal', 'Romano', '2017', '2017', 1]
# ['Antonio', 'Senzatela', '2017', '2017', 1]
# ['Paul', 'Sewald', '2017', '2017', 1]
# ['Brock', 'Stassi', '2017', '2017', 1]
# ['Ben', 'Taylor', '2017', '2017', 1]
# ['Luis', 'Torrens', '2017', '2017', 1]
# ['Stuart', 'Turner', '2017', '2017', 1]
# ['Jesse', 'Winker', '2017', '2017', 1]

# %% [markdown]
# ### Current players

# %%
for career in split_player_list:
    if "2017" in career[3]:
        print (career)
# Out:
# ['Fernando', 'Abad', '2010', '2017', 8]
# ['Jose', 'Abreu', '2014', '2017', 4]
# ['Cristhian', 'Adames', '2014', '2017', 4]
# ['Lane', 'Adams', '2014', '2017', 4]
# ['Matt', 'Adams', '2012', '2017', 6]
# ['Jim', 'Adduci', '2013', '2017', 5]
# ['Tim', 'Adleman', '2016', '2017', 2]
# ['Jesus', 'Aguilar', '2014', '2017', 4]
# ['Nick', 'Ahmed', '2014', '2017', 4]
# ['Matt', 'Albers', '2006', '2017', 12]
# ['Arismendy', 'Alcantara', '2014', '2017', 4]
# ['Raul', 'Alcantara', '2016', '2017', 2]
# ['Scott', 'Alexander', '2015', '2017', 3]
# ['Cody', 'Allen', '2012', '2017', 6]
# ['Abraham', 'Almonte', '2013', '2017', 5]
# ['Albert', 'Almora', '2016', '2017', 2]
# ['Yonder', 'Alonso', '2010', '2017', 8]
# ['Dan', 'Altavilla', '2016', '2017', 2]
# ['Aaron', 'Altherr', '2014', '2017', 4]
# ['Jose', 'Altuve', '2011', '2017', 7]
# ['Dario', 'Alvarez', '2014', '2017', 4]
# ['Jose', 'Alvarez', '2013', '2017', 5]
# ['Alexi', 'Amarista', '2011', '2017', 7]
# ['Brett', 'Anderson', '2009', '2017', 9]
# ['Chase', 'Anderson', '2014', '2017', 4]
# ['Tim', 'Anderson', '2016', '2017', 2]
# ['Tyler', 'Anderson', '2016', '2017', 2]
# ['Matt', 'Andriese', '2015', '2017', 3]
# ['Elvis', 'Andrus', '2009', '2017', 9]
# ['Norichika', 'Aoki', '2012', '2017', 6]
# ['Jayson', 'Aquino', '2016', '2017', 2]
# ['Chris', 'Archer', '2012', '2017', 6]
# ['Orlando', 'Arcia', '2016', '2017', 2]
# ['Nolan', 'Arenado', '2013', '2017', 5]
# ['Shawn', 'Armstrong', '2015', '2017', 3]
# ['Jake', 'Arrieta', '2010', '2017', 8]
# ['Bronson', 'Arroyo', '2000', '2017', 18]
# ['Christian', 'Arroyo', '2017', '2017', 1]
# ['Cody', 'Asche', '2013', '2017', 5]
# ['Alec', 'Asher', '2015', '2017', 3]
# ['Barrett', 'Astin', '2017', '2017', 1]
# ['Alex', 'Avila', '2009', '2017', 9]
# ['Luis', 'Avilan', '2012', '2017', 6]
# ['Erick', 'Aybar', '2006', '2017', 12]
# ['Javier', 'Baez', '2014', '2017', 4]
# ['Pedro', 'Baez', '2014', '2017', 4]
# ['Andrew', 'Bailey', '2009', '2017', 9]
# ['Jett', 'Bandy', '2015', '2017', 3]
# ['Johnny', 'Barbato', '2016', '2017', 2]
# ['Austin', 'Barnes', '2015', '2017', 3]
# ['Danny', 'Barnes', '2016', '2017', 2]
# ['Jacob', 'Barnes', '2016', '2017', 2]
# ['Matt', 'Barnes', '2014', '2017', 4]
# ['Tony', 'Barnette', '2016', '2017', 2]
# ['Darwin', 'Barney', '2010', '2017', 8]
# ['Tucker', 'Barnhart', '2014', '2017', 4]
# ['Kyle', 'Barraclough', '2015', '2017', 3]
# ['Anthony', 'Bass', '2011', '2017', 7]
# ['Antonio', 'Bastardo', '2009', '2017', 9]
# ['Trevor', 'Bauer', '2012', '2017', 6]
# ['Jose', 'Bautista', '2004', '2017', 14]
# ['Rafael', 'Bautista', '2017', '2017', 1]
# ['Chris', 'Beck', '2015', '2017', 3]
# ['Tim', 'Beckham', '2013', '2017', 5]
# ['Cam', 'Bedrosian', '2014', '2017', 4]
# ['Matt', 'Belisle', '2003', '2017', 15]
# ['Josh', 'Bell', '2016', '2017', 2]
# ['Cody', 'Bellinger', '2017', '2017', 1]
# ['Brandon', 'Belt', '2011', '2017', 7]
# ['Carlos', 'Beltran', '1998', '2017', 20]
# ['Andrew', 'Benintendi', '2016', '2017', 2]
# ['Joaquin', 'Benoit', '2001', '2017', 17]
# ['Dellin', 'Betances', '2011', '2017', 7]
# ['Christian', 'Bethancourt', '2013', '2017', 5]
# ['Mookie', 'Betts', '2014', '2017', 4]
# ['Joe', 'Biagini', '2016', '2017', 2]
# ['Greg', 'Bird', '2015', '2017', 3]
# ['Ty', 'Blach', '2016', '2017', 2]
# ['Charlie', 'Blackmon', '2011', '2017', 7]
# ['Andres', 'Blanco', '2004', '2017', 14]
# ['Joe', 'Blanton', '2004', '2017', 14]
# ['Jabari', 'Blash', '2016', '2017', 2]
# ['Jerry', 'Blevins', '2007', '2017', 11]
# ['Xander', 'Bogaerts', '2013', '2017', 5]
# ['Emilio', 'Bonifacio', '2007', '2017', 11]
# ['Jorge', 'Bonifacio', '2017', '2017', 1]
# ['Lisalverto', 'Bonilla', '2014', '2017', 4]
# ['John', 'Bormann', '2017', '2017', 1]
# ['Buddy', 'Boshers', '2013', '2017', 5]
# ['Justin', 'Bour', '2014', '2017', 4]
# ['Peter', 'Bourjos', '2010', '2017', 8]
# ['Matthew', 'Bowman', '2016', '2017', 2]
# ['Matt', 'Boyd', '2015', '2017', 3]
# ['Brad', 'Brach', '2011', '2017', 7]
# ['Silvino', 'Bracho', '2015', '2017', 3]
# ['Archie', 'Bradley', '2015', '2017', 3]
# ['Jackie', 'Bradley', '2013', '2017', 5]
# ['Michael', 'Brantley', '2009', '2017', 9]
# ['Ryan', 'Braun', '2007', '2017', 11]
# ['Alex', 'Bregman', '2016', '2017', 2]
# ['Craig', 'Breslow', '2005', '2017', 13]
# ['Zach', 'Britton', '2011', '2017', 7]
# ['Jonathan', 'Broxton', '2005', '2017', 13]
# ['Keon', 'Broxton', '2015', '2017', 3]
# ['Jay', 'Bruce', '2008', '2017', 10]
# ['Kris', 'Bryant', '2015', '2017', 3]
# ['Clay', 'Buchholz', '2007', '2017', 11]
# ['Ryan', 'Buchter', '2014', '2017', 4]
# ['Madison', 'Bumgarner', '2009', '2017', 9]
# ['Dylan', 'Bundy', '2012', '2017', 6]
# ['Matt', 'Bush', '2016', '2017', 2]
# ['Drew', 'Butera', '2010', '2017', 8]
# ['Byron', 'Buxton', '2015', '2017', 3]
# ['Asdrubal', 'Cabrera', '2007', '2017', 11]
# ['Melky', 'Cabrera', '2005', '2017', 13]
# ['Miguel', 'Cabrera', '2003', '2017', 15]
# ['Trevor', 'Cahill', '2009', '2017', 9]
# ['Lorenzo', 'Cain', '2010', '2017', 8]
# ['Matt', 'Cain', '2005', '2017', 13]
# ['Kole', 'Calhoun', '2012', '2017', 6]
# ['Johan', 'Camargo', '2017', '2017', 1]
# ['Leonel', 'Campos', '2014', '2017', 4]
# ['Mark', 'Canha', '2015', '2017', 3]
# ['Robinson', 'Cano', '2005', '2017', 13]
# ['Stephen', 'Cardullo', '2016', '2017', 2]
# ['Shane', 'Carle', '2017', '2017', 1]
# ['Matt', 'Carpenter', '2011', '2017', 7]
# ['Carlos', 'Carrasco', '2009', '2017', 9]
# ['Ezequiel', 'Carrera', '2011', '2017', 7]
# ['Chris', 'Carter', '2010', '2017', 8]
# ['Andrew', 'Cashner', '2010', '2017', 8]
# ['Santiago', 'Casilla', '2004', '2017', 14]
# ['Nicholas', 'Castellanos', '2013', '2017', 5]
# ['Welington', 'Castillo', '2010', '2017', 8]
# ['Jason', 'Castro', '2010', '2017', 8]
# ['Starlin', 'Castro', '2010', '2017', 8]
# ['Brett', 'Cecil', '2009', '2017', 9]
# ['Xavier', 'Cedeno', '2011', '2017', 7]
# ['Francisco', 'Cervelli', '2008', '2017', 10]
# ['Yoenis', 'Cespedes', '2012', '2017', 6]
# ['Luis', 'Cessa', '2016', '2017', 2]
# ['Jhoulys', 'Chacin', '2009', '2017', 9]
# ['Andrew', 'Chafin', '2014', '2017', 4]
# ['Aroldis', 'Chapman', '2010', '2017', 8]
# ['Tyler', 'Chatwood', '2011', '2017', 7]
# ['Jesse', 'Chavez', '2008', '2017', 10]
# ['WeiYin', 'Chen', '2012', '2017', 6]
# ['Robinson', 'Chirinos', '2011', '2017', 7]
# ['Lonnie', 'Chisenhall', '2011', '2017', 7]
# ['ShinSoo', 'Choo', '2005', '2017', 13]
# ['Tony', 'Cingrani', '2012', '2017', 6]
# ['Alex', 'Claudio', '2014', '2017', 4]
# ['Tyler', 'Clippard', '2007', '2017', 11]
# ['Alex', 'Cobb', '2011', '2017', 7]
# ['Chris', 'Coghlan', '2009', '2017', 9]
# ['Gerrit', 'Cole', '2013', '2017', 5]
# ['Tyler', 'Collins', '2014', '2017', 4]
# ['Josh', 'Collmenter', '2011', '2017', 7]
# ['Alex', 'Colome', '2013', '2017', 5]
# ['Bartolo', 'Colon', '1997', '2017', 21]
# ['Christian', 'Colon', '2014', '2017', 4]
# ['Michael', 'Conforto', '2015', '2017', 3]
# ['Adam', 'Conley', '2015', '2017', 3]
# ['Willson', 'Contreras', '2016', '2017', 2]
# ['Patrick', 'Corbin', '2012', '2017', 6]
# ['Allen', 'Cordoba', '2017', '2017', 1]
# ['Carlos', 'Correa', '2015', '2017', 3]
# ['Jarred', 'Cosart', '2013', '2017', 5]
# ['Jharel', 'Cotton', '2016', '2017', 2]
# ['Daniel', 'Coulombe', '2014', '2017', 4]
# ['Dylan', 'Covey', '2017', '2017', 1]
# ['Zack', 'Cozart', '2011', '2017', 7]
# ['Brandon', 'Crawford', '2011', '2017', 7]
# ['Stefan', 'Crichton', '2017', '2017', 1]
# ['C.J.', 'Cron', '2014', '2017', 4]
# ['Nelson', 'Cruz', '2005', '2017', 13]
# ['Johnny', 'Cueto', '2008', '2017', 10]
# ['William', 'Cuevas', '2016', '2017', 2]
# ['Cheslor', 'Cuthbert', '2015', '2017', 3]
# ['Chase', "d'Arnaud", '2011', '2017', 7]
# ['Travis', "d'Arnaud", '2013', '2017', 5]
# ['Yu', 'Darvish', '2012', '2017', 6]
# ['Matt', 'Davidson', '2013', '2017', 5]
# ['Zach', 'Davies', '2015', '2017', 3]
# ['Chris', 'Davis', '2008', '2017', 10]
# ['Khris', 'Davis', '2013', '2017', 5]
# ['Rajai', 'Davis', '2006', '2017', 12]
# ['Rookie', 'Davis', '2017', '2017', 1]
# ['Wade', 'Davis', '2009', '2017', 9]
# ['Grant', 'Dayton', '2016', '2017', 2]
# ['ChaseDe', 'Jong', '2017', '2017', 1]
# ['Jorge', 'DeLaRosa', '2004', '2017', 14]
# ['Jaff', 'Decker', '2013', '2017', 5]
# ['Jacob', 'deGrom', '2014', '2017', 4]
# ['Randall', 'Delgado', '2011', '2017', 7]
# ['Matt', 'Dermody', '2016', '2017', 2]
# ['Daniel', 'Descalso', '2010', '2017', 8]
# ['Delino', 'DeShields', '2015', '2017', 3]
# ['Ian', 'Desmond', '2009', '2017', 9]
# ['Chris', 'Devenski', '2016', '2017', 2]
# ['Aledmys', 'Diaz', '2016', '2017', 2]
# ['Edwin', 'Diaz', '2016', '2017', 2]
# ['Jumbo', 'Diaz', '2014', '2017', 4]
# ['Miguel', 'Diaz', '2017', '2017', 1]
# ['Yandy', 'Diaz', '2017', '2017', 1]
# ['Corey', 'Dickerson', '2013', '2017', 5]
# ['R.A.', 'Dickey', '2001', '2017', 17]
# ['Derek', 'Dietrich', '2013', '2017', 5]
# ['Wilmer', 'Difo', '2015', '2017', 3]
# ['Josh', 'Donaldson', '2010', '2017', 8]
# ['Sean', 'Doolittle', '2012', '2017', 6]
# ['Brian', 'Dozier', '2012', '2017', 6]
# ['Oliver', 'Drake', '2015', '2017', 3]
# ['Stephen', 'Drew', '2006', '2017', 12]
# ['Brandon', 'Drury', '2015', '2017', 3]
# ['Lucas', 'Duda', '2010', '2017', 8]
# ['Brian', 'Duensing', '2009', '2017', 9]
# ['Tyler', 'Duffey', '2015', '2017', 3]
# ['Danny', 'Duffy', '2011', '2017', 7]
# ['Ryan', 'Dull', '2015', '2017', 3]
# ['Mike', 'Dunn', '2009', '2017', 9]
# ['Adam', 'Duvall', '2014', '2017', 4]
# ['Jarrod', 'Dyson', '2010', '2017', 8]
# ['Sam', 'Dyson', '2012', '2017', 6]
# ['Adam', 'Eaton', '2012', '2017', 6]
# ['Josh', 'Edgin', '2012', '2017', 6]
# ['Carl', 'Edwards', '2015', '2017', 3]
# ['Zach', 'Eflin', '2016', '2017', 2]
# ['Brett', 'Eibner', '2016', '2017', 2]
# ['Jerad', 'Eickhoff', '2015', '2017', 3]
# ['A.J.', 'Ellis', '2008', '2017', 10]
# ['Jacoby', 'Ellsbury', '2007', '2017', 11]
# ['Edwin', 'Encarnacion', '2005', '2017', 13]
# ['Phil', 'Ervin', '2017', '2017', 1]
# ['Jake', 'Esch', '2016', '2017', 2]
# ['Alcides', 'Escobar', '2008', '2017', 10]
# ['Eduardo', 'Escobar', '2011', '2017', 7]
# ['Yunel', 'Escobar', '2007', '2017', 11]
# ['Danny', 'Espinosa', '2010', '2017', 8]
# ['Carlos', 'Estevez', '2016', '2017', 2]
# ['Marco', 'Estrada', '2008', '2017', 10]
# ['Jeurys', 'Familia', '2012', '2017', 6]
# ['Danny', 'Farquhar', '2011', '2017', 7]
# ['Tim', 'Federowicz', '2011', '2017', 7]
# ['Scott', 'Feldman', '2005', '2017', 13]
# ['Michael', 'Feliz', '2015', '2017', 3]
# ['Neftali', 'Feliz', '2009', '2017', 9]
# ['Josh', 'Fields', '2013', '2017', 5]
# ['Casey', 'Fien', '2009', '2017', 9]
# ['Mike', 'Fiers', '2011', '2017', 7]
# ['Brandon', 'Finnegan', '2014', '2017', 4]
# ['Ryan', 'Flaherty', '2012', '2017', 6]
# ['Wilmer', 'Flores', '2013', '2017', 5]
# ['Tyler', 'Flowers', '2009', '2017', 9]
# ['Mike', 'Foltynewicz', '2014', '2017', 4]
# ['Logan', 'Forsythe', '2011', '2017', 7]
# ['Dexter', 'Fowler', '2008', '2017', 10]
# ['Maikel', 'Franco', '2014', '2017', 4]
# ['Nick', 'Franklin', '2013', '2017', 5]
# ['Adam', 'Frazier', '2016', '2017', 2]
# ['Todd', 'Frazier', '2011', '2017', 7]
# ['Kyle', 'Freeland', '2017', '2017', 1]
# ['Freddie', 'Freeman', '2010', '2017', 8]
# ['Mike', 'Freeman', '2016', '2017', 2]
# ['David', 'Freese', '2009', '2017', 9]
# ['Eric', 'Fryer', '2011', '2017', 7]
# ['Michael', 'Fulmer', '2016', '2017', 2]
# ['Yovani', 'Gallardo', '2007', '2017', 11]
# ['Joey', 'Gallo', '2015', '2017', 3]
# ['Freddy', 'Galvis', '2012', '2017', 6]
# ['Ben', 'Gamel', '2016', '2017', 2]
# ['Adonis', 'Garcia', '2015', '2017', 3]
# ['Avisail', 'Garcia', '2012', '2017', 6]
# ['Greg', 'Garcia', '2014', '2017', 4]
# ['Jaime', 'Garcia', '2008', '2017', 10]
# ['Jarlin', 'Garcia', '2017', '2017', 1]
# ['Leury', 'Garcia', '2013', '2017', 5]
# ['Luis', 'Garcia', '2013', '2017', 5]
# ['Willy', 'Garcia', '2017', '2017', 1]
# ['Brett', 'Gardner', '2008', '2017', 10]
# ['Dustin', 'Garneau', '2015', '2017', 3]
# ['Amir', 'Garrett', '2017', '2017', 1]
# ['Ryan', 'Garton', '2016', '2017', 2]
# ['Matt', 'Garza', '2006', '2017', 12]
# ['Evan', 'Gattis', '2013', '2017', 5]
# ['Kevin', 'Gausman', '2013', '2017', 5]
# ['Cory', 'Gearrin', '2011', '2017', 7]
# ['Scooter', 'Gennett', '2013', '2017', 5]
# ['Craig', 'Gentry', '2009', '2017', 9]
# ['Kyle', 'Gibson', '2013', '2017', 5]
# ['Ken', 'Giles', '2014', '2017', 4]
# ['Conor', 'Gillaspie', '2008', '2017', 10]
# ['Sean', 'Gilmartin', '2015', '2017', 3]
# ['Chris', 'Gimenez', '2009', '2017', 9]
# ['Mychal', 'Givens', '2015', '2017', 3]
# ['Tyler', 'Glasnow', '2016', '2017', 2]
# ['Koda', 'Glover', '2016', '2017', 2]
# ['Zack', 'Godley', '2015', '2017', 3]
# ['David', 'Goforth', '2015', '2017', 3]
# ['Ryan', 'Goins', '2013', '2017', 5]
# ['Paul', 'Goldschmidt', '2011', '2017', 7]
# ['Yan', 'Gomes', '2012', '2017', 6]
# ['Carlos', 'Gomez', '2007', '2017', 11]
# ['Jeanmar', 'Gomez', '2010', '2017', 8]
# ['Adrian', 'Gonzalez', '2004', '2017', 14]
# ['Carlos', 'Gonzalez', '2008', '2017', 10]
# ['Gio', 'Gonzalez', '2008', '2017', 10]
# ['Marwin', 'Gonzalez', '2012', '2017', 6]
# ['Miguel', 'Gonzalez', '2012', '2017', 6]
# ['Nick', 'Goody', '2015', '2017', 3]
# ['Alex', 'Gordon', '2007', '2017', 11]
# ['Dee', 'Gordon', '2011', '2017', 7]
# ['Terrance', 'Gore', '2014', '2017', 4]
# ['Philip', 'Gosselin', '2013', '2017', 5]
# ['Matt', 'Grace', '2015', '2017', 3]
# ['Yasmani', 'Grandal', '2012', '2017', 6]
# ['Curtis', 'Granderson', '2004', '2017', 14]
# ['Juan', 'Graterol', '2016', '2017', 2]
# ['Kendall', 'Graveman', '2014', '2017', 4]
# ['Jon', 'Gray', '2015', '2017', 3]
# ['Grant', 'Green', '2013', '2017', 5]
# ['Shane', 'Greene', '2014', '2017', 4]
# ['Luke', 'Gregerson', '2009', '2017', 9]
# ['Didi', 'Gregorius', '2012', '2017', 6]
# ['Zack', 'Greinke', '2004', '2017', 14]
# ['Randal', 'Grichuk', '2014', '2017', 4]
# ['A.J.', 'Griffin', '2012', '2017', 6]
# ['Jason', 'Grilli', '2000', '2017', 18]
# ['Justin', 'Grimm', '2012', '2017', 6]
# ['Robbie', 'Grossman', '2013', '2017', 5]
# ['Robert', 'Gsellman', '2016', '2017', 2]
# ['Deolis', 'Guerra', '2015', '2017', 3]
# ['Junior', 'Guerra', '2015', '2017', 3]
# ['Yuli', 'Gurriel', '2016', '2017', 2]
# ['Jandel', 'Gustave', '2016', '2017', 2]
# ['Jeremy', 'Guthrie', '2004', '2017', 14]
# ['Franklin', 'Gutierrez', '2005', '2017', 13]
# ['Brandon', 'Guyer', '2011', '2017', 7]
# ['Jedd', 'Gyorko', '2013', '2017', 5]
# ['Jesse', 'Hahn', '2014', '2017', 4]
# ['Justin', 'Haley', '2017', '2017', 1]
# ['Cole', 'Hamels', '2006', '2017', 12]
# ['Billy', 'Hamilton', '2013', '2017', 5]
# ['Jason', 'Hammel', '2006', '2017', 12]
# ['Brad', 'Hand', '2011', '2017', 7]
# ['Mitch', 'Haniger', '2016', '2017', 2]
# ['Alen', 'Hanson', '2016', '2017', 2]
# ['J.A.', 'Happ', '2007', '2017', 11]
# ['Blaine', 'Hardy', '2014', '2017', 4]
# ['J.J.', 'Hardy', '2005', '2017', 13]
# ['Bryce', 'Harper', '2012', '2017', 6]
# ['Will', 'Harris', '2012', '2017', 6]
# ['Josh', 'Harrison', '2011', '2017', 7]
# ['Donnie', 'Hart', '2016', '2017', 2]
# ['Matt', 'Harvey', '2012', '2017', 6]
# ['Chris', 'Hatcher', '2010', '2017', 8]
# ['Mike', 'Hauschild', '2017', '2017', 1]
# ['Jeremy', 'Hazelbaker', '2016', '2017', 2]
# ['Chase', 'Headley', '2007', '2017', 11]
# ['Ryon', 'Healy', '2016', '2017', 2]
# ['Adeiny', 'Hechavarria', '2012', '2017', 6]
# ['Austin', 'Hedges', '2015', '2017', 3]
# ['Chris', 'Heisey', '2010', '2017', 8]
# ['Jeremy', 'Hellickson', '2010', '2017', 8]
# ['Heath', 'Hembree', '2013', '2017', 5]
# ['Kyle', 'Hendricks', '2014', '2017', 4]
# ['Liam', 'Hendriks', '2011', '2017', 7]
# ['Guillermo', 'Heredia', '2016', '2017', 2]
# ['Ariel', 'Hernandez', '2017', '2017', 1]
# ['Cesar', 'Hernandez', '2013', '2017', 5]
# ['David', 'Hernandez', '2009', '2017', 9]
# ['Enrique', 'Hernandez', '2014', '2017', 4]
# ['Felix', 'Hernandez', '2005', '2017', 13]
# ['Gorkys', 'Hernandez', '2012', '2017', 6]
# ['Marco', 'Hernandez', '2016', '2017', 2]
# ['Teoscar', 'Hernandez', '2016', '2017', 2]
# ['Kelvin', 'Herrera', '2011', '2017', 7]
# ['Odubel', 'Herrera', '2015', '2017', 3]
# ['Chris', 'Herrmann', '2012', '2017', 6]
# ['Chris', 'Heston', '2014', '2017', 4]
# ['Jason', 'Heyward', '2010', '2017', 8]
# ['Aaron', 'Hicks', '2013', '2017', 5]
# ['John', 'Hicks', '2015', '2017', 3]
# ['Kyle', 'Higashioka', '2017', '2017', 1]
# ['Aaron', 'Hill', '2005', '2017', 13]
# ['Rich', 'Hill', '2005', '2017', 13]
# ['Jonathan', 'Holder', '2016', '2017', 2]
# ['Derek', 'Holland', '2009', '2017', 9]
# ['Greg', 'Holland', '2010', '2017', 8]
# ['Matt', 'Holliday', '2004', '2017', 14]
# ['Brock', 'Holt', '2012', '2017', 6]
# ['J.J.', 'Hoover', '2012', '2017', 6]
# ['Eric', 'Hosmer', '2011', '2017', 7]
# ['J.P.', 'Howell', '2005', '2017', 13]
# ['James', 'Hoyt', '2016', '2017', 2]
# ['ChihWei', 'Hu', '2017', '2017', 1]
# ['Daniel', 'Hudson', '2009', '2017', 9]
# ['Jared', 'Hughes', '2011', '2017', 7]
# ['Phil', 'Hughes', '2007', '2017', 11]
# ['Nick', 'Hundley', '2008', '2017', 10]
# ['Tommy', 'Hunter', '2008', '2017', 10]
# ['Chris', 'Iannetta', '2006', '2017', 12]
# ['Jose', 'Iglesias', '2011', '2017', 7]
# ['Raisel', 'Iglesias', '2015', '2017', 3]
# ['Ender', 'Inciarte', '2014', '2017', 4]
# ['Hisashi', 'Iwakuma', '2012', '2017', 6]
# ['Austin', 'Jackson', '2010', '2017', 8]
# ['Luke', 'Jackson', '2015', '2017', 3]
# ['Travis', 'Jankowski', '2015', '2017', 3]
# ['Kenley', 'Jansen', '2010', '2017', 8]
# ['John', 'Jaso', '2008', '2017', 10]
# ['Jon', 'Jay', '2010', '2017', 8]
# ['Jeremy', 'Jeffress', '2010', '2017', 8]
# ['Dan', 'Jennings', '2012', '2017', 6]
# ['Joe', 'Jimenez', '2017', '2017', 1]
# ['Ubaldo', 'Jimenez', '2006', '2017', 12]
# ['Brian', 'Johnson', '2015', '2017', 3]
# ['Jim', 'Johnson', '2006', '2017', 12]
# ['Adam', 'Jones', '2006', '2017', 12]
# ['JaCoby', 'Jones', '2016', '2017', 2]
# ['Nate', 'Jones', '2012', '2017', 6]
# ['Caleb', 'Joseph', '2014', '2017', 4]
# ['Tommy', 'Joseph', '2016', '2017', 2]
# ['Matthew', 'Joyce', '2008', '2017', 10]
# ['Aaron', 'Judge', '2016', '2017', 2]
# ['Taylor', 'Jungmann', '2015', '2017', 3]
# ['Jake', 'Junis', '2017', '2017', 1]
# ['Tommy', 'Kahnle', '2014', '2017', 4]
# ['Nate', 'Karns', '2013', '2017', 5]
# ['Keone', 'Kela', '2015', '2017', 3]
# ['Shawn', 'Kelley', '2009', '2017', 9]
# ['Joe', 'Kelly', '2012', '2017', 6]
# ['Ty', 'Kelly', '2016', '2017', 2]
# ['Matt', 'Kemp', '2006', '2017', 12]
# ['Tony', 'Kemp', '2016', '2017', 2]
# ['Howie', 'Kendrick', '2006', '2017', 12]
# ['Ian', 'Kennedy', '2007', '2017', 11]
# ['Max', 'Kepler', '2015', '2017', 3]
# ['Clayton', 'Kershaw', '2008', '2017', 10]
# ['Dallas', 'Keuchel', '2012', '2017', 6]
# ['Kevin', 'Kiermaier', '2013', '2017', 5]
# ['HyunSoo', 'Kim', '2016', '2017', 2]
# ['Craig', 'Kimbrel', '2010', '2017', 8]
# ['Ian', 'Kinsler', '2006', '2017', 12]
# ['Brandon', 'Kintzler', '2010', '2017', 8]
# ['Jason', 'Kipnis', '2011', '2017', 7]
# ['Patrick', 'Kivlehan', '2016', '2017', 2]
# ['Corey', 'Kluber', '2011', '2017', 7]
# ['Andrew', 'Knapp', '2017', '2017', 1]
# ['Corey', 'Knebel', '2014', '2017', 4]
# ['Tom', 'Koehler', '2012', '2017', 6]
# ['George', 'Kontos', '2011', '2017', 7]
# ['Pete', 'Kozma', '2011', '2017', 7]
# ['Ian', 'Krol', '2013', '2017', 5]
# ['Chad', 'Kuhl', '2016', '2017', 2]
# ['TommyLa', 'Stella', '2014', '2017', 4]
# ['John', 'Lackey', '2002', '2017', 16]
# ['Juan', 'Lagares', '2013', '2017', 5]
# ['Ryan', 'LaMarre', '2015', '2017', 3]
# ['Jake', 'Lamb', '2014', '2017', 4]
# ['Mat', 'Latos', '2009', '2017', 9]
# ['Derek', 'Law', '2016', '2017', 2]
# ['Casey', 'Lawrence', '2017', '2017', 1]
# ['Tommy', 'Layne', '2012', '2017', 6]
# ['Mike', 'Leake', '2010', '2017', 8]
# ['Wade', 'LeBlanc', '2008', '2017', 10]
# ['Jose', 'Leclerc', '2016', '2017', 2]
# ['Zach', 'Lee', '2015', '2017', 3]
# ['Mark', 'Leiter', '2017', '2017', 1]
# ['DJ', 'LeMahieu', '2011', '2017', 7]
# ['Sandy', 'Leon', '2012', '2017', 6]
# ['Dominic', 'Leone', '2014', '2017', 4]
# ['Jon', 'Lester', '2006', '2017', 12]
# ['Adam', 'Liberatore', '2015', '2017', 3]
# ['Adam', 'Lind', '2006', '2017', 12]
# ['Francisco', 'Lindor', '2015', '2017', 3]
# ['Francisco', 'Liriano', '2005', '2017', 13]
# ['Jose', 'Lobaton', '2009', '2017', 9]
# ['Boone', 'Logan', '2006', '2017', 12]
# ['Evan', 'Longoria', '2008', '2017', 10]
# ['Michael', 'Lorenzen', '2015', '2017', 3]
# ['Aaron', 'Loup', '2012', '2017', 6]
# ['Jed', 'Lowrie', '2008', '2017', 10]
# ['Jonathan', 'Lucroy', '2010', '2017', 8]
# ['Jordan', 'Lyles', '2011', '2017', 7]
# ['Lance', 'Lynn', '2011', '2017', 7]
# ['Tyler', 'Lyons', '2013', '2017', 5]
# ['Dixon', 'Machado', '2015', '2017', 3]
# ['Manny', 'Machado', '2012', '2017', 6]
# ['Ryan', 'Madson', '2003', '2017', 15]
# ['Kenta', 'Maeda', '2016', '2017', 2]
# ['Mikie', 'Mahtook', '2015', '2017', 3]
# ['Luke', 'Maile', '2015', '2017', 3]
# ['Martin', 'Maldonado', '2011', '2017', 7]
# ['Sean', 'Manaea', '2016', '2017', 2]
# ['Trey', 'Mancini', '2016', '2017', 2]
# ['Manuel', 'Margot', '2016', '2017', 2]
# ['Jhan', 'Marinez', '2010', '2017', 8]
# ['Jake', 'Marisnick', '2013', '2017', 5]
# ['Nick', 'Markakis', '2006', '2017', 12]
# ['German', 'Marquez', '2016', '2017', 2]
# ['Chris', 'Marrero', '2011', '2017', 7]
# ['Evan', 'Marshall', '2014', '2017', 4]
# ['Jefry', 'Marte', '2015', '2017', 3]
# ['Starling', 'Marte', '2012', '2017', 6]
# ['Leonys', 'Martin', '2011', '2017', 7]
# ['Russell', 'Martin', '2006', '2017', 12]
# ['Carlos', 'Martinez', '2013', '2017', 5]
# ['Jose', 'Martinez', '2016', '2017', 2]
# ['Michael', 'Martinez', '2011', '2017', 7]
# ['Nick', 'Martinez', '2014', '2017', 4]
# ['Victor', 'Martinez', '2002', '2017', 16]
# ['Jeff', 'Mathis', '2005', '2017', 13]
# ['Joe', 'Mauer', '2004', '2017', 14]
# ['Brandon', 'Maurer', '2013', '2017', 5]
# ['Bruce', 'Maxwell', '2016', '2017', 2]
# ['Jacob', 'May', '2017', '2017', 1]
# ['Cameron', 'Maybin', '2007', '2017', 11]
# ['Nomar', 'Mazara', '2016', '2017', 2]
# ['Zach', 'McAllister', '2011', '2017', 7]
# ['Brian', 'McCann', '2005', '2017', 13]
# ['James', 'McCann', '2014', '2017', 4]
# ['Brandon', 'McCarthy', '2005', '2017', 13]
# ['Lance', 'McCullers', '2015', '2017', 3]
# ['Andrew', 'McCutchen', '2009', '2017', 9]
# ['T.J.', 'McFarland', '2013', '2017', 5]
# ['Jake', 'McGee', '2010', '2017', 8]
# ['Dustin', 'McGowan', '2005', '2017', 13]
# ['Adalberto', 'Mejia', '2016', '2017', 2]
# ['Mark', 'Melancon', '2009', '2017', 9]
# ['Jordy', 'Mercer', '2012', '2017', 6]
# ['Whit', 'Merrifield', '2016', '2017', 2]
# ['Devin', 'Mesoraco', '2011', '2017', 7]
# ['Alex', 'Meyer', '2015', '2017', 3]
# ['Wade', 'Miley', '2011', '2017', 7]
# ['Andrew', 'Miller', '2006', '2017', 12]
# ['Brad', 'Miller', '2013', '2017', 5]
# ['Shelby', 'Miller', '2012', '2017', 6]
# ['Tommy', 'Milone', '2011', '2017', 7]
# ['Mike', 'Minor', '2010', '2017', 8]
# ['Ariel', 'Miranda', '2016', '2017', 2]
# ['Bryan', 'Mitchell', '2014', '2017', 4]
# ['Yadier', 'Molina', '2004', '2017', 14]
# ['Raul', 'Mondesi', '2016', '2017', 2]
# ['Frankie', 'Montas', '2015', '2017', 3]
# ['Miguel', 'Montero', '2006', '2017', 12]
# ['Rafael', 'Montero', '2014', '2017', 4]
# ['Jordan', 'Montgomery', '2017', '2017', 1]
# ['Mike', 'Montgomery', '2015', '2017', 3]
# ['Matt', 'Moore', '2011', '2017', 7]
# ['Tyler', 'Moore', '2012', '2017', 6]
# ['Kendrys', 'Morales', '2006', '2017', 12]
# ['Mitch', 'Moreland', '2010', '2017', 8]
# ['Adam', 'Morgan', '2015', '2017', 3]
# ['Mike', 'Morin', '2014', '2017', 4]
# ['Logan', 'Morrison', '2010', '2017', 8]
# ['Mike', 'Morse', '2005', '2017', 13]
# ['Charlie', 'Morton', '2008', '2017', 10]
# ['Brandon', 'Moss', '2007', '2017', 11]
# ['Jason', 'Motte', '2008', '2017', 10]
# ['Taylor', 'Motter', '2016', '2017', 2]
# ['Mike', 'Moustakas', '2011', '2017', 7]
# ['Peter', 'Moylan', '2006', '2017', 12]
# ['Daniel', 'Murphy', '2008', '2017', 10]
# ['Joe', 'Musgrove', '2016', '2017', 2]
# ['Wil', 'Myers', '2013', '2017', 5]
# ['Mike', 'Napoli', '2006', '2017', 12]
# ['Tyler', 'Naquin', '2016', '2017', 2]
# ['Omar', 'Narvaez', '2016', '2017', 2]
# ['Daniel', 'Nava', '2010', '2017', 8]
# ['Jimmy', 'Nelson', '2013', '2017', 5]
# ['Hector', 'Neris', '2014', '2017', 4]
# ['Pat', 'Neshek', '2006', '2017', 12]
# ['Dovydas', 'Neverauskas', '2017', '2017', 1]
# ['Gift', 'Ngoepe', '2017', '2017', 1]
# ['Juan', 'Nicasio', '2011', '2017', 7]
# ['Kirk', 'Nieuwenhuis', '2012', '2017', 6]
# ['Aaron', 'Nola', '2015', '2017', 3]
# ['Ricky', 'Nolasco', '2006', '2017', 12]
# ['Bud', 'Norris', '2009', '2017', 9]
# ['Daniel', 'Norris', '2014', '2017', 4]
# ['Derek', 'Norris', '2012', '2017', 6]
# ['Ivan', 'Nova', '2010', '2017', 8]
# ['Eduardo', 'Nunez', '2010', '2017', 8]
# ['Vidal', 'Nuno', '2013', '2017', 5]
# ['Darren', "O'Day", '2008', '2017', 10]
# ['Eric', "O'Flaherty", '2006', '2017', 12]
# ['Scott', 'Oberg', '2015', '2017', 3]
# ['Rougned', 'Odor', '2014', '2017', 4]
# ['Jake', 'Odorizzi', '2012', '2017', 6]
# ['Seunghwan', 'Oh', '2016', '2017', 2]
# ['Steven', 'Okert', '2016', '2017', 2]
# ['Matt', 'Olson', '2016', '2017', 2]
# ['Paulo', 'Orlando', '2015', '2017', 3]
# ['Daniel', 'Ortiz', '2017', '2017', 1]
# ['Jose', 'Osuna', '2017', '2017', 1]
# ['Roberto', 'Osuna', '2015', '2017', 3]
# ['Dan', 'Otero', '2012', '2017', 6]
# ['Adam', 'Ottavino', '2010', '2017', 8]
# ['Dillon', 'Overton', '2016', '2017', 2]
# ['Chris', 'Owings', '2013', '2017', 5]
# ['Marcell', 'Ozuna', '2013', '2017', 5]
# ['Joe', 'Panik', '2014', '2017', 4]
# ['Blake', 'Parker', '2012', '2017', 6]
# ['Jarrett', 'Parker', '2015', '2017', 3]
# ['Gerardo', 'Parra', '2009', '2017', 9]
# ['James', 'Paxton', '2013', '2017', 5]
# ['James', 'Pazos', '2015', '2017', 3]
# ['Brad', 'Peacock', '2011', '2017', 7]
# ['Steve', 'Pearce', '2007', '2017', 11]
# ['Joc', 'Pederson', '2014', '2017', 4]
# ['Dustin', 'Pedroia', '2006', '2017', 12]
# ['Mike', 'Pelfrey', '2006', '2017', 12]
# ['Hunter', 'Pence', '2007', '2017', 11]
# ['Cliff', 'Pennington', '2008', '2017', 10]
# ['David', 'Peralta', '2014', '2017', 4]
# ['Jhonny', 'Peralta', '2003', '2017', 15]
# ['Wandy', 'Peralta', '2016', '2017', 2]
# ['Wily', 'Peralta', '2012', '2017', 6]
# ['Jose', 'Peraza', '2015', '2017', 3]
# ['Luis', 'Perdomo', '2016', '2017', 2]
# ['Carlos', 'Perez', '2015', '2017', 3]
# ['Hernan', 'Perez', '2012', '2017', 6]
# ['Martin', 'Perez', '2012', '2017', 6]
# ['Oliver', 'Perez', '2002', '2017', 16]
# ['Roberto', 'Perez', '2014', '2017', 4]
# ['Salvador', 'Perez', '2011', '2017', 7]
# ['Jace', 'Peterson', '2014', '2017', 4]
# ['Shane', 'Peterson', '2013', '2017', 5]
# ['Yusmeiro', 'Petit', '2006', '2017', 12]
# ['Jake', 'Petricka', '2013', '2017', 5]
# ['Josh', 'Phegley', '2013', '2017', 5]
# ['David', 'Phelps', '2012', '2017', 6]
# ['Brandon', 'Phillips', '2002', '2017', 16]
# ['Kevin', 'Pillar', '2013', '2017', 5]
# ['Manny', 'Pina', '2011', '2017', 7]
# ['Chad', 'Pinder', '2016', '2017', 2]
# ['Michael', 'Pineda', '2011', '2017', 7]
# ['Stephen', 'Piscotty', '2015', '2017', 3]
# ['Nick', 'Pivetta', '2017', '2017', 1]
# ['Kevin', 'Plawecki', '2015', '2017', 3]
# ['Trevor', 'Plouffe', '2010', '2017', 8]
# ['Gregory', 'Polanco', '2014', '2017', 4]
# ['Jorge', 'Polanco', '2014', '2017', 4]
# ['A.J.', 'Pollock', '2012', '2017', 6]
# ['Drew', 'Pomeranz', '2011', '2017', 7]
# ['Rick', 'Porcello', '2009', '2017', 9]
# ['Buster', 'Posey', '2009', '2017', 9]
# ['Brooks', 'Pounders', '2016', '2017', 2]
# ['Boog', 'Powell', '2017', '2017', 1]
# ['Martin', 'Prado', '2006', '2017', 12]
# ['Ryan', 'Pressly', '2013', '2017', 5]
# ['Jurickson', 'Profar', '2012', '2017', 6]
# ['Austin', 'Pruitt', '2017', '2017', 1]
# ['Yasiel', 'Puig', '2013', '2017', 5]
# ['Albert', 'Pujols', '2001', '2017', 17]
# ['Zach', 'Putnam', '2011', '2017', 7]
# ['Kevin', 'Quackenbush', '2014', '2017', 4]
# ['Chad', 'Qualls', '2004', '2017', 14]
# ['Jose', 'Quintana', '2012', '2017', 6]
# ['Erasmo', 'Ramirez', '2012', '2017', 6]
# ['Hanley', 'Ramirez', '2005', '2017', 13]
# ['J.C.', 'Ramirez', '2013', '2017', 5]
# ['Jose', 'Ramirez', '2013', '2017', 5]
# ['Jose', 'Ramirez', '2014', '2017', 4]
# ['Neil', 'Ramirez', '2014', '2017', 4]
# ['Noe', 'Ramirez', '2015', '2017', 3]
# ['A.J.', 'Ramos', '2012', '2017', 6]
# ['Edubray', 'Ramos', '2016', '2017', 2]
# ['Robbie', 'Ray', '2014', '2017', 4]
# ['J.T.', 'Realmuto', '2014', '2017', 4]
# ['Anthony', 'Recker', '2011', '2017', 7]
# ['Josh', 'Reddick', '2009', '2017', 9]
# ['Addison', 'Reed', '2011', '2017', 7]
# ['Cody', 'Reed', '2016', '2017', 2]
# ['Anthony', 'Rendon', '2013', '2017', 5]
# ['Hunter', 'Renfroe', '2016', '2017', 2]
# ['Ben', 'Revere', '2010', '2017', 8]
# ['Jose', 'Reyes', '2003', '2017', 15]
# ['Mark', 'Reynolds', '2007', '2017', 11]
# ['Matt', 'Reynolds', '2016', '2017', 2]
# ['Clayton', 'Richard', '2008', '2017', 10]
# ['Garrett', 'Richards', '2011', '2017', 7]
# ['Joey', 'Rickard', '2016', '2017', 2]
# ['J.T.', 'Riddle', '2017', '2017', 1]
# ['Rene', 'Rivera', '2004', '2017', 14]
# ['T.J.', 'Rivera', '2016', '2017', 2]
# ['Felipe', 'Rivero', '2015', '2017', 3]
# ['Anthony', 'Rizzo', '2011', '2017', 7]
# ['Tanner', 'Roark', '2013', '2017', 5]
# ['Daniel', 'Robertson', '2017', '2017', 1]
# ['David', 'Robertson', '2008', '2017', 10]
# ['Drew', 'Robinson', '2017', '2017', 1]
# ['Hansel', 'Robles', '2015', '2017', 3]
# ['Fernando', 'Rodney', '2002', '2017', 16]
# ['Eduardo', 'Rodriguez', '2015', '2017', 3]
# ['Francisco', 'Rodriguez', '2002', '2017', 16]
# ['Joely', 'Rodriguez', '2016', '2017', 2]
# ['Chaz', 'Roe', '2013', '2017', 5]
# ['Taylor', 'Rogers', '2016', '2017', 2]
# ['Miguel', 'Rojas', '2014', '2017', 4]
# ['Sal', 'Romano', '2017', '2017', 1]
# ['Enny', 'Romero', '2013', '2017', 5]
# ['Andrew', 'Romine', '2010', '2017', 8]
# ['Austin', 'Romine', '2011', '2017', 7]
# ['Sergio', 'Romo', '2008', '2017', 10]
# ['Bruce', 'Rondon', '2013', '2017', 5]
# ['Hector', 'Rondon', '2013', '2017', 5]
# ['Adam', 'Rosales', '2008', '2017', 10]
# ['Eddie', 'Rosario', '2015', '2017', 3]
# ['Trevor', 'Rosenthal', '2012', '2017', 6]
# ['Joe', 'Ross', '2015', '2017', 3]
# ['Robbie', 'Ross', '2012', '2017', 6]
# ['Ryan', 'Rua', '2014', '2017', 4]
# ['Carlos', 'Ruiz', '2006', '2017', 12]
# ['Cameron', 'Rupp', '2013', '2017', 5]
# ['Chris', 'Rusin', '2012', '2017', 6]
# ['Addison', 'Russell', '2015', '2017', 3]
# ['Josh', 'Rutledge', '2012', '2017', 6]
# ['Kyle', 'Ryan', '2014', '2017', 4]
# ['HyunJin', 'Ryu', '2013', '2017', 5]
# ['Marc', 'Rzepczynski', '2009', '2017', 9]
# ['CC', 'Sabathia', '2001', '2017', 17]
# ['Tyler', 'Saladino', '2015', '2017', 3]
# ['Fernando', 'Salas', '2010', '2017', 8]
# ['Danny', 'Salazar', '2013', '2017', 5]
# ['Chris', 'Sale', '2010', '2017', 8]
# ['Jarrod', 'Saltalamacchia', '2007', '2017', 11]
# ['Jeff', 'Samardzija', '2008', '2017', 10]
# ['Aaron', 'Sanchez', '2014', '2017', 4]
# ['Anibal', 'Sanchez', '2006', '2017', 12]
# ['Gary', 'Sanchez', '2015', '2017', 3]
# ['Hector', 'Sanchez', '2011', '2017', 7]
# ['Yolmer', 'Sanchez', '2014', '2017', 4]
# ['Pablo', 'Sandoval', '2008', '2017', 10]
# ['Miguel', 'Sano', '2015', '2017', 3]
# ['Carlos', 'Santana', '2010', '2017', 8]
# ['Danny', 'Santana', '2014', '2017', 4]
# ['Domingo', 'Santana', '2014', '2017', 4]
# ['Ervin', 'Santana', '2005', '2017', 13]
# ['Hector', 'Santiago', '2011', '2017', 7]
# ['Luis', 'Sardinas', '2014', '2017', 4]
# ['Michael', 'Saunders', '2009', '2017', 9]
# ['Warwick', 'Saupold', '2016', '2017', 2]
# ['Scott', 'Schebler', '2015', '2017', 3]
# ['Max', 'Scherzer', '2008', '2017', 10]
# ['Ryan', 'Schimpf', '2016', '2017', 2]
# ['Jonathan', 'Schoop', '2013', '2017', 5]
# ['Kyle', 'Schwarber', '2015', '2017', 3]
# ['Robby', 'Scott', '2016', '2017', 2]
# ['Evan', 'Scribner', '2011', '2017', 7]
# ['Corey', 'Seager', '2015', '2017', 3]
# ['Kyle', 'Seager', '2011', '2017', 7]
# ['Rob', 'Segedin', '2016', '2017', 2]
# ['Jean', 'Segura', '2012', '2017', 6]
# ['Steve', 'Selsky', '2016', '2017', 2]
# ['Marcus', 'Semien', '2013', '2017', 5]
# ['Antonio', 'Senzatela', '2017', '2017', 1]
# ['Luis', 'Severino', '2015', '2017', 3]
# ['Paul', 'Sewald', '2017', '2017', 1]
# ['Bryan', 'Shaw', '2011', '2017', 7]
# ['Travis', 'Shaw', '2015', '2017', 3]
# ['James', 'Shields', '2006', '2017', 12]
# ['Matt', 'Shoemaker', '2013', '2017', 5]
# ['Chasen', 'Shreve', '2014', '2017', 4]
# ['Kevin', 'Siegrist', '2013', '2017', 5]
# ['Andrelton', 'Simmons', '2012', '2017', 6]
# ['Tony', 'Sipp', '2009', '2017', 9]
# ['Tyler', 'Skaggs', '2012', '2017', 6]
# ['Joe', 'Smith', '2007', '2017', 11]
# ['Kevan', 'Smith', '2016', '2017', 2]
# ['Mallex', 'Smith', '2016', '2017', 2]
# ['Seth', 'Smith', '2007', '2017', 11]
# ['Justin', 'Smoak', '2010', '2017', 8]
# ['Josh', 'Smoker', '2016', '2017', 2]
# ['Blake', 'Snell', '2016', '2017', 2]
# ['Miguel', 'Socolovich', '2012', '2017', 6]
# ['Yangervis', 'Solarte', '2014', '2017', 4]
# ['Sammy', 'Solis', '2015', '2017', 3]
# ['Joakim', 'Soria', '2007', '2017', 11]
# ['Geovany', 'Soto', '2005', '2017', 13]
# ['Steven', 'Souza', '2014', '2017', 4]
# ['Denard', 'Span', '2008', '2017', 10]
# ['Cory', 'Spangenberg', '2014', '2017', 4]
# ['George', 'Springer', '2014', '2017', 4]
# ['Craig', 'Stammen', '2009', '2017', 9]
# ['Giancarlo', 'Stanton', '2010', '2017', 8]
# ['Brock', 'Stassi', '2017', '2017', 1]
# ['Robert', 'Stephenson', '2016', '2017', 2]
# ['Chris', 'Stewart', '2006', '2017', 12]
# ['Drew', 'Storen', '2010', '2017', 8]
# ['Trevor', 'Story', '2016', '2017', 2]
# ['Matt', 'Strahm', '2016', '2017', 2]
# ['Dan', 'Straily', '2012', '2017', 6]
# ['Stephen', 'Strasburg', '2010', '2017', 8]
# ['Chris', 'Stratton', '2016', '2017', 2]
# ['Hunter', 'Strickland', '2014', '2017', 4]
# ['Ross', 'Stripling', '2016', '2017', 2]
# ['Marcus', 'Stroman', '2014', '2017', 4]
# ['Pedro', 'Strop', '2009', '2017', 9]
# ['Drew', 'Stubbs', '2009', '2017', 9]
# ['Eugenio', 'Suarez', '2014', '2017', 4]
# ['Jesus', 'Sucre', '2013', '2017', 5]
# ['Brent', 'Suter', '2016', '2017', 2]
# ['Ichiro', 'Suzuki', '2001', '2017', 17]
# ['Kurt', 'Suzuki', '2007', '2017', 11]
# ['Dansby', 'Swanson', '2016', '2017', 2]
# ['Anthony', 'Swarzak', '2009', '2017', 9]
# ['Noah', 'Syndergaard', '2015', '2017', 3]
# ['Matt', 'Szczur', '2014', '2017', 4]
# ['Jameson', 'Taillon', '2016', '2017', 2]
# ['Masahiro', 'Tanaka', '2014', '2017', 4]
# ['Raimel', 'Tapia', '2016', '2017', 2]
# ['Ben', 'Taylor', '2017', '2017', 1]
# ['Chris', 'Taylor', '2014', '2017', 4]
# ['Michael', 'Taylor', '2014', '2017', 4]
# ['Junichi', 'Tazawa', '2009', '2017', 9]
# ['Julio', 'Teheran', '2011', '2017', 7]
# ['Ryan', 'Tepera', '2015', '2017', 3]
# ['Eric', 'Thames', '2011', '2017', 7]
# ['Trayce', 'Thompson', '2015', '2017', 3]
# ['Andrew', 'Toles', '2016', '2017', 2]
# ['Yasmany', 'Tomas', '2015', '2017', 3]
# ['Josh', 'Tomlin', '2010', '2017', 8]
# ['Kelby', 'Tomlinson', '2015', '2017', 3]
# ['Michael', 'Tonkin', '2013', '2017', 5]
# ['Luis', 'Torrens', '2017', '2017', 1]
# ['Carlos', 'Torres', '2009', '2017', 9]
# ['Jose', 'Torres', '2016', '2017', 2]
# ['Ronald', 'Torreyes', '2015', '2017', 3]
# ['Devon', 'Travis', '2015', '2017', 3]
# ['Blake', 'Treinen', '2014', '2017', 4]
# ['Andrew', 'Triggs', '2016', '2017', 2]
# ['Mike', 'Trout', '2011', '2017', 7]
# ['Mark', 'Trumbo', '2010', '2017', 8]
# ['Sam', 'Tuivailala', '2014', '2017', 4]
# ['Troy', 'Tulowitzki', '2006', '2017', 12]
# ['Jacob', 'Turner', '2011', '2017', 7]
# ['Justin', 'Turner', '2009', '2017', 9]
# ['Stuart', 'Turner', '2017', '2017', 1]
# ['Trea', 'Turner', '2015', '2017', 3]
# ['Koji', 'Uehara', '2009', '2017', 9]
# ['Justin', 'Upton', '2007', '2017', 11]
# ['Jose', 'Urena', '2015', '2017', 3]
# ['Julio', 'Urias', '2016', '2017', 2]
# ['Chase', 'Utley', '2003', '2017', 15]
# ['Pat', 'Valaika', '2016', '2017', 2]
# ['Cesar', 'Valdez', '2010', '2017', 8]
# ['Jose', 'Valdez', '2015', '2017', 3]
# ['Danny', 'Valencia', '2010', '2017', 8]
# ['ScottVan', 'Slyke', '2012', '2017', 6]
# ['Jason', 'Vargas', '2005', '2017', 13]
# ['Kennys', 'Vargas', '2014', '2017', 4]
# ['Christian', 'Vazquez', '2014', '2017', 4]
# ['Vince', 'Velasquez', '2015', '2017', 3]
# ['Justin', 'Verlander', '2005', '2017', 13]
# ['Logan', 'Verrett', '2015', '2017', 3]
# ['Jonathan', 'Villar', '2013', '2017', 5]
# ['Nick', 'Vincent', '2012', '2017', 6]
# ['Arodys', 'Vizcaino', '2011', '2017', 7]
# ['Daniel', 'Vogelbach', '2016', '2017', 2]
# ['Stephen', 'Vogt', '2012', '2017', 6]
# ['Edinson', 'Volquez', '2005', '2017', 13]
# ['Joey', 'Votto', '2007', '2017', 11]
# ['Michael', 'Wacha', '2013', '2017', 5]
# ['Adam', 'Wainwright', '2005', '2017', 13]
# ['Neil', 'Walker', '2009', '2017', 9]
# ['Taijuan', 'Walker', '2013', '2017', 5]
# ['Adam', 'Warren', '2012', '2017', 6]
# ['Tony', 'Watson', '2011', '2017', 7]
# ['Jered', 'Weaver', '2006', '2017', 12]
# ['Rickie', 'Weeks', '2003', '2017', 15]
# ['Jayson', 'Werth', '2002', '2017', 16]
# ['Zack', 'Wheeler', '2013', '2017', 5]
# ['Chase', 'Whitley', '2014', '2017', 4]
# ['Matt', 'Wieters', '2009', '2017', 9]
# ['Tom', 'Wilhelmsen', '2011', '2017', 7]
# ['Trevor', 'Williams', '2016', '2017', 2]
# ['Alex', 'Wilson', '2013', '2017', 5]
# ['Justin', 'Wilson', '2012', '2017', 6]
# ['Tyler', 'Wilson', '2015', '2017', 3]
# ['Jesse', 'Winker', '2017', '2017', 1]
# ['Matt', 'Wisler', '2015', '2017', 3]
# ['Nick', 'Wittgren', '2016', '2017', 2]
# ['Tony', 'Wolters', '2016', '2017', 2]
# ['Kolten', 'Wong', '2013', '2017', 5]
# ['Alex', 'Wood', '2013', '2017', 5]
# ['Blake', 'Wood', '2010', '2017', 8]
# ['Travis', 'Wood', '2010', '2017', 8]
# ['Daniel', 'Wright', '2016', '2017', 2]
# ['Steven', 'Wright', '2013', '2017', 5]
# ['Kirby', 'Yates', '2014', '2017', 4]
# ['Christian', 'Yelich', '2013', '2017', 5]
# ['Michael', 'Ynoa', '2016', '2017', 2]
# ['Chris', 'Young', '2004', '2017', 14]
# ['Chris', 'Young', '2006', '2017', 12]
# ['Brad', 'Ziegler', '2008', '2017', 10]
# ['Ryan', 'Zimmerman', '2005', '2017', 13]
# ['Jordan', 'Zimmermann', '2009', '2017', 9]
# ['Ben', 'Zobrist', '2006', '2017', 12]
# ['Mike', 'Zunino', '2013', '2017', 5]
# ['Tony', 'Zych', '2015', '2017', 3]

# %% [markdown]
# ### Hall of Famers

# %%
#the original html had a plus for every HOF player, so I just left it in. 
for career in split_player_list:
    if "+" in career[1]:
        print (career)
# Out:
# ['Hank', 'Aaron+', '1954', '1976', 23]
# ['Pete', 'Alexander+', '1911', '1930', 20]
# ['Roberto', 'Alomar+', '1988', '2004', 17]
# ['Walter', 'Alston+', '1936', '1936', 1]
# ['Sparky', 'Anderson+', '1959', '1959', 1]
# ['Cap', 'Anson+', '1871', '1897', 27]
# ['Luis', 'Aparicio+', '1956', '1973', 18]
# ['Luke', 'Appling+', '1930', '1950', 21]
# ['Richie', 'Ashburn+', '1948', '1962', 15]
# ['Earl', 'Averill+', '1929', '1941', 13]
# ['Jeff', 'Bagwell+', '1991', '2005', 15]
# ['HomeRun', 'Baker+', '1908', '1922', 15]
# ['Dave', 'Bancroft+', '1915', '1930', 16]
# ['Ernie', 'Banks+', '1953', '1971', 19]
# ['Jake', 'Beckley+', '1888', '1907', 20]
# ['Johnny', 'Bench+', '1967', '1983', 17]
# ['Chief', 'Bender+', '1903', '1925', 23]
# ['Yogi', 'Berra+', '1946', '1965', 20]
# ['Craig', 'Biggio+', '1988', '2007', 20]
# ['Bert', 'Blyleven+', '1970', '1992', 23]
# ['Wade', 'Boggs+', '1982', '1999', 18]
# ['Jim', 'Bottomley+', '1922', '1937', 16]
# ['Lou', 'Boudreau+', '1938', '1952', 15]
# ['Roger', 'Bresnahan+', '1897', '1915', 19]
# ['George', 'Brett+', '1973', '1993', 21]
# ['Lou', 'Brock+', '1961', '1979', 19]
# ['Dan', 'Brouthers+', '1879', '1904', 26]
# ['Mordecai', 'Brown+', '1903', '1916', 14]
# ['Willard', 'Brown+', '1947', '1947', 1]
# ['Jim', 'Bunning+', '1955', '1971', 17]
# ['Jesse', 'Burkett+', '1890', '1905', 16]
# ['Roy', 'Campanella+', '1948', '1957', 10]
# ['Rod', 'Carew+', '1967', '1985', 19]
# ['Max', 'Carey+', '1910', '1929', 20]
# ['Steve', 'Carlton+', '1965', '1988', 24]
# ['Gary', 'Carter+', '1974', '1992', 19]
# ['Orlando', 'Cepeda+', '1958', '1974', 17]
# ['Frank', 'Chance+', '1898', '1914', 17]
# ['Jack', 'Chesbro+', '1899', '1909', 11]
# ['Fred', 'Clarke+', '1894', '1915', 22]
# ['John', 'Clarkson+', '1882', '1894', 13]
# ['Roberto', 'Clemente+', '1955', '1972', 18]
# ['Ty', 'Cobb+', '1905', '1928', 24]
# ['Mickey', 'Cochrane+', '1925', '1937', 13]
# ['Eddie', 'Collins+', '1906', '1930', 25]
# ['Jimmy', 'Collins+', '1895', '1908', 14]
# ['Earle', 'Combs+', '1924', '1935', 12]
# ['Charlie', 'Comiskey+', '1882', '1894', 13]
# ['Jocko', 'Conlan+', '1934', '1935', 2]
# ['Roger', 'Connor+', '1880', '1897', 18]
# ['Stan', 'Coveleski+', '1912', '1928', 17]
# ['Bobby', 'Cox+', '1968', '1969', 2]
# ['Sam', 'Crawford+', '1899', '1917', 19]
# ['Joe', 'Cronin+', '1926', '1945', 20]
# ['Candy', 'Cummings+', '1872', '1877', 6]
# ['Kiki', 'Cuyler+', '1921', '1938', 18]
# ['George', 'Davis+', '1890', '1909', 20]
# ['Andre', 'Dawson+', '1976', '1996', 21]
# ['Dizzy', 'Dean+', '1930', '1947', 18]
# ['Ed', 'Delahanty+', '1888', '1903', 16]
# ['Bill', 'Dickey+', '1928', '1946', 19]
# ['Joe', 'DiMaggio+', '1936', '1951', 16]
# ['Larry', 'Doby+', '1947', '1959', 13]
# ['Bobby', 'Doerr+', '1937', '1951', 15]
# ['Don', 'Drysdale+', '1956', '1969', 14]
# ['Hugh', 'Duffy+', '1888', '1906', 19]
# ['Leo', 'Durocher+', '1925', '1945', 21]
# ['Dennis', 'Eckersley+', '1975', '1998', 24]
# ['Johnny', 'Evers+', '1902', '1929', 28]
# ['Buck', 'Ewing+', '1880', '1897', 18]
# ['Red', 'Faber+', '1914', '1933', 20]
# ['Bob', 'Feller+', '1936', '1956', 21]
# ['Rick', 'Ferrell+', '1929', '1947', 19]
# ['Rollie', 'Fingers+', '1968', '1985', 18]
# ['Carlton', 'Fisk+', '1969', '1993', 25]
# ['Elmer', 'Flick+', '1898', '1910', 13]
# ['Whitey', 'Ford+', '1950', '1967', 18]
# ['Nellie', 'Fox+', '1947', '1965', 19]
# ['Jimmie', 'Foxx+', '1925', '1945', 21]
# ['Frankie', 'Frisch+', '1919', '1937', 19]
# ['Pud', 'Galvin+', '1875', '1892', 18]
# ['Lou', 'Gehrig+', '1923', '1939', 17]
# ['Charlie', 'Gehringer+', '1924', '1942', 19]
# ['Bob', 'Gibson+', '1959', '1975', 17]
# ['Tom', 'Glavine+', '1987', '2008', 22]
# ['Lefty', 'Gomez+', '1930', '1943', 14]
# ['Joe', 'Gordon+', '1938', '1950', 13]
# ['Goose', 'Goslin+', '1921', '1938', 18]
# ['Rich', 'Gossage+', '1972', '1994', 23]
# ['Hank', 'Greenberg+', '1930', '1947', 18]
# ['Ken', 'Griffey+', '1989', '2010', 22]
# ['Clark', 'Griffith+', '1891', '1914', 24]
# ['Burleigh', 'Grimes+', '1916', '1934', 19]
# ['Lefty', 'Grove+', '1925', '1941', 17]
# ['Tony', 'Gwynn+', '1982', '2001', 20]
# ['Chick', 'Hafey+', '1924', '1937', 14]
# ['Jesse', 'Haines+', '1918', '1937', 20]
# ['Billy', 'Hamilton+', '1888', '1901', 14]
# ['Ned', 'Hanlon+', '1880', '1892', 13]
# ['Bucky', 'Harris+', '1919', '1931', 13]
# ['Gabby', 'Hartnett+', '1922', '1941', 20]
# ['Harry', 'Heilmann+', '1914', '1932', 19]
# ['Rickey', 'Henderson+', '1979', '2003', 25]
# ['Billy', 'Herman+', '1931', '1947', 17]
# ['Whitey', 'Herzog+', '1956', '1963', 8]
# ['Harry', 'Hooper+', '1909', '1925', 17]
# ['Rogers', 'Hornsby+', '1915', '1937', 23]
# ['Waite', 'Hoyt+', '1918', '1938', 21]
# ['Carl', 'Hubbell+', '1928', '1943', 16]
# ['Miller', 'Huggins+', '1904', '1916', 13]
# ['Catfish', 'Hunter+', '1965', '1979', 15]
# ['Monte', 'Irvin+', '1949', '1956', 8]
# ['Reggie', 'Jackson+', '1967', '1987', 21]
# ['Travis', 'Jackson+', '1922', '1936', 15]
# ['Fergie', 'Jenkins+', '1965', '1983', 19]
# ['Hughie', 'Jennings+', '1891', '1918', 28]
# ['Randy', 'Johnson+', '1988', '2009', 22]
# ['Walter', 'Johnson+', '1907', '1927', 21]
# ['Addie', 'Joss+', '1902', '1910', 9]
# ['Al', 'Kaline+', '1953', '1974', 22]
# ['Tim', 'Keefe+', '1880', '1893', 14]
# ['Willie', 'Keeler+', '1892', '1910', 19]
# ['George', 'Kell+', '1943', '1957', 15]
# ['Joe', 'Kelley+', '1891', '1908', 18]
# ['HighPockets', 'Kelly+', '1915', '1932', 18]
# ['King', 'Kelly+', '1878', '1893', 16]
# ['Harmon', 'Killebrew+', '1954', '1975', 22]
# ['Ralph', 'Kiner+', '1946', '1955', 10]
# ['Chuck', 'Klein+', '1928', '1944', 17]
# ['Sandy', 'Koufax+', '1955', '1966', 12]
# ['TonyLa', 'Russa+', '1963', '1973', 11]
# ['Nap', 'Lajoie+', '1896', '1916', 21]
# ['Barry', 'Larkin+', '1986', '2004', 19]
# ['Tom', 'Lasorda+', '1954', '1956', 3]
# ['Tony', 'Lazzeri+', '1926', '1939', 14]
# ['Bob', 'Lemon+', '1941', '1958', 18]
# ['Freddie', 'Lindstrom+', '1924', '1936', 13]
# ['Ernie', 'Lombardi+', '1931', '1947', 17]
# ['Al', 'Lopez+', '1928', '1947', 20]
# ['Ted', 'Lyons+', '1923', '1946', 24]
# ['Connie', 'Mack+', '1886', '1896', 11]
# ['Greg', 'Maddux+', '1986', '2008', 23]
# ['Mickey', 'Mantle+', '1951', '1968', 18]
# ['Heinie', 'Manush+', '1923', '1939', 17]
# ['Rabbit', 'Maranville+', '1912', '1935', 24]
# ['Juan', 'Marichal+', '1960', '1975', 16]
# ['Rube', 'Marquard+', '1908', '1925', 18]
# ['Pedro', 'Martinez+', '1992', '2009', 18]
# ['Eddie', 'Mathews+', '1952', '1968', 17]
# ['Christy', 'Mathewson+', '1900', '1916', 17]
# ['Willie', 'Mays+', '1951', '1973', 23]
# ['Bill', 'Mazeroski+', '1956', '1972', 17]
# ['Tommy', 'McCarthy+', '1884', '1896', 13]
# ['Willie', 'McCovey+', '1959', '1980', 22]
# ['Joe', 'McGinnity+', '1899', '1908', 10]
# ['John', 'McGraw+', '1891', '1907', 17]
# ['Bill', 'McKechnie+', '1907', '1920', 14]
# ['Bid', 'McPhee+', '1882', '1899', 18]
# ['Joe', 'Medwick+', '1932', '1948', 17]
# ['Johnny', 'Mize+', '1936', '1953', 18]
# ['Paul', 'Molitor+', '1978', '1998', 21]
# ['Joe', 'Morgan+', '1963', '1984', 22]
# ['Eddie', 'Murray+', '1977', '1997', 21]
# ['Stan', 'Musial+', '1941', '1963', 23]
# ['Hal', 'Newhouser+', '1939', '1955', 17]
# ['Kid', 'Nichols+', '1890', '1906', 17]
# ['Phil', 'Niekro+', '1964', '1987', 24]
# ['Hank', "O'Day+", '1884', '1890', 7]
# ['Jim', "O'Rourke+", '1872', '1904', 33]
# ['Mel', 'Ott+', '1926', '1947', 22]
# ['Satchel', 'Paige+', '1948', '1965', 18]
# ['Jim', 'Palmer+', '1965', '1984', 20]
# ['Herb', 'Pennock+', '1912', '1934', 23]
# ['Tony', 'Perez+', '1964', '1986', 23]
# ['Gaylord', 'Perry+', '1962', '1983', 22]
# ['Mike', 'Piazza+', '1992', '2007', 16]
# ['Eddie', 'Plank+', '1901', '1917', 17]
# ['Kirby', 'Puckett+', '1984', '1995', 12]
# ['OldHoss', 'Radbourn+', '1880', '1891', 12]
# ['Tim', 'Raines+', '1979', '2002', 24]
# ['PeeWee', 'Reese+', '1940', '1958', 19]
# ['Jim', 'Rice+', '1974', '1989', 16]
# ['Sam', 'Rice+', '1915', '1934', 20]
# ['Branch', 'Rickey+', '1905', '1914', 10]
# ['Cal', 'Ripken+', '1981', '2001', 21]
# ['Eppa', 'Rixey+', '1912', '1933', 22]
# ['Phil', 'Rizzuto+', '1941', '1956', 16]
# ['Robin', 'Roberts+', '1948', '1966', 19]
# ['Brooks', 'Robinson+', '1955', '1977', 23]
# ['Frank', 'Robinson+', '1956', '1976', 21]
# ['Jackie', 'Robinson+', '1947', '1956', 10]
# ['Wilbert', 'Robinson+', '1886', '1902', 17]
# ['Ivan', 'Rodriguez+', '1991', '2011', 21]
# ['Edd', 'Roush+', '1913', '1931', 19]
# ['Red', 'Ruffing+', '1924', '1947', 24]
# ['Amos', 'Rusie+', '1889', '1901', 13]
# ['Babe', 'Ruth+', '1914', '1935', 22]
# ['Nolan', 'Ryan+', '1966', '1993', 28]
# ['Ryne', 'Sandberg+', '1981', '1997', 17]
# ['Ron', 'Santo+', '1960', '1974', 15]
# ['Ray', 'Schalk+', '1912', '1929', 18]
# ['Mike', 'Schmidt+', '1972', '1989', 18]
# ['Red', 'Schoendienst+', '1945', '1963', 19]
# ['Tom', 'Seaver+', '1967', '1986', 20]
# ['Joe', 'Sewell+', '1920', '1933', 14]
# ['Al', 'Simmons+', '1924', '1944', 21]
# ['George', 'Sisler+', '1915', '1930', 16]
# ['Enos', 'Slaughter+', '1938', '1959', 22]
# ['Ozzie', 'Smith+', '1978', '1996', 19]
# ['John', 'Smoltz+', '1988', '2009', 22]
# ['Duke', 'Snider+', '1947', '1964', 18]
# ['Billy', 'Southworth+', '1913', '1929', 17]
# ['Warren', 'Spahn+', '1942', '1965', 24]
# ['Al', 'Spalding+', '1871', '1878', 8]
# ['Tris', 'Speaker+', '1907', '1928', 22]
# ['Willie', 'Stargell+', '1962', '1982', 21]
# ['Casey', 'Stengel+', '1912', '1925', 14]
# ['Bruce', 'Sutter+', '1976', '1988', 13]
# ['Don', 'Sutton+', '1966', '1988', 23]
# ['Bill', 'Terry+', '1923', '1936', 14]
# ['Frank', 'Thomas+', '1990', '2008', 19]
# ['Sam', 'Thompson+', '1885', '1906', 22]
# ['Joe', 'Tinker+', '1902', '1916', 15]
# ['Joe', 'Torre+', '1960', '1977', 18]
# ['Pie', 'Traynor+', '1920', '1937', 18]
# ['Dazzy', 'Vance+', '1915', '1935', 21]
# ['Arky', 'Vaughan+', '1932', '1948', 17]
# ['Rube', 'Waddell+', '1897', '1910', 14]
# ['Honus', 'Wagner+', '1897', '1917', 21]
# ['Bobby', 'Wallace+', '1894', '1918', 25]
# ['Ed', 'Walsh+', '1904', '1917', 14]
# ['Lloyd', 'Waner+', '1927', '1945', 19]
# ['Paul', 'Waner+', '1926', '1945', 20]
# ['John', 'Ward+', '1878', '1894', 17]
# ['Mickey', 'Welch+', '1880', '1892', 13]
# ['Zack', 'Wheat+', '1909', '1927', 19]
# ['Deacon', 'White+', '1871', '1890', 20]
# ['Hoyt', 'Wilhelm+', '1952', '1972', 21]
# ['Billy', 'Williams+', '1959', '1976', 18]
# ['Dick', 'Williams+', '1951', '1964', 14]
# ['Ted', 'Williams+', '1939', '1960', 22]
# ['Vic', 'Willis+', '1898', '1910', 13]
# ['Hack', 'Wilson+', '1923', '1934', 12]
# ['Dave', 'Winfield+', '1973', '1995', 23]
# ['George', 'Wright+', '1871', '1882', 12]
# ['Harry', 'Wright+', '1871', '1877', 7]
# ['Early', 'Wynn+', '1939', '1963', 25]
# ['Carl', 'Yastrzemski+', '1961', '1983', 23]
# ['Cy', 'Young+', '1890', '1911', 22]
# ['Ross', 'Youngs+', '1917', '1926', 10]
# ['Robin', 'Yount+', '1974', '1993', 20]

# %% [markdown]
# ### Players with long careers

# %%
long_careers = []
for career in split_player_list:
    if career[4] > 20:
        long_careers.append(career)
        print (career)
print ("number of players:", len(long_careers))
# Out:
# ['Hank', 'Aaron+', '1954', '1976', 23]
# ['Babe', 'Adams', '1906', '1926', 21]
# ['Nick', 'Altrock', '1898', '1933', 36]
# ['Cap', 'Anson+', '1871', '1897', 27]
# ['Luke', 'Appling+', '1930', '1950', 21]
# ['Jimmy', 'Austin', '1909', '1929', 21]
# ['Harold', 'Baines', '1980', '2001', 22]
# ['Miguel', 'Batista', '1992', '2012', 21]
# ['BoomBoom', 'Beck', '1924', '1945', 22]
# ['Chief', 'Bender+', '1903', '1925', 23]
# ['Bert', 'Blyleven+', '1970', '1992', 23]
# ['Barry', 'Bonds', '1986', '2007', 22]
# ['George', 'Brett+', '1973', '1993', 21]
# ['Dan', 'Brouthers+', '1879', '1904', 26]
# ['Bill', 'Buckner', '1969', '1990', 22]
# ['Guy', 'Bush', '1923', '1945', 23]
# ['Earl', 'Caldwell', '1928', '1948', 21]
# ['Fred', 'Carisch', '1903', '1923', 21]
# ['Steve', 'Carlton+', '1965', '1988', 24]
# ['Phil', 'Cavarretta', '1934', '1955', 22]
# ['Fred', 'Clarke+', '1894', '1915', 22]
# ['Roger', 'Clemens', '1984', '2007', 24]
# ['Ty', 'Cobb+', '1905', '1928', 24]
# ['Eddie', 'Collins+', '1906', '1930', 25]
# ['Bartolo', 'Colon', '1997', '2017', 21]
# ['Johnny', 'Cooney', '1921', '1944', 24]
# ['Lave', 'Cross', '1887', '1907', 21]
# ['Bill', 'Dahlen', '1891', '1911', 21]
# ['Danny', 'Darwin', '1978', '1998', 21]
# ['Harry', 'Davis', '1895', '1917', 23]
# ['Andre', 'Dawson+', '1976', '1996', 21]
# ['Rick', 'Dempsey', '1969', '1992', 24]
# ['Murry', 'Dickson', '1939', '1959', 21]
# ['Bill', 'Donovan', '1898', '1918', 21]
# ['Leo', 'Durocher+', '1925', '1945', 21]
# ['Jimmy', 'Dykes', '1918', '1939', 22]
# ['Dennis', 'Eckersley+', '1975', '1998', 24]
# ['Darrell', 'Evans', '1969', '1989', 21]
# ['Johnny', 'Evers+', '1902', '1929', 28]
# ['Ron', 'Fairly', '1958', '1978', 21]
# ['Bob', 'Feller+', '1936', '1956', 21]
# ['Carlton', 'Fisk+', '1969', '1993', 25]
# ['Jimmie', 'Foxx+', '1925', '1945', 21]
# ['John', 'Franco', '1984', '2005', 22]
# ['Julio', 'Franco', '1982', '2007', 26]
# ['Tom', 'Glavine+', '1987', '2008', 22]
# ['Kid', 'Gleason', '1888', '1912', 25]
# ['Mike', 'Gonzalez', '1912', '1932', 21]
# ['Tom', 'Gordon', '1988', '2009', 22]
# ['Rich', 'Gossage+', '1972', '1994', 23]
# ['Hank', 'Gowdy', '1910', '1930', 21]
# ['Ken', 'Griffey+', '1989', '2010', 22]
# ['Clark', 'Griffith+', '1891', '1914', 24]
# ['Charlie', 'Grimm', '1916', '1936', 21]
# ['Grover', 'Hartley', '1911', '1934', 24]
# ['LaTroy', 'Hawkins', '1995', '2015', 21]
# ['Rickey', 'Henderson+', '1979', '2003', 25]
# ['Gil', 'Hodges', '1943', '1963', 21]
# ['Rick', 'Honeycutt', '1977', '1997', 21]
# ['Rogers', 'Hornsby+', '1915', '1937', 23]
# ['Charlie', 'Hough', '1970', '1994', 25]
# ['Waite', 'Hoyt+', '1918', '1938', 21]
# ['Reggie', 'Jackson+', '1967', '1987', 21]
# ['Hughie', 'Jennings+', '1891', '1918', 28]
# ['Tommy', 'John', '1963', '1989', 27]
# ['Randy', 'Johnson+', '1988', '2009', 22]
# ['Walter', 'Johnson+', '1907', '1927', 21]
# ['SadSam', 'Jones', '1914', '1935', 22]
# ['Jim', 'Kaat', '1959', '1983', 25]
# ['Al', 'Kaline+', '1953', '1974', 22]
# ['Harmon', 'Killebrew+', '1954', '1975', 22]
# ['Nap', 'Lajoie+', '1896', '1916', 21]
# ['Arlie', 'Latham', '1880', '1909', 30]
# ['Tommy', 'Leach', '1898', '1918', 21]
# ['Dutch', 'Leonard', '1933', '1953', 21]
# ['Dolf', 'Luque', '1914', '1935', 22]
# ['Ted', 'Lyons+', '1923', '1946', 24]
# ['Greg', 'Maddux+', '1986', '2008', 23]
# ['Rabbit', 'Maranville+', '1912', '1935', 24]
# ['Dennis', 'Martinez', '1976', '1998', 23]
# ['Willie', 'Mays+', '1951', '1973', 23]
# ['Tim', 'McCarver', '1959', '1980', 22]
# ['Willie', 'McCovey+', '1959', '1980', 22]
# ['Lindy', 'McDaniel', '1955', '1975', 21]
# ['Deacon', 'McGuire', '1884', '1912', 29]
# ['Cal', 'McLish', '1944', '1964', 21]
# ['Jose', 'Mesa', '1987', '2007', 21]
# ['Minnie', 'Minoso', '1949', '1980', 32]
# ['Clarence', 'Mitchell', '1911', '1932', 22]
# ['Paul', 'Molitor+', '1978', '1998', 21]
# ['Joe', 'Morgan+', '1963', '1984', 22]
# ['Mike', 'Morgan', '1978', '2002', 25]
# ['Manny', 'Mota', '1962', '1982', 21]
# ['Jamie', 'Moyer', '1986', '2012', 27]
# ['Terry', 'Mulholland', '1986', '2006', 21]
# ['Eddie', 'Murray+', '1977', '1997', 21]
# ['Stan', 'Musial+', '1941', '1963', 23]
# ['Graig', 'Nettles', '1967', '1988', 22]
# ['Bobo', 'Newsom', '1929', '1953', 25]
# ['Joe', 'Niekro', '1967', '1988', 22]
# ['Phil', 'Niekro+', '1964', '1987', 24]
# ['Joe', 'Nuxhall', '1944', '1966', 23]
# ['Jack', "O'Connor", '1887', '1910', 24]
# ['Bob', "O'Farrell", '1915', '1935', 21]
# ['Charley', "O'Leary", '1904', '1934', 31]
# ['Jim', "O'Rourke+", '1872', '1904', 33]
# ['Darren', 'Oliver', '1993', '2013', 21]
# ['Jesse', 'Orosco', '1979', '2003', 25]
# ['Mel', 'Ott+', '1926', '1947', 22]
# ['Heinie', 'Peitz', '1892', '1913', 22]
# ['Herb', 'Pennock+', '1912', '1934', 23]
# ['Tony', 'Perez+', '1964', '1986', 23]
# ['Gaylord', 'Perry+', '1962', '1983', 22]
# ['Dave', 'Philley', '1941', '1962', 22]
# ['Lou', 'Piniella', '1964', '1984', 21]
# ['Jack', 'Quinn', '1909', '1933', 25]
# ['Tim', 'Raines+', '1979', '2002', 24]
# ['Jerry', 'Reuss', '1969', '1990', 22]
# ['Arthur', 'Rhodes', '1991', '2011', 21]
# ['Cal', 'Ripken+', '1981', '2001', 21]
# ['Eppa', 'Rixey+', '1912', '1933', 22]
# ['Brooks', 'Robinson+', '1955', '1977', 23]
# ['Frank', 'Robinson+', '1956', '1976', 21]
# ['Alex', 'Rodriguez', '1994', '2016', 23]
# ['Ivan', 'Rodriguez+', '1991', '2011', 21]
# ['Pete', 'Rose', '1963', '1986', 24]
# ['Red', 'Ruffing+', '1924', '1947', 24]
# ['Babe', 'Ruth+', '1914', '1935', 22]
# ['Jack', 'Ryan', '1889', '1913', 25]
# ['Nolan', 'Ryan+', '1966', '1993', 28]
# ['Paul', 'Schreiber', '1922', '1945', 24]
# ['Luke', 'Sewell', '1921', '1942', 22]
# ['Gary', 'Sheffield', '1988', '2009', 22]
# ['Ruben', 'Sierra', '1986', '2006', 21]
# ['Al', 'Simmons+', '1924', '1944', 21]
# ['Curt', 'Simmons', '1947', '1967', 21]
# ['Ted', 'Simmons', '1968', '1988', 21]
# ['Enos', 'Slaughter+', '1938', '1959', 22]
# ['John', 'Smoltz+', '1988', '2009', 22]
# ['Warren', 'Spahn+', '1942', '1965', 24]
# ['Tris', 'Speaker+', '1907', '1928', 22]
# ['Willie', 'Stargell+', '1962', '1982', 21]
# ['Rusty', 'Staub', '1963', '1985', 23]
# ['Gabby', 'Street', '1904', '1931', 28]
# ['Don', 'Sutton+', '1966', '1988', 23]
# ['Frank', 'Tanana', '1973', '1993', 21]
# ['Jim', 'Thome', '1991', '2012', 22]
# ['Sam', 'Thompson+', '1885', '1906', 22]
# ['Elmer', 'Valo', '1940', '1961', 22]
# ['Dazzy', 'Vance+', '1915', '1935', 21]
# ['Mickey', 'Vernon', '1939', '1960', 22]
# ['Omar', 'Vizquel', '1989', '2012', 24]
# ['Honus', 'Wagner+', '1897', '1917', 21]
# ['Bobby', 'Wallace+', '1894', '1918', 25]
# ['David', 'Wells', '1987', '2007', 21]
# ['Hoyt', 'Wilhelm+', '1952', '1972', 21]
# ['Ted', 'Williams+', '1939', '1960', 22]
# ['Dave', 'Winfield+', '1973', '1995', 23]
# ['Early', 'Wynn+', '1939', '1963', 25]
# ['Carl', 'Yastrzemski+', '1961', '1983', 23]
# ['Cy', 'Young+', '1890', '1911', 22]
# number of players: 161

# %% [markdown]
# ### Average length of career

# %%
import numpy as np

len_career = []
for row in split_player_list:
#     if int(row[2]) > 2000:
    len_career.append(row[4])
    
print (np.mean(len_career))
# Out:
# 5.74736398144
